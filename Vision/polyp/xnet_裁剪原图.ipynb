# %% [markdown]
# # Unet模型裁剪labelme生成的图片

# %%
import os
import sys
import cv2
import shutil
import numpy as np
from PIL import Image
from imageio import imread,imwrite

sys.path.insert(0, r'D:\projects\Vision\Lib\trainer')

from mbsh.core.unet.data import *
from mbsh.core.unet_pp.segmentation_models import Unet, Xnet
# from mbsh.core.images import fetch_all_files, split_video
from mbsh.core.xnet import mini_unet_model,xnet_predict_file
# Out:
# 2022-06-06 10:20:06,166 - INFO - __init__.py - init_logger - 58 - ini  logger file D:\projects\Vision\Lib\logs\kernel-db5be543-7330-487f-9b80-163afa95488c.log
# use temp dir:d:\znyx\temp
# 2022-06-06 10:20:07,407 - DEBUG - tpu_cluster_resolver.py - <module> - 32 - Falling back to TensorFlow client; we recommended you install the Cloud TPU client directly with pip install cloud-tpu-client.
# 2022-06-06 10:20:07,749 - DEBUG - __init__.py - <module> - 47 - Creating converter from 7 to 5
# 2022-06-06 10:20:07,749 - DEBUG - __init__.py - <module> - 47 - Creating converter from 5 to 7
# 2022-06-06 10:20:07,750 - DEBUG - __init__.py - <module> - 47 - Creating converter from 7 to 5
# 2022-06-06 10:20:07,750 - DEBUG - __init__.py - <module> - 47 - Creating converter from 5 to 7
# 2022-06-06 10:20:10,075 - INFO - utils.py - _init_num_threads - 145 - Note: NumExpr detected 16 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# 2022-06-06 10:20:10,075 - INFO - utils.py - _init_num_threads - 157 - NumExpr defaulting to 8 threads.
# 2022-06-06 10:20:10,849 - DEBUG - __init__.py - wrapper - 224 - matplotlib data path: C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\mpl-data
# 2022-06-06 10:20:10,857 - DEBUG - __init__.py - wrapper - 224 - CONFIGDIR=C:\Users\Administrator\.matplotlib
# 2022-06-06 10:20:10,860 - DEBUG - __init__.py - <module> - 1394 - matplotlib version 3.4.3
# 2022-06-06 10:20:10,860 - DEBUG - __init__.py - <module> - 1395 - interactive is False
# 2022-06-06 10:20:10,861 - DEBUG - __init__.py - <module> - 1396 - platform is win32
# 2022-06-06 10:20:10,861 - DEBUG - __init__.py - <module> - 1397 - loaded modules: ['sys', 'builtins', '_frozen_importlib', '_imp', '_thread', '_warnings', '_weakref', '_io', 'marshal', 'nt', 'winreg', '_frozen_importlib_external', 'time', 'zipimport', '_codecs', 'codecs', 'encodings.aliases', 'encodings', 'encodings.utf_8', '_signal', 'encodings.latin_1', '_abc', 'abc', 'io', '__main__', '_stat', 'stat', '_collections_abc', 'genericpath', 'ntpath', 'os.path', 'os', '_sitebuiltins', '_locale', '_bootlocale', 'types', 'importlib._bootstrap', 'importlib._bootstrap_external', 'warnings', 'importlib', 'importlib.machinery', '_heapq', 'heapq', 'itertools', 'keyword', '_operator', 'operator', 'reprlib', '_collections', 'collections', 'collections.abc', '_functools', 'functools', 'contextlib', 'enum', '_sre', 'sre_constants', 'sre_parse', 'sre_compile', 'copyreg', 're', 'typing.io', 'typing.re', 'typing', 'importlib.abc', 'importlib.util', 'google', 'google.cloud', 'google.logging', 'google.iam', 'mpl_toolkits', 'ruamel', 'sphinxcontrib', 'zope', 'site', '_weakrefset', 'weakref', 'pkgutil', 'runpy', 'ipykernel._version', '_json', 'json.scanner', 'json.decoder', 'json.encoder', 'json', 'errno', 'signal', 'threading', 'msvcrt', '_winapi', 'subprocess', 'jupyter_client._version', 'posixpath', 'fnmatch', 'glob', '_socket', 'math', 'select', 'selectors', 'socket', 'zlib', '_compression', '_bz2', 'bz2', '_lzma', 'lzma', 'shutil', '_bisect', 'bisect', '_random', '_sha512', 'random', 'tempfile', 'getpass', 'platform', 'zmq.libzmq', 'zmq.backend.select', 'cython_runtime', 'zmq.backend.cython.constants', '_cython_0_29_24', 'zmq.backend.cython.error', 'zmq.error', 'zmq.backend.cython.message', 'zmq.backend.cython.context', 'copy', '_struct', 'struct', '_compat_pickle', '_pickle', 'pickle', 'zmq.backend.cython.socket', 'zmq.backend.cython.utils', 'zmq.backend.cython._poll', 'zmq.backend.cython._version', 'zmq.backend.cython._device', 'zmq.backend.cython._proxy_steerable', 'zmq.backend.cython', 'zmq.backend', 'zmq.utils', 'zmq.utils.constant_names', 'zmq.sugar.constants', 'atexit', 'zmq.sugar.attrsettr', 'zmq.sugar.poll', 'zmq.utils.jsonapi', 'zmq.utils.strtypes', 'zmq.sugar.socket', 'zmq.sugar.context', 'zmq.sugar.frame', 'zmq.sugar.tracker', 'zmq.sugar.version', 'zmq.sugar.stopwatch', 'zmq.sugar', 'zmq', '_ast', 'ast', '_opcode', 'opcode', 'dis', 'token', 'tokenize', 'linecache', 'inspect', 'traitlets.utils', 'traitlets.utils.getargspec', 'traitlets.utils.importstring', 'traitlets.utils.sentinel', 'traitlets.utils.bunch', 'traitlets.utils.descriptions', 'traitlets.traitlets', 'traitlets.utils.decorators', 'traitlets._version', 'traitlets', 'traceback', '_string', 'string', 'logging', 'pprint', 'gettext', 'argparse', 'traitlets.config.loader', 'textwrap', 'traitlets.utils.text', 'traitlets.config.configurable', 'traitlets.config.application', 'traitlets.config', 'jupyter_client.localinterfaces', 'jupyter_core.version', 'jupyter_core', 'urllib', 'urllib.parse', 'pathlib', 'jupyter_core.paths', 'jupyter_client.utils', 'jupyter_client.connect', 'traitlets.log', 'jupyter_client.launcher', 'concurrent', 'concurrent.futures._base', 'concurrent.futures', '_ssl', 'binascii', 'base64', 'ssl', 'asyncio.constants', 'asyncio.format_helpers', 'asyncio.base_futures', 'asyncio.log', 'asyncio.coroutines', '_contextvars', 'contextvars', 'asyncio.exceptions', 'asyncio.base_tasks', '_asyncio', 'asyncio.events', 'asyncio.futures', 'asyncio.protocols', 'asyncio.transports', 'asyncio.sslproto', 'asyncio.locks', 'asyncio.tasks', 'asyncio.staggered', 'asyncio.trsock', 'asyncio.base_events', 'asyncio.runners', 'asyncio.queues', 'asyncio.streams', 'asyncio.subprocess', 'asyncio.threads', '_overlapped', 'asyncio.base_subprocess', 'asyncio.proactor_events', 'asyncio.selector_events', 'asyncio.windows_utils', 'asyncio.windows_events', 'asyncio', 'jupyter_client.channelsabc', 'jupyter_client.channels', 'jupyter_client.clientabc', 'jupyter_client.client', 'jupyter_client.kerne ...
# 2022-06-06 10:20:10,913 - DEBUG - __init__.py - wrapper - 224 - CACHEDIR=C:\Users\Administrator\.matplotlib
# 2022-06-06 10:20:10,917 - DEBUG - font_manager.py - _load_fontmanager - 1439 - Using fontManager instance from C:\Users\Administrator\.matplotlib\fontlist-v330.json
# 2022-06-06 10:20:11,731 - DEBUG - pyplot.py - switch_backend - 290 - Loaded backend module://matplotlib_inline.backend_inline version unknown.
# 2022-06-06 10:20:11,735 - DEBUG - pyplot.py - switch_backend - 290 - Loaded backend module://matplotlib_inline.backend_inline version unknown.
# 2022-06-06 10:20:12,071 - DEBUG - font_manager.py - _findfont_cached - 1329 - findfont: Matching sans\-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=10.0.
# 2022-06-06 10:20:12,072 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'DejaVu Sans' (DejaVuSans-Bold.ttf) normal normal 700 normal>) = 0.33499999999999996
# 2022-06-06 10:20:12,073 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'STIXGeneral' (STIXGeneralBolIta.ttf) italic normal 700 normal>) = 11.335
# 2022-06-06 10:20:12,073 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'DejaVu Sans' (DejaVuSans-Oblique.ttf) oblique normal 400 normal>) = 1.05
# 2022-06-06 10:20:12,074 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'STIXNonUnicode' (STIXNonUniBol.ttf) normal normal 700 normal>) = 10.335
# 2022-06-06 10:20:12,075 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'cmr10' (cmr10.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,075 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'STIXGeneral' (STIXGeneral.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,076 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'cmss10' (cmss10.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,076 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'DejaVu Serif' (DejaVuSerif-Bold.ttf) normal normal 700 normal>) = 10.335
# 2022-06-06 10:20:12,077 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'STIXNonUnicode' (STIXNonUniBolIta.ttf) italic normal 700 normal>) = 11.335
# 2022-06-06 10:20:12,078 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'cmtt10' (cmtt10.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,078 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'STIXGeneral' (STIXGeneralItalic.ttf) italic normal 400 normal>) = 11.05
# 2022-06-06 10:20:12,079 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'DejaVu Serif Display' (DejaVuSerifDisplay.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,080 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'DejaVu Sans Mono' (DejaVuSansMono.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,080 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'DejaVu Sans Mono' (DejaVuSansMono-Bold.ttf) normal normal 700 normal>) = 10.335
# 2022-06-06 10:20:12,081 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'DejaVu Sans Mono' (DejaVuSansMono-BoldOblique.ttf) oblique normal 700 normal>) = 11.335
# 2022-06-06 10:20:12,081 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'STIXSizeThreeSym' (STIXSizThreeSymBol.ttf) normal normal 700 normal>) = 10.335
# 2022-06-06 10:20:12,082 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'STIXGeneral' (STIXGeneralBol.ttf) normal normal 700 normal>) = 10.335
# 2022-06-06 10:20:12,082 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'DejaVu Serif' (DejaVuSerif-Italic.ttf) italic normal 400 normal>) = 11.05
# 2022-06-06 10:20:12,083 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'cmex10' (cmex10.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,084 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'DejaVu Sans' (DejaVuSans-BoldOblique.ttf) oblique normal 700 normal>) = 1.335
# 2022-06-06 10:20:12,085 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'DejaVu Sans Display' (DejaVuSansDisplay.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,086 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'STIXSizeFourSym' (STIXSizFourSymReg.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,087 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'STIXSizeFourSym' (STIXSizFourSymBol.ttf) normal normal 700 normal>) = 10.335
# 2022-06-06 10:20:12,087 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'DejaVu Sans' (DejaVuSans.ttf) normal normal 400 normal>) = 0.05
# 2022-06-06 10:20:12,088 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'cmsy10' (cmsy10.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,088 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'cmb10' (cmb10.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,089 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'DejaVu Sans Mono' (DejaVuSansMono-Oblique.ttf) oblique normal 400 normal>) = 11.05
# 2022-06-06 10:20:12,089 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'DejaVu Serif' (DejaVuSerif.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,090 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'STIXSizeFiveSym' (STIXSizFiveSymReg.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,091 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'STIXSizeTwoSym' (STIXSizTwoSymReg.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,091 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'cmmi10' (cmmi10.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,092 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'STIXSizeOneSym' (STIXSizOneSymBol.ttf) normal normal 700 normal>) = 10.335
# 2022-06-06 10:20:12,093 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'STIXSizeOneSym' (STIXSizOneSymReg.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,094 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'DejaVu Serif' (DejaVuSerif-BoldItalic.ttf) italic normal 700 normal>) = 11.335
# 2022-06-06 10:20:12,095 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'STIXNonUnicode' (STIXNonUniIta.ttf) italic normal 400 normal>) = 11.05
# 2022-06-06 10:20:12,096 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'STIXSizeTwoSym' (STIXSizTwoSymBol.ttf) normal normal 700 normal>) = 10.335
# 2022-06-06 10:20:12,097 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'STIXNonUnicode' (STIXNonUni.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,098 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'STIXSizeThreeSym' (STIXSizThreeSymReg.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,099 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Bookman Old Style' (BOOKOSBI.TTF) italic normal 600 normal>) = 11.24
# 2022-06-06 10:20:12,099 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Book Antiqua' (ANTQUAI.TTF) italic normal 400 normal>) = 11.05
# 2022-06-06 10:20:12,100 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Candara' (Candarali.ttf) italic normal 400 normal>) = 11.05
# 2022-06-06 10:20:12,100 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Nirmala UI' (Nirmala.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,101 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Arial' (ariali.ttf) italic normal 400 normal>) = 7.413636363636363
# 2022-06-06 10:20:12,102 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'MS Reference Sans Serif' (REFSAN.TTF) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,103 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'STLiti' (STLITI.TTF) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,104 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Century' (CENTURY.TTF) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,104 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Corbel' (corbeli.ttf) italic normal 400 normal>) = 11.05
# 2022-06-06 10:20:12,105 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Segoe UI' (segoeuib.ttf) normal normal 700 normal>) = 10.335
# 2022-06-06 10:20:12,106 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Tahoma' (tahoma.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,106 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Sylfaen' (sylfaen.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,107 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'STHupo' (STHUPO.TTF) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,108 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Calibri' (calibrii.ttf) italic normal 400 normal>) = 11.05
# 2022-06-06 10:20:12,108 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Microsoft Sans Serif' (micross.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,109 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'SimSun-ExtB' (simsunb.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,110 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Microsoft JhengHei' (msjhbd.ttc) normal normal 700 normal>) = 10.335
# 2022-06-06 10:20:12,110 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Book Antiqua' (ANTQUABI.TTF) italic normal 700 normal>) = 11.335
# 2022-06-06 10:20:12,111 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Malgun Gothic' (malgun.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,111 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'FangSong' (simfang.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,112 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Nirmala UI' (NirmalaB.ttf) normal normal 700 normal>) = 10.335
# 2022-06-06 10:20:12,113 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Georgia' (georgiai.ttf) italic normal 400 normal>) = 11.05
# 2022-06-06 10:20:12,113 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Segoe UI Emoji' (seguiemj.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,114 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Javanese Text' (javatext.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,115 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Verdana' (verdanaz.ttf) italic normal 700 normal>) = 4.971363636363637
# 2022-06-06 10:20:12,116 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Segoe UI Historic' (seguihis.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,117 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Dubai' (DUBAI-REGULAR.TTF) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,118 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Candara' (Candara.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,119 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Verdana' (verdana.ttf) normal normal 400 normal>) = 3.6863636363636365
# 2022-06-06 10:20:12,120 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Microsoft PhagsPa' (phagspab.ttf) normal normal 700 normal>) = 10.335
# 2022-06-06 10:20:12,120 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Microsoft YaHei' (msyh.ttc) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,121 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Segoe Print' (segoepr.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,122 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Dubai' (DUBAI-BOLD.TTF) normal normal 700 normal>) = 10.335
# 2022-06-06 10:20:12,123 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Corbel' (corbelb.ttf) normal normal 700 normal>) = 10.335
# 2022-06-06 10:20:12,123 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Garamond' (GARAIT.TTF) italic normal 400 normal>) = 11.05
# 2022-06-06 10:20:12,124 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Corbel' (corbeli.ttf) italic normal 400 normal>) = 11.05
# 2022-06-06 10:20:12,125 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Microsoft JhengHei' (msjh.ttc) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,126 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Palatino Linotype' (palabi.ttf) italic normal 700 normal>) = 11.335
# 2022-06-06 10:20:12,128 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Verdana' (verdanaz.ttf) italic normal 700 normal>) = 4.971363636363637
# 2022-06-06 10:20:12,128 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Century Gothic' (GOTHICI.TTF) italic normal 400 normal>) = 11.05
# 2022-06-06 10:20:12,129 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Verdana' (verdanai.ttf) italic normal 400 normal>) = 4.6863636363636365
# 2022-06-06 10:20:12,131 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'DengXian' (Deng.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,131 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Calibri' (calibriz.ttf) italic normal 700 normal>) = 11.335
# 2022-06-06 10:20:12,132 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'MS Gothic' (msgothic.ttc) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,133 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Wingdings' (wingding.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,134 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Garamond' (GARABD.TTF) normal normal 700 normal>) = 10.335
# 2022-06-06 10:20:12,135 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Segoe UI' (seguisbi.ttf) italic normal 600 normal>) = 11.24
# 2022-06-06 10:20:12,136 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Ebrima' (ebrimabd.ttf) normal normal 700 normal>) = 10.335
# 2022-06-06 10:20:12,137 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Gadugi' (gadugib.ttf) normal normal 700 normal>) = 10.335
# 2022-06-06 10:20:12,138 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Candara' (Candaraz.ttf) italic normal 700 normal>) = 11.335
# 2022-06-06 10:20:12,138 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'LiSu' (SIMLI.TTF) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,139 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'SimHei' (simhei.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,140 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'DengXian' (Dengl.ttf) normal normal 300 normal>) = 10.145
# 2022-06-06 10:20:12,141 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Consolas' (consolab.ttf) normal normal 700 normal>) = 10.335
# 2022-06-06 10:20:12,142 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'MingLiU-ExtB' (mingliub.ttc) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,142 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'STHupo' (STHUPO.TTF) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,143 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Segoe Script' (segoesc.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,144 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Century Gothic' (GOTHICI.TTF) italic normal 400 normal>) = 11.05
# 2022-06-06 10:20:12,145 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Square721 BT' (TT0246M_.TTF) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,146 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Segoe UI' (seguisbi.ttf) italic normal 600 normal>) = 11.24
# 2022-06-06 10:20:12,147 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'STXingkai' (STXINGKA.TTF) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,148 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Trebuchet MS' (trebucit.ttf) italic normal 400 normal>) = 11.05
# 2022-06-06 10:20:12,148 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Ebrima' (ebrima.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,149 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Trebuchet MS' (trebucbd.ttf) normal normal 700 normal>) = 10.335
# 2022-06-06 10:20:12,150 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Segoe UI' (seguibli.ttf) italic normal 900 normal>) = 11.525
# 2022-06-06 10:20:12,151 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Century Gothic' (GOTHICB.TTF) normal normal 700 normal>) = 10.335
# 2022-06-06 10:20:12,152 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'LiSu' (SIMLI.TTF) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,153 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Sitka Small' (SitkaI.ttc) italic normal 400 normal>) = 11.05
# 2022-06-06 10:20:12,153 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Consolas' (consolab.ttf) normal normal 700 normal>) = 10.335
# 2022-06-06 10:20:12,154 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Segoe UI' (seguibli.ttf) italic normal 900 normal>) = 11.525
# 2022-06-06 10:20:12,155 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Corbel' (corbell.ttf) normal normal 300 normal>) = 10.145
# 2022-06-06 10:20:12,156 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Century Gothic' (GOTHICBI.TTF) italic normal 700 normal>) = 11.335
# 2022-06-06 10:20:12,156 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Microsoft PhagsPa' (phagspa.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,158 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Candara' (Candarab.ttf) normal normal 700 normal>) = 10.335
# 2022-06-06 10:20:12,159 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'SimSun-ExtB' (simsunb.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,160 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Yu Gothic' (YuGothM.ttc) normal normal 500 normal>) = 10.145
# 2022-06-06 10:20:12,161 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Comic Sans MS' (comicbd.ttf) normal normal 700 normal>) = 10.335
# 2022-06-06 10:20:12,162 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Cambria' (cambriab.ttf) normal normal 700 normal>) = 10.335
# 2022-06-06 10:20:12,163 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Book Antiqua' (ANTQUABI.TTF) italic normal 700 normal>) = 11.335
# 2022-06-06 10:20:12,164 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'SimHei' (simhei.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,164 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Segoe UI' (segoeuil.ttf) normal normal 300 normal>) = 10.145
# 2022-06-06 10:20:12,165 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Arial' (ariblk.ttf) normal normal 900 normal>) = 6.888636363636364
# 2022-06-06 10:20:12,168 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'STXinwei' (STXINWEI.TTF) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,168 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Corbel' (corbel.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,169 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Candara' (Candarali.ttf) italic normal 400 normal>) = 11.05
# 2022-06-06 10:20:12,170 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Cambria' (cambriab.ttf) normal normal 700 normal>) = 10.335
# 2022-06-06 10:20:12,171 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Leelawadee UI' (LeelaUIb.ttf) normal normal 700 normal>) = 10.335
# 2022-06-06 10:20:12,172 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'MV Boli' (mvboli.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,172 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Calibri' (calibriz.ttf) italic normal 700 normal>) = 11.335
# 2022-06-06 10:20:12,174 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Arial' (arial.ttf) normal normal 400 normal>) = 6.413636363636363
# 2022-06-06 10:20:12,175 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Dubai' (DUBAI-LIGHT.TTF) normal normal 300 normal>) = 10.145
# 2022-06-06 10:20:12,176 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Microsoft JhengHei' (msjhbd.ttc) normal normal 700 normal>) = 10.335
# 2022-06-06 10:20:12,177 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Javanese Text' (javatext.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,179 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Ink Free' (Inkfree.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,180 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Palatino Linotype' (palabi.ttf) italic normal 700 normal>) = 11.335
# 2022-06-06 10:20:12,181 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'YouYuan' (SIMYOU.TTF) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,182 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Segoe UI' (segoeui.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,182 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Bookman Old Style' (BOOKOSI.TTF) italic normal 300 normal>) = 11.145
# 2022-06-06 10:20:12,183 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Yu Gothic' (YuGothB.ttc) normal normal 700 normal>) = 10.335
# 2022-06-06 10:20:12,184 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Bookman Old Style' (BOOKOSI.TTF) italic normal 300 normal>) = 11.145
# 2022-06-06 10:20:12,184 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'STKaiti' (STKAITI.TTF) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,185 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Microsoft PhagsPa' (phagspab.ttf) normal normal 700 normal>) = 10.335
# 2022-06-06 10:20:12,186 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Segoe Script' (segoescb.ttf) normal normal 700 normal>) = 10.335
# 2022-06-06 10:20:12,187 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Segoe UI' (segoeuil.ttf) normal normal 300 normal>) = 10.145
# 2022-06-06 10:20:12,188 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'STKaiti' (STKAITI.TTF) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,189 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Gabriola' (Gabriola.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,189 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Courier New' (cour.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,190 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Arial' (arialbd.ttf) normal normal 700 normal>) = 6.698636363636363
# 2022-06-06 10:20:12,191 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Monotype Corsiva' (MTCORSVA.TTF) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,191 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Candara' (Candaraz.ttf) italic normal 700 normal>) = 11.335
# 2022-06-06 10:20:12,192 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Constantia' (constan.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,193 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Comic Sans MS' (comic.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,194 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Malgun Gothic' (malgunsl.ttf) normal normal 300 normal>) = 10.145
# 2022-06-06 10:20:12,195 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Microsoft New Tai Lue' (ntailu.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,196 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Yu Gothic' (YuGothM.ttc) normal normal 500 normal>) = 10.145
# 2022-06-06 10:20:12,196 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Adobe Devanagari' (AdobeDevanagari-Bold.otf) normal normal 700 normal>) = 10.335
# 2022-06-06 10:20:12,197 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Arial' (ARIALNB.TTF) normal normal 700 condensed>) = 6.8986363636363635
# 2022-06-06 10:20:12,198 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Microsoft YaHei' (msyhbd.ttc) normal normal 700 normal>) = 10.335
# 2022-06-06 10:20:12,198 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Sitka Small' (SitkaI.ttc) italic normal 400 normal>) = 11.05
# 2022-06-06 10:20:12,199 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Myanmar Text' (mmrtextb.ttf) normal normal 700 normal>) = 10.335
# 2022-06-06 10:20:12,200 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Arial' (ARIALNBI.TTF) italic normal 700 condensed>) = 7.8986363636363635
# 2022-06-06 10:20:12,200 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Times New Roman' (timesi.ttf) italic normal 400 normal>) = 11.05
# 2022-06-06 10:20:12,201 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Microsoft New Tai Lue' (ntailu.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,202 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Verdana' (verdana.ttf) normal normal 400 normal>) = 3.6863636363636365
# 2022-06-06 10:20:12,203 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'STFangsong' (STFANGSO.TTF) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,204 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Palatino Linotype' (palai.ttf) italic normal 400 normal>) = 11.05
# 2022-06-06 10:20:12,205 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Adobe Devanagari' (AdobeDevanagari-Italic.otf) italic normal 400 normal>) = 11.05
# 2022-06-06 10:20:12,205 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Garamond' (GARA.TTF) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,207 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Microsoft JhengHei' (msjh.ttc) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,207 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Lucida Sans Unicode' (l_10646.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,208 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Nirmala UI' (NirmalaB.ttf) normal normal 700 normal>) = 10.335
# 2022-06-06 10:20:12,209 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Palatino Linotype' (palab.ttf) normal normal 700 normal>) = 10.335
# 2022-06-06 10:20:12,209 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'MT Extra' (MTEXTRA.TTF) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,210 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Microsoft PhagsPa' (phagspa.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,211 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Lucida Console' (lucon.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,211 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Sitka Small' (SitkaB.ttc) normal normal 700 normal>) = 10.335
# 2022-06-06 10:20:12,213 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Verdana' (verdanab.ttf) normal normal 700 normal>) = 3.9713636363636367
# 2022-06-06 10:20:12,213 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Corbel' (corbelz.ttf) italic normal 700 normal>) = 11.335
# 2022-06-06 10:20:12,214 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Microsoft YaHei' (msyhl.ttc) normal normal 290 normal>) = 10.1545
# 2022-06-06 10:20:12,215 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Cambria' (cambriaz.ttf) italic normal 700 normal>) = 11.335
# 2022-06-06 10:20:12,215 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Palatino Linotype' (pala.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,216 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Georgia' (georgia.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,217 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Segoe UI' (seguisb.ttf) normal normal 600 normal>) = 10.24
# 2022-06-06 10:20:12,218 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Arial' (ariali.ttf) italic normal 400 normal>) = 7.413636363636363
# 2022-06-06 10:20:12,218 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Segoe UI' (segoeuii.ttf) italic normal 400 normal>) = 11.05
# 2022-06-06 10:20:12,219 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Cambria' (cambriai.ttf) italic normal 400 normal>) = 11.05
# 2022-06-06 10:20:12,220 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Gadugi' (gadugi.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,220 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Georgia' (georgiai.ttf) italic normal 400 normal>) = 11.05
# 2022-06-06 10:20:12,221 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Microsoft New Tai Lue' (ntailub.ttf) normal normal 700 normal>) = 10.335
# 2022-06-06 10:20:12,222 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Tahoma' (tahoma.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,223 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Sylfaen' (sylfaen.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,223 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Cambria' (cambriai.ttf) italic normal 400 normal>) = 11.05
# 2022-06-06 10:20:12,224 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Nirmala UI' (Nirmala.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,225 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Candara' (Candaral.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,225 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Myanmar Text' (mmrtext.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,226 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'STXihei' (STXIHEI.TTF) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,227 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Garamond' (GARA.TTF) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,228 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Century Gothic' (GOTHICBI.TTF) italic normal 700 normal>) = 11.335
# 2022-06-06 10:20:12,228 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Nirmala UI' (NirmalaS.ttf) normal normal 350 normal>) = 10.0975
# 2022-06-06 10:20:12,230 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Consolas' (consolaz.ttf) italic normal 700 normal>) = 11.335
# 2022-06-06 10:20:12,230 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Bookshelf Symbol 7' (BSSYM7.TTF) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,231 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Franklin Gothic Medium' (framd.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,233 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Lucida Console' (lucon.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,234 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Candara' (Candarai.ttf) italic normal 400 normal>) = 11.05
# 2022-06-06 10:20:12,235 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Garamond' (GARABD.TTF) normal normal 700 normal>) = 10.335
# 2022-06-06 10:20:12,236 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Sitka Small' (Sitka.ttc) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,237 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Arial' (ARIALNI.TTF) italic normal 400 condensed>) = 7.613636363636363
# 2022-06-06 10:20:12,238 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Segoe MDL2 Assets' (segmdl2.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,238 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Book Antiqua' (ANTQUAB.TTF) normal normal 700 normal>) = 10.335
# 2022-06-06 10:20:12,240 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Yu Gothic' (YuGothR.ttc) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,240 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Microsoft Tai Le' (taile.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,241 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Segoe Print' (segoepr.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,242 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Arial' (arialbd.ttf) normal normal 700 normal>) = 6.698636363636363
# 2022-06-06 10:20:12,243 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Segoe UI' (seguili.ttf) italic normal 300 normal>) = 11.145
# 2022-06-06 10:20:12,243 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Palatino Linotype' (palai.ttf) italic normal 400 normal>) = 11.05
# 2022-06-06 10:20:12,244 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Arial' (ARIALNBI.TTF) italic normal 700 condensed>) = 7.8986363636363635
# 2022-06-06 10:20:12,246 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Dubai' (DUBAI-MEDIUM.TTF) normal normal 500 normal>) = 10.145
# 2022-06-06 10:20:12,246 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Century Gothic' (GOTHIC.TTF) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,248 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Georgia' (georgiab.ttf) normal normal 700 normal>) = 10.335
# 2022-06-06 10:20:12,249 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Webdings' (webdings.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,249 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Times New Roman' (timesi.ttf) italic normal 400 normal>) = 11.05
# 2022-06-06 10:20:12,250 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Georgia' (georgiaz.ttf) italic normal 700 normal>) = 11.335
# 2022-06-06 10:20:12,251 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Bookman Old Style' (BOOKOSB.TTF) normal normal 600 normal>) = 10.24
# 2022-06-06 10:20:12,252 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Lucida Sans Unicode' (l_10646.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,253 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'FZYaoTi' (FZYTK.TTF) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,254 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'YouYuan' (SIMYOU.TTF) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,255 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Myanmar Text' (mmrtext.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,256 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Corbel' (corbelz.ttf) italic normal 700 normal>) = 11.335
# 2022-06-06 10:20:12,257 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Ebrima' (ebrimabd.ttf) normal normal 700 normal>) = 10.335
# 2022-06-06 10:20:12,258 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'STXinwei' (STXINWEI.TTF) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,259 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Segoe UI' (seguisb.ttf) normal normal 600 normal>) = 10.24
# 2022-06-06 10:20:12,260 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Ink Free' (Inkfree.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,261 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Myanmar Text' (mmrtextb.ttf) normal normal 700 normal>) = 10.335
# 2022-06-06 10:20:12,262 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Calibri' (calibril.ttf) normal normal 300 normal>) = 10.145
# 2022-06-06 10:20:12,263 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Marlett' (marlett.ttf) normal normal 500 normal>) = 10.145
# 2022-06-06 10:20:12,263 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'MS Reference Sans Serif' (REFSAN.TTF) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,264 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Trebuchet MS' (trebuc.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,265 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Calibri' (calibrili.ttf) italic normal 300 normal>) = 11.145
# 2022-06-06 10:20:12,266 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Georgia' (georgia.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,267 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Microsoft JhengHei' (msjhl.ttc) normal normal 290 normal>) = 10.1545
# 2022-06-06 10:20:12,267 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'SimSun' (simsun.ttc) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,268 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Comic Sans MS' (comic.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,269 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'DengXian' (Deng.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,269 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Verdana' (verdanai.ttf) italic normal 400 normal>) = 4.6863636363636365
# 2022-06-06 10:20:12,270 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Segoe MDL2 Assets' (segmdl2.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,270 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Arial' (arialbi.ttf) italic normal 700 normal>) = 7.698636363636363
# 2022-06-06 10:20:12,271 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Impact' (impact.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,272 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'STSong' (STSONG.TTF) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,272 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Segoe UI' (segoeuiz.ttf) italic normal 700 normal>) = 11.335
# 2022-06-06 10:20:12,273 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'MV Boli' (mvboli.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,274 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Wingdings 3' (WINGDNG3.TTF) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,275 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'MT Extra' (MTEXTRA.TTF) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,276 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Arial' (ARIALNI.TTF) italic normal 400 condensed>) = 7.613636363636363
# 2022-06-06 10:20:12,277 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Yu Gothic' (YuGothL.ttc) normal normal 300 normal>) = 10.145
# ...
# 2022-06-06 10:20:12,344 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Consolas' (consolaz.ttf) italic normal 700 normal>) = 11.335
# 2022-06-06 10:20:12,345 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Constantia' (constan.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,346 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Leelawadee UI' (LeelawUI.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,347 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Georgia' (georgiab.ttf) normal normal 700 normal>) = 10.335
# 2022-06-06 10:20:12,348 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Segoe Script' (segoescb.ttf) normal normal 700 normal>) = 10.335
# 2022-06-06 10:20:12,348 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'MS Gothic' (msgothic.ttc) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,349 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Segoe Script' (segoesc.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,350 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Century' (CENTURY.TTF) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,351 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Courier New' (couri.ttf) italic normal 400 normal>) = 11.05
# 2022-06-06 10:20:12,351 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Leelawadee UI' (LeelaUIb.ttf) normal normal 700 normal>) = 10.335
# 2022-06-06 10:20:12,352 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Arial' (ARIALN.TTF) normal normal 400 condensed>) = 6.613636363636363
# 2022-06-06 10:20:12,353 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Candara' (Candaral.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,354 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'FZYaoTi' (FZYTK.TTF) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,354 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'STSong' (STSONG.TTF) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,355 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'DengXian' (Dengb.ttf) normal normal 700 normal>) = 10.335
# 2022-06-06 10:20:12,356 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Franklin Gothic Medium' (framd.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,357 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Segoe UI' (seguisli.ttf) italic normal 350 normal>) = 11.0975
# 2022-06-06 10:20:12,358 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Dubai' (DUBAI-REGULAR.TTF) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,358 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Calibri' (calibri.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,359 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Gadugi' (gadugi.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,360 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Arial' (arial.ttf) normal normal 400 normal>) = 6.413636363636363
# 2022-06-06 10:20:12,360 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Corbel' (corbelb.ttf) normal normal 700 normal>) = 10.335
# 2022-06-06 10:20:12,361 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Microsoft Yi Baiti' (msyi.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,362 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Calibri' (calibrib.ttf) normal normal 700 normal>) = 10.335
# 2022-06-06 10:20:12,363 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Segoe UI Symbol' (seguisym.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,364 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Calibri' (calibril.ttf) normal normal 300 normal>) = 10.145
# 2022-06-06 10:20:12,365 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Arial' (ARIALN.TTF) normal normal 400 condensed>) = 6.613636363636363
# 2022-06-06 10:20:12,365 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Corbel' (corbelli.ttf) italic normal 300 normal>) = 11.145
# 2022-06-06 10:20:12,366 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Comic Sans MS' (comici.ttf) italic normal 400 normal>) = 11.05
# 2022-06-06 10:20:12,367 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'STFangsong' (STFANGSO.TTF) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,368 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Segoe UI' (segoeuisl.ttf) normal normal 350 normal>) = 10.0975
# 2022-06-06 10:20:12,368 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Trebuchet MS' (trebucbi.ttf) italic normal 700 normal>) = 11.335
# 2022-06-06 10:20:12,369 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'FZShuTi' (FZSTK.TTF) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,369 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Trebuchet MS' (trebucbi.ttf) italic normal 700 normal>) = 11.335
# 2022-06-06 10:20:12,370 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'MS Reference Specialty' (REFSPCL.TTF) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,371 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Sitka Small' (SitkaZ.ttc) italic normal 700 normal>) = 11.335
# 2022-06-06 10:20:12,372 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Wingdings 2' (WINGDNG2.TTF) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,372 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'STZhongsong' (STZHONGS.TTF) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,373 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Candara' (Candarai.ttf) italic normal 400 normal>) = 11.05
# 2022-06-06 10:20:12,374 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Bookman Old Style' (BOOKOS.TTF) normal normal 300 normal>) = 10.145
# 2022-06-06 10:20:12,374 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Comic Sans MS' (comici.ttf) italic normal 400 normal>) = 11.05
# 2022-06-06 10:20:12,375 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Times New Roman' (timesbi.ttf) italic normal 700 normal>) = 11.335
# 2022-06-06 10:20:12,375 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'HoloLens MDL2 Assets' (holomdl2.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,376 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Candara' (Candarab.ttf) normal normal 700 normal>) = 10.335
# 2022-06-06 10:20:12,377 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Yu Gothic' (YuGothB.ttc) normal normal 700 normal>) = 10.335
# 2022-06-06 10:20:12,378 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Arial' (arialbi.ttf) italic normal 700 normal>) = 7.698636363636363
# 2022-06-06 10:20:12,379 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Comic Sans MS' (comicbd.ttf) normal normal 700 normal>) = 10.335
# 2022-06-06 10:20:12,380 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Nirmala UI' (NirmalaS.ttf) normal normal 350 normal>) = 10.0975
# 2022-06-06 10:20:12,381 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Segoe UI' (seguisli.ttf) italic normal 350 normal>) = 11.0975
# 2022-06-06 10:20:12,381 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Malgun Gothic' (malgunbd.ttf) normal normal 700 normal>) = 10.335
# 2022-06-06 10:20:12,382 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Book Antiqua' (ANTQUAB.TTF) normal normal 700 normal>) = 10.335
# 2022-06-06 10:20:12,383 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Tahoma' (tahomabd.ttf) normal normal 700 normal>) = 10.335
# 2022-06-06 10:20:12,383 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Calibri' (calibrili.ttf) italic normal 300 normal>) = 11.145
# 2022-06-06 10:20:12,384 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Segoe UI Historic' (seguihis.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,385 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Trebuchet MS' (trebuc.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,385 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Webdings' (webdings.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,386 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Book Antiqua' (ANTQUAI.TTF) italic normal 400 normal>) = 11.05
# 2022-06-06 10:20:12,386 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Malgun Gothic' (malgunsl.ttf) normal normal 300 normal>) = 10.145
# 2022-06-06 10:20:12,387 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Microsoft Himalaya' (himalaya.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,388 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Impact' (impact.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,388 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Dubai' (DUBAI-LIGHT.TTF) normal normal 300 normal>) = 10.145
# 2022-06-06 10:20:12,389 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Segoe UI' (segoeuii.ttf) italic normal 400 normal>) = 11.05
# 2022-06-06 10:20:12,390 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Courier New' (courbd.ttf) normal normal 700 normal>) = 10.335
# 2022-06-06 10:20:12,390 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Dubai' (DUBAI-BOLD.TTF) normal normal 700 normal>) = 10.335
# 2022-06-06 10:20:12,391 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Palatino Linotype' (pala.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,392 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Consolas' (consola.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,392 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Times New Roman' (timesbi.ttf) italic normal 700 normal>) = 11.335
# 2022-06-06 10:20:12,393 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Malgun Gothic' (malgunbd.ttf) normal normal 700 normal>) = 10.335
# 2022-06-06 10:20:12,394 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Century Gothic' (GOTHIC.TTF) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,394 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'STCaiyun' (STCAIYUN.TTF) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,395 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Times New Roman' (times.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,397 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Arial' (ariblk.ttf) normal normal 900 normal>) = 6.888636363636364
# 2022-06-06 10:20:12,398 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Mongolian Baiti' (monbaiti.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,398 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Bookman Old Style' (BOOKOSBI.TTF) italic normal 600 normal>) = 11.24
# 2022-06-06 10:20:12,399 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Georgia' (georgiaz.ttf) italic normal 700 normal>) = 11.335
# 2022-06-06 10:20:12,400 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'FangSong' (simfang.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,401 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'STXingkai' (STXINGKA.TTF) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,402 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Bahnschrift' (bahnschrift.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,402 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'MS Reference Specialty' (REFSPCL.TTF) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,403 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Bahnschrift' (bahnschrift.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,403 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Calibri' (calibrii.ttf) italic normal 400 normal>) = 11.05
# 2022-06-06 10:20:12,404 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Segoe UI' (seguibl.ttf) normal normal 900 normal>) = 10.525
# 2022-06-06 10:20:12,405 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Tahoma' (tahomabd.ttf) normal normal 700 normal>) = 10.335
# 2022-06-06 10:20:12,406 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Sitka Small' (SitkaZ.ttc) italic normal 700 normal>) = 11.335
# 2022-06-06 10:20:12,406 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Times New Roman' (times.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,407 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Cambria' (cambriaz.ttf) italic normal 700 normal>) = 11.335
# 2022-06-06 10:20:12,408 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'KaiTi' (simkai.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,408 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Symbol' (symbol.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,409 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Verdana' (verdanab.ttf) normal normal 700 normal>) = 3.9713636363636367
# 2022-06-06 10:20:12,410 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Microsoft Tai Le' (taile.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,410 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Microsoft YaHei' (msyhbd.ttc) normal normal 700 normal>) = 10.335
# 2022-06-06 10:20:12,411 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Palatino Linotype' (palab.ttf) normal normal 700 normal>) = 10.335
# 2022-06-06 10:20:12,412 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Gadugi' (gadugib.ttf) normal normal 700 normal>) = 10.335
# 2022-06-06 10:20:12,413 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'Calibri' (calibri.ttf) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,414 - DEBUG - font_manager.py - _findfont_cached - 1341 - findfont: score(<Font 'ZWAdobeF' (ZWAdobeF.TTF) normal normal 400 normal>) = 10.05
# 2022-06-06 10:20:12,414 - DEBUG - font_manager.py - _findfont_cached - 1367 - findfont: Matching sans\-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=10.0 to DejaVu Sans ('C:\\ProgramData\\Anaconda3\\lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\DejaVuSans.ttf') with score of 0.050000.

# %%
from mbsh.core.xnet import mini_unet_model, xnet_predict_file

# %%
os.environ["CUDA_DEVICE_ORDER"] ="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="-1"  
import tensorflow as tf
tf.test.is_gpu_available()
# Out:
# 2022-06-06 10:20:28,762 - WARNING - deprecation.py - new_func - 350 - From C:\Users\ADMINI~1\AppData\Local\Temp/ipykernel_89100/3939705663.py:4: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# False

# %% [markdown]
# ## 模型配置

# %%
# model_path = r'H:\ai_data\img_crop\train1227\cache\X_ca_region_19-12-27_10_16_19-0.996.hdf5'
# model_path = r'H:\ai_data\img_crop\纵隔超声/cache\X_ca_region_21-05-12_10_21_14-0.995.hdf5'
model_path = r'D:\projects\Vision\Models\X_ca_region_21-09-07_14_07_17-0.995.hdf5'

img_size = (512, 512)
input_size = img_size + (3,)
use_unet = False

# 视频图转换后图像大小
# 不改变尺寸则设置为None
img_resize = None #(512, 512)

# %% [markdown]
# ## 加载模型及参数

# %%
# 创建模型并加载
if use_unet:
#     model = unet(input_size=input_size)
    model = Unet(input_shape=input_size, backbone_name='resnet50', encoder_weights='imagenet', decoder_block_type='transpose')
else:
    model = Xnet(input_shape=input_size, backbone_name='resnet50', encoder_weights='imagenet', decoder_block_type='transpose')

model.load_weights(model_path)
# Out:
# 2022-06-06 10:22:04,333 - DEBUG - attrs.py - __getitem__ - 77 - Creating converter from 3 to 5
# KerasTensor(type_spec=TensorSpec(shape=(None, 16, 16, 2048), dtype=tf.float32, name=None), name='relu1/Relu:0', description="created by layer 'relu1'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 16, 16, 2048), dtype=tf.float32, name=None), name='relu1/Relu:0', description="created by layer 'relu1'")

# %% [markdown]
# ## 图片处理函数

# %%
cv2.__version__
# Out:
# '4.4.0'

# %%
# 根据轮廓点列表计算轮廓面积
def areaCal(contour):
    area = 0
    for i in range(len(contour)):
        area += cv2.contourArea(contour[i])
    return area


def takeLength(elem):
    return areaCal([elem])

def resize_image(img, size):
    """
    resize 保持原图的长宽比
    """
    image = Image.fromarray(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
#     print(image.size,image.shape,type(image))
    iw, ih = image.size
    w, h = size
    scale = min(w / iw, h / ih)
    nw = int(iw * scale)
    nh = int(ih * scale)

    image = image.resize((nw, nh), Image.BICUBIC)
    new_image = Image.new('RGB', size, (0, 0, 0))
    new_image.paste(image, ((w - nw) // 2, (h - nh) // 2))
    img = np.array(new_image)
    return (scale, nw, nh), img[:, :, ::-1]

def process_img(src_img, img_size):
    src_img_bak = src_img.copy()
    src_h = src_img_bak.shape[0]
    src_w = src_img_bak.shape[1]

    new_w, new_h = img_size

    (scale, nw, nh), img = resize_image(src_img, img_size)

    # trans.resize把img从numpy.uint8类型转换为numpy.float64
    img = trans.resize(img, img_size)

    # reshape把img从(512, 512, 3)转换为(1, 512, 512, 3)
    img = np.reshape(img,(1,)+img.shape)

    # 模型识别图片, results为(1, 512, 512, 1)，是灰度图片
    results = model.predict(np.array(img),verbose=1)

    # gray_img是（512，512）的灰度图，元素类型numpy.float32
    gray_img = results[0][:,:,0]
    gray_img[np.where(gray_img <= 0.3)] = 0

    # heatmap转为灰度图
    bw_heatmap = np.uint8(255 * gray_img)
    bw_heatmap[bw_heatmap != 0] = 255
    if cv2.__version__[0] == '4':
        ai_ctrs, _ = cv2.findContours(bw_heatmap.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    else:
        _, ai_ctrs, _ = cv2.findContours(bw_heatmap.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    
    if len(ai_ctrs) == 0:
        print('len ai ctrs 000000000000')
        return False,src_img
        
#     print(ai_ctrs, 'ppppppp')
    ai_ctrs = list(ai_ctrs)
    ai_ctrs.sort(key=takeLength, reverse=True)
    

    x,y,w,h = cv2.boundingRect(ai_ctrs[0])

    # 映射到原图尺寸的坐标系  
    x = x - (new_w - nw) // 2
    y = y - (new_h - nh) // 2
    
    new_x = 0 if x < 0 else x
    new_y = 0 if y < 0 else y
    
    x1 = int(new_x / scale)
    y1 = int(new_y / scale)
    w1 = int(w / scale)
    h1 = int(h / scale)
    
    img_out = src_img_bak[y1:y1+h1, x1:x1+w1, :]
#     print(x1, y1, w1, h1, '3333333333')
    return True,img_out, (x1, y1, w1, h1)
#     return True,img_out[: , : , : : -1], (x1, y1, w1, h1)

def predict_file(file, output_folder, test_label_path=None):
    file_path,file_name = os.path.split(file)
    src_img,reg_ai_ctrs = xnet_predict_file(model=model, file=file, model_input_img_size=img_size, predict_area_num=2,
                                       min_area=0.001)
    
    src_img_w = src_img.shape[1]
    src_img_h = src_img.shape[0]
    
    black_mask_image = Image.new('RGB', (src_img_w, src_img_h), (0, 0, 0))
    black_mask_image = np.array(black_mask_image)
    
    last_ai_mask_image = black_mask_image.copy()
    last_ai_area = 0
    
#     for item in reg_ai_ctrs:
#         # 轮廓点稀疏化
#         sparse_ai_ctrs = sparse_ctrs([item], gap=points_gap)

#         # (78, 2)
#     #     print(sparse_ai_ctrs[0].shape)
#         sparse_ai_ctrs = np.expand_dims(sparse_ai_ctrs, axis=2)
#         # (78, 1, 2)

#         ai_mask_image = black_mask_image.copy()
#         cv2.fillPoly(ai_mask_image, sparse_ai_ctrs, (255, 255, 255))

#         # 识别得到的黑白图
#     #     save_img_file(os.path.join(result_path, file_name[:-4]+'_aimask'+file_name[-4:]), ai_mask_image)
#         ai_area = black_white_statistics(ai_mask_image, 'ai mask')
        
#         last_ai_area += ai_area
#         last_ai_mask_image += ai_mask_image
        
    cv2.drawContours(src_img, reg_ai_ctrs, -1, color=reg_color, thickness=2)
    save_img_file(os.path.join(output_folder, file_name), src_img)    
    
    
def process_path(imgs_path, labels_path, out_imgs_path, out_labels_path, img_size):
    files = os.listdir(imgs_path)
    for file in files:
        ext = file.split('.')[-1]
        if ext == 'csv':
            continue
            
        abs_file = os.path.join(imgs_path, file)
#         predict_file(abs_file)
#         continue
#         src_img = imread(abs_file)
        try:
            src_img = imread(abs_file)
        except:
            print('read error file: ', abs_file)
            return
        
#         print(src_img.shape)
        if src_img.shape[1] / src_img.shape[0] > 1.2 or src_img.shape[0] / src_img.shape[1] > 1.2:
            result, out_img, rect = process_img(src_img, img_size)
#             print(rect, 'kkkkkkkk')
        else:
#             continue
            result, out_img, rect = 1,src_img,None #[0,0,-1,-1]
#             result, out_img, rect = 1,src_img[: , : , : : -1],None #[0,0,-1,-1]
        if not result:
#             print('detect rect error file: ', abs_file)
            return

        if img_resize:
            _,out_img = resize_image(out_img, img_resize)
            
        # 处理label
        img_fn = os.path.join(labels_path, file[:])
        if not os.path.exists(img_fn):
            continue
            
        new_fn = os.path.join(out_imgs_path, file)
#         cv2.imencode('.png', out_img[: , : , : : -1])[1].tofile(new_fn)
        cv2.imencode('.png', out_img)[1].tofile(new_fn)
        

        img = np.array(Image.open(img_fn))
        if rect:
            img = img[rect[1]:rect[1]+rect[3], rect[0]:rect[0]+rect[2]]

        if img_resize:
            _,img = resize_image(img, img_resize)
        
        new_fn = os.path.join(out_labels_path, file)
        img = Image.fromarray(img)
        img.save(new_fn)
    
    
# def process_files(path, target_dir, img_size):
#     img_fn = os.path.join(path,'img.png')
#     try:
#         src_img = imread(img_fn)
#     except:
#         print('read error file: ', img_fn)
#         return
    
#     result, out_img, rect = process_img(src_img, img_size)
#     if not result:
#         print('detect rect error file: ', img_fn)
#         return
    
#     if img_resize:
#         print(out_img.shape)
#         _,out_img = resize_image(out_img, img_resize)
            
# #     fpath,fname = os.path.split(file)
#     new_fn = os.path.join(target_dir, 'img_crop.png')
#     cv2.imencode('.png', out_img[: , : , : : -1])[1].tofile(new_fn)
        
        
#     img_fn = os.path.join(path,'label.png')
# #     img = Image.open(img_fn)
    
#     img = np.array(Image.open(img_fn))
#     img = img[rect[1]:rect[1]+rect[3], rect[0]:rect[0]+rect[2]]
# #     print(img.shape,'ttt')

#     if img_resize:
#         _,img = resize_image(img, img_resize)

#     img = Image.fromarray(img, mode='P')
#     colormap = label_colormap(255)
#     img.putpalette((colormap * 255).astype(np.uint8).flatten())

        
#     new_fn = os.path.join(target_dir, 'label_crop.png')
#     img.save(new_fn)

# %%
def predict_img(img_path, output_folder, test_label_path=None):
    file_path, file_name = os.path.split(img_path)
    src_img = imread(img_path)
    if src_img.shape[1] / src_img.shape[0] > 1.2 or src_img.shape[0] / src_img.shape[1] > 1.2:
        result, out_img, rect = process_img(src_img, img_size)
#       print(rect, 'kkkkkkkk')
    else:
#       continue
        result, out_img, rect = 1, src_img, None #[0,0,-1,-1]
#       result, out_img, rect = 1, src_img[: , : , : : -1], None #[0,0,-1,-1]
    if not result:
#print('detect rect error file: ', abs_file)
        return

    if img_resize:
        _, out_img = resize_image(out_img, img_resize)
            
    out_img_path = os.path.join(output_folder, file_name)
#cv2.imencode('.png', out_img[: , : , : : -1])[1].tofile(new_fn)
    cv2.imencode('.png', out_img)[1].tofile(out_img_path)

# %%
in_path = r'data\input\imgs\3450'
out_path = in_path + '_out'
os.makedirs(out_path, exist_ok=True)

subs = os.listdir(in_path)
for sub in subs:
    if 'mask' in sub:
        imgs_path = os.path.join(in_path, sub[:-5])
        labels_path = os.path.join(in_path, sub)

        out_imgs_path = os.path.join(out_path, 'images')
        out_labels_path = os.path.join(out_path, 'labels')
        if not os.path.exists(out_imgs_path):
            os.makedirs(out_imgs_path, exist_ok=True)
        if not os.path.exists(out_labels_path):
            os.makedirs(out_labels_path, exist_ok=True)

        process_path(imgs_path, labels_path, out_imgs_path, out_labels_path, img_size)
# Out:
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step

# %%
predict_img(r'data\input\imgs\3450\1.jpg', r'data\input\imgs\3450_crop')
# Out:
# 1/1 [==============================] - 1s 835ms/step
