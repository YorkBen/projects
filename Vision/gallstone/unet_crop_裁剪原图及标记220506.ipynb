# %% [markdown]
# # Unet模型裁剪labelme生成的图片

# %%
import os
import sys
import cv2
import shutil
import numpy as np
from PIL import Image
from imageio import imread,imwrite

sys.path.insert(0, 'trainer')

from mbsh.core.unet.data import *
from mbsh.core.unet_pp.segmentation_models import Unet, Xnet
# from mbsh.core.images import fetch_all_files, split_video
from mbsh.core.xnet import mini_unet_model,xnet_predict_file
# Out:
# 2022-05-09 15:51:13,329 - INFO - __init__.py - init_logger - 58 - ini  logger file D:\projects\znyx-trainer\logs\kernel-257fbcdf-02a6-4846-abaf-b21ec0cab45a.log
# use temp dir:d:\znyx\temp
# Using TensorFlow backend.
# 2022-05-09 15:51:16,085 - DEBUG - __init__.py - wrapper - 241 - (private) matplotlib data path: C:\ProgramData\Anaconda3\envs\tf1\lib\site-packages\matplotlib\mpl-data
# 2022-05-09 15:51:16,086 - DEBUG - __init__.py - wrapper - 241 - matplotlib data path: C:\ProgramData\Anaconda3\envs\tf1\lib\site-packages\matplotlib\mpl-data
# 2022-05-09 15:51:16,091 - DEBUG - __init__.py - wrapper - 241 - CONFIGDIR=C:\Users\Administrator\.matplotlib
# 2022-05-09 15:51:16,094 - DEBUG - __init__.py - <module> - 1480 - matplotlib version 3.3.4
# 2022-05-09 15:51:16,094 - DEBUG - __init__.py - <module> - 1481 - interactive is False
# 2022-05-09 15:51:16,095 - DEBUG - __init__.py - <module> - 1482 - platform is win32
# 2022-05-09 15:51:16,096 - DEBUG - __init__.py - <module> - 1483 - loaded modules: ['builtins', 'sys', '_frozen_importlib', '_imp', '_warnings', '_thread', '_weakref', '_frozen_importlib_external', '_io', 'marshal', 'nt', 'winreg', 'zipimport', 'encodings', 'codecs', '_codecs', 'encodings.aliases', 'encodings.utf_8', '_signal', '__main__', 'encodings.latin_1', 'io', 'abc', '_weakrefset', '_bootlocale', '_locale', 'encodings.cp65001', 'functools', '_functools', 'collections', '_collections_abc', 'operator', '_operator', 'keyword', 'heapq', '_heapq', 'itertools', 'reprlib', '_collections', 'types', 'collections.abc', 'weakref', 'site', 'os', 'errno', 'stat', '_stat', 'ntpath', 'genericpath', 'os.path', '_sitebuiltins', 'sysconfig', 'importlib', 'importlib._bootstrap', 'importlib._bootstrap_external', 'warnings', 'importlib.util', 'importlib.abc', 'importlib.machinery', 'contextlib', 'mpl_toolkits', 'google', 'pywin32_bootstrap', 'pywin32_system32', 'runpy', 'pkgutil', 'ipykernel', 'ipykernel._version', 'ipykernel.connect', 'json', 'json.decoder', 're', 'enum', 'sre_compile', '_sre', 'sre_parse', 'sre_constants', 'copyreg', 'json.scanner', '_json', 'json.encoder', 'subprocess', 'time', 'signal', 'threading', 'traceback', 'linecache', 'tokenize', 'token', 'msvcrt', '_winapi', 'IPython', 'IPython.core', 'IPython.core.getipython', 'IPython.core.release', 'IPython.core.application', 'atexit', 'copy', 'glob', 'fnmatch', 'posixpath', 'logging', 'string', '_string', 'shutil', 'zlib', 'bz2', '_compression', '_bz2', 'lzma', '_lzma', 'traitlets', 'traitlets.traitlets', 'inspect', 'ast', '_ast', 'dis', 'opcode', '_opcode', 'six', '__future__', 'struct', '_struct', 'traitlets.utils', 'traitlets.utils.getargspec', 'traitlets.utils.importstring', 'ipython_genutils', 'ipython_genutils._version', 'ipython_genutils.py3compat', 'ipython_genutils.encoding', 'locale', 'platform', 'traitlets.utils.sentinel', 'traitlets.utils.bunch', 'traitlets._version', 'traitlets.config', 'traitlets.config.application', 'decorator', 'traitlets.config.configurable', 'traitlets.config.loader', 'argparse', 'textwrap', 'gettext', 'ipython_genutils.path', 'random', 'math', 'hashlib', '_hashlib', '_blake2', '_sha3', 'bisect', '_bisect', '_random', 'ipython_genutils.text', 'ipython_genutils.importstring', 'IPython.core.crashhandler', 'pprint', 'IPython.core.ultratb', 'pydoc', 'urllib', 'urllib.parse', 'IPython.core.debugger', 'bdb', 'IPython.utils', 'IPython.utils.PyColorize', 'IPython.utils.coloransi', 'IPython.utils.ipstruct', 'IPython.utils.colorable', 'pygments', 'IPython.utils.py3compat', 'IPython.utils.encoding', 'IPython.core.excolors', 'IPython.testing', 'IPython.testing.skipdoctest', 'pdb', 'cmd', 'code', 'codeop', 'IPython.core.display_trap', 'IPython.utils.path', 'IPython.utils.process', 'IPython.utils._process_win32', 'ctypes', '_ctypes', 'ctypes._endian', 'ctypes.wintypes', 'IPython.utils._process_common', 'shlex', 'IPython.utils.decorators', 'IPython.utils.data', 'IPython.utils.terminal', 'IPython.utils.sysinfo', 'IPython.utils._sysinfo', 'IPython.core.profiledir', 'IPython.paths', 'tempfile', 'IPython.utils.importstring', 'IPython.terminal', 'IPython.terminal.embed', 'IPython.core.compilerop', 'IPython.core.magic_arguments', 'IPython.core.error', 'IPython.utils.text', 'pathlib', 'IPython.core.magic', 'getopt', 'IPython.core.oinspect', 'typing', 'typing.io', 'typing.re', 'IPython.core.page', 'IPython.core.display', 'binascii', 'mimetypes', 'IPython.lib', 'IPython.lib.security', 'getpass', 'IPython.lib.pretty', 'datetime', '_datetime', 'IPython.utils.openpy', 'IPython.utils.dir2', 'IPython.utils.wildcard', 'pygments.lexers', 'pygments.lexers._mapping', 'pygments.modeline', 'pygments.plugin', 'pygments.util', 'pygments.lexers.python', 'pygments.lexer', 'pygments.filter', 'pygments.filters', 'pygments.token', 'pygments.regexopt', 'pygments.unistring', 'pygments.formatters', 'pygments.formatters._mapping', 'pygments.formatters.html', 'pygments.formatter', 'pygmen ...
# 2022-05-09 15:51:16,205 - DEBUG - __init__.py - wrapper - 241 - CACHEDIR=C:\Users\Administrator\.matplotlib
# 2022-05-09 15:51:16,208 - DEBUG - font_manager.py - <module> - 1436 - Using fontManager instance from C:\Users\Administrator\.matplotlib\fontlist-v330.json
# 2022-05-09 15:51:16,921 - DEBUG - pyplot.py - switch_backend - 290 - Loaded backend module://ipykernel.pylab.backend_inline version unknown.
# 2022-05-09 15:51:16,925 - DEBUG - pyplot.py - switch_backend - 290 - Loaded backend module://ipykernel.pylab.backend_inline version unknown.
# 2022-05-09 15:51:17,452 - WARNING - module_wrapper.py - _tfmw_add_deprecation_warning - 139 - From trainer\mbsh\core\yolo3\model.py:17: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# 2022-05-09 15:51:17,452 - WARNING - module_wrapper.py - _tfmw_add_deprecation_warning - 139 - From trainer\mbsh\core\yolo3\model.py:17: The name tf.GPUOptions is deprecated. Please use tf.compat.v1.GPUOptions instead.
#
# 2022-05-09 15:51:17,453 - WARNING - module_wrapper.py - _tfmw_add_deprecation_warning - 139 - From trainer\mbsh\core\yolo3\model.py:18: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2022-05-09 15:51:25,858 - DEBUG - font_manager.py - _findfont_cached - 1334 - findfont: Matching sans\-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=10.0.
# 2022-05-09 15:51:25,859 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'DejaVu Sans' (DejaVuSans-Bold.ttf) normal normal 700 normal>) = 0.33499999999999996
# 2022-05-09 15:51:25,860 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'STIXGeneral' (STIXGeneralBolIta.ttf) italic normal 700 normal>) = 11.335
# 2022-05-09 15:51:25,861 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'DejaVu Sans' (DejaVuSans-Oblique.ttf) oblique normal 400 normal>) = 1.05
# 2022-05-09 15:51:25,861 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'STIXNonUnicode' (STIXNonUniBol.ttf) normal normal 700 normal>) = 10.335
# 2022-05-09 15:51:25,862 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'cmr10' (cmr10.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,862 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'STIXGeneral' (STIXGeneral.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,863 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'cmss10' (cmss10.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,864 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'DejaVu Serif' (DejaVuSerif-Bold.ttf) normal normal 700 normal>) = 10.335
# 2022-05-09 15:51:25,864 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'STIXNonUnicode' (STIXNonUniBolIta.ttf) italic normal 700 normal>) = 11.335
# 2022-05-09 15:51:25,865 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'cmtt10' (cmtt10.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,865 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'STIXGeneral' (STIXGeneralItalic.ttf) italic normal 400 normal>) = 11.05
# 2022-05-09 15:51:25,866 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'DejaVu Serif Display' (DejaVuSerifDisplay.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,866 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'DejaVu Sans Mono' (DejaVuSansMono.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,867 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'DejaVu Sans Mono' (DejaVuSansMono-Bold.ttf) normal normal 700 normal>) = 10.335
# 2022-05-09 15:51:25,868 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'DejaVu Sans Mono' (DejaVuSansMono-BoldOblique.ttf) oblique normal 700 normal>) = 11.335
# 2022-05-09 15:51:25,868 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'STIXSizeThreeSym' (STIXSizThreeSymBol.ttf) normal normal 700 normal>) = 10.335
# 2022-05-09 15:51:25,869 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'STIXGeneral' (STIXGeneralBol.ttf) normal normal 700 normal>) = 10.335
# 2022-05-09 15:51:25,869 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'DejaVu Serif' (DejaVuSerif-Italic.ttf) italic normal 400 normal>) = 11.05
# 2022-05-09 15:51:25,870 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'cmex10' (cmex10.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,870 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'DejaVu Sans' (DejaVuSans-BoldOblique.ttf) oblique normal 700 normal>) = 1.335
# 2022-05-09 15:51:25,871 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'DejaVu Sans Display' (DejaVuSansDisplay.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,871 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'STIXSizeFourSym' (STIXSizFourSymReg.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,872 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'STIXSizeFourSym' (STIXSizFourSymBol.ttf) normal normal 700 normal>) = 10.335
# 2022-05-09 15:51:25,872 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'DejaVu Sans' (DejaVuSans.ttf) normal normal 400 normal>) = 0.05
# 2022-05-09 15:51:25,873 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'cmsy10' (cmsy10.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,873 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'cmb10' (cmb10.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,874 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'DejaVu Sans Mono' (DejaVuSansMono-Oblique.ttf) oblique normal 400 normal>) = 11.05
# 2022-05-09 15:51:25,874 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'DejaVu Serif' (DejaVuSerif.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,875 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'STIXSizeFiveSym' (STIXSizFiveSymReg.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,875 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'STIXSizeTwoSym' (STIXSizTwoSymReg.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,876 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'cmmi10' (cmmi10.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,876 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'STIXSizeOneSym' (STIXSizOneSymBol.ttf) normal normal 700 normal>) = 10.335
# 2022-05-09 15:51:25,877 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'STIXSizeOneSym' (STIXSizOneSymReg.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,877 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'DejaVu Serif' (DejaVuSerif-BoldItalic.ttf) italic normal 700 normal>) = 11.335
# 2022-05-09 15:51:25,878 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'STIXNonUnicode' (STIXNonUniIta.ttf) italic normal 400 normal>) = 11.05
# 2022-05-09 15:51:25,878 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'STIXSizeTwoSym' (STIXSizTwoSymBol.ttf) normal normal 700 normal>) = 10.335
# 2022-05-09 15:51:25,879 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'STIXNonUnicode' (STIXNonUni.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,879 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'STIXSizeThreeSym' (STIXSizThreeSymReg.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,880 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Bookman Old Style' (BOOKOSBI.TTF) italic normal 600 normal>) = 11.24
# 2022-05-09 15:51:25,880 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Book Antiqua' (ANTQUAI.TTF) italic normal 400 normal>) = 11.05
# 2022-05-09 15:51:25,881 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Candara' (Candarali.ttf) italic normal 400 normal>) = 11.05
# 2022-05-09 15:51:25,881 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Nirmala UI' (Nirmala.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,882 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Arial' (ariali.ttf) italic normal 400 normal>) = 7.413636363636363
# 2022-05-09 15:51:25,882 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'MS Reference Sans Serif' (REFSAN.TTF) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,883 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'STLiti' (STLITI.TTF) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,883 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Century' (CENTURY.TTF) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,884 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Corbel' (corbeli.ttf) italic normal 400 normal>) = 11.05
# 2022-05-09 15:51:25,884 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Segoe UI' (segoeuib.ttf) normal normal 700 normal>) = 10.335
# 2022-05-09 15:51:25,885 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Tahoma' (tahoma.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,886 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Sylfaen' (sylfaen.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,886 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'STHupo' (STHUPO.TTF) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,887 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Calibri' (calibrii.ttf) italic normal 400 normal>) = 11.05
# 2022-05-09 15:51:25,887 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Microsoft Sans Serif' (micross.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,888 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'SimSun-ExtB' (simsunb.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,888 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Microsoft JhengHei' (msjhbd.ttc) normal normal 700 normal>) = 10.335
# 2022-05-09 15:51:25,889 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Book Antiqua' (ANTQUABI.TTF) italic normal 700 normal>) = 11.335
# 2022-05-09 15:51:25,889 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Malgun Gothic' (malgun.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,890 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'FangSong' (simfang.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,890 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Nirmala UI' (NirmalaB.ttf) normal normal 700 normal>) = 10.335
# 2022-05-09 15:51:25,891 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Georgia' (georgiai.ttf) italic normal 400 normal>) = 11.05
# 2022-05-09 15:51:25,891 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Segoe UI Emoji' (seguiemj.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,892 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Javanese Text' (javatext.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,892 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Verdana' (verdanaz.ttf) italic normal 700 normal>) = 4.971363636363637
# 2022-05-09 15:51:25,893 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Segoe UI Historic' (seguihis.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,893 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Dubai' (DUBAI-REGULAR.TTF) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,894 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Candara' (Candara.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,894 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Verdana' (verdana.ttf) normal normal 400 normal>) = 3.6863636363636365
# 2022-05-09 15:51:25,895 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Microsoft PhagsPa' (phagspab.ttf) normal normal 700 normal>) = 10.335
# 2022-05-09 15:51:25,895 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Microsoft YaHei' (msyh.ttc) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,896 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Segoe Print' (segoepr.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,896 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Dubai' (DUBAI-BOLD.TTF) normal normal 700 normal>) = 10.335
# 2022-05-09 15:51:25,897 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Corbel' (corbelb.ttf) normal normal 700 normal>) = 10.335
# 2022-05-09 15:51:25,897 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Garamond' (GARAIT.TTF) italic normal 400 normal>) = 11.05
# 2022-05-09 15:51:25,898 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Corbel' (corbeli.ttf) italic normal 400 normal>) = 11.05
# 2022-05-09 15:51:25,898 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Microsoft JhengHei' (msjh.ttc) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,899 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Palatino Linotype' (palabi.ttf) italic normal 700 normal>) = 11.335
# 2022-05-09 15:51:25,899 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Verdana' (verdanaz.ttf) italic normal 700 normal>) = 4.971363636363637
# 2022-05-09 15:51:25,900 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Century Gothic' (GOTHICI.TTF) italic normal 400 normal>) = 11.05
# 2022-05-09 15:51:25,900 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Verdana' (verdanai.ttf) italic normal 400 normal>) = 4.6863636363636365
# 2022-05-09 15:51:25,901 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'DengXian' (Deng.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,901 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Calibri' (calibriz.ttf) italic normal 700 normal>) = 11.335
# 2022-05-09 15:51:25,902 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'MS Gothic' (msgothic.ttc) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,902 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Wingdings' (wingding.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,903 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Garamond' (GARABD.TTF) normal normal 700 normal>) = 10.335
# 2022-05-09 15:51:25,903 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Segoe UI' (seguisbi.ttf) italic normal 600 normal>) = 11.24
# 2022-05-09 15:51:25,904 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Ebrima' (ebrimabd.ttf) normal normal 700 normal>) = 10.335
# 2022-05-09 15:51:25,904 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Gadugi' (gadugib.ttf) normal normal 700 normal>) = 10.335
# 2022-05-09 15:51:25,905 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Candara' (Candaraz.ttf) italic normal 700 normal>) = 11.335
# 2022-05-09 15:51:25,905 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'LiSu' (SIMLI.TTF) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,906 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'SimHei' (simhei.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,906 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'DengXian' (Dengl.ttf) normal normal 300 normal>) = 10.145
# 2022-05-09 15:51:25,907 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Consolas' (consolab.ttf) normal normal 700 normal>) = 10.335
# 2022-05-09 15:51:25,907 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'MingLiU-ExtB' (mingliub.ttc) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,908 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'STHupo' (STHUPO.TTF) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,908 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Segoe Script' (segoesc.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,909 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Century Gothic' (GOTHICI.TTF) italic normal 400 normal>) = 11.05
# 2022-05-09 15:51:25,909 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Square721 BT' (TT0246M_.TTF) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,909 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Segoe UI' (seguisbi.ttf) italic normal 600 normal>) = 11.24
# 2022-05-09 15:51:25,910 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'STXingkai' (STXINGKA.TTF) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,911 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Trebuchet MS' (trebucit.ttf) italic normal 400 normal>) = 11.05
# 2022-05-09 15:51:25,911 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Ebrima' (ebrima.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,912 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Trebuchet MS' (trebucbd.ttf) normal normal 700 normal>) = 10.335
# 2022-05-09 15:51:25,912 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Segoe UI' (seguibli.ttf) italic normal 900 normal>) = 11.525
# 2022-05-09 15:51:25,913 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Century Gothic' (GOTHICB.TTF) normal normal 700 normal>) = 10.335
# 2022-05-09 15:51:25,913 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'LiSu' (SIMLI.TTF) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,914 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Sitka Small' (SitkaI.ttc) italic normal 400 normal>) = 11.05
# 2022-05-09 15:51:25,914 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Consolas' (consolab.ttf) normal normal 700 normal>) = 10.335
# 2022-05-09 15:51:25,915 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Segoe UI' (seguibli.ttf) italic normal 900 normal>) = 11.525
# 2022-05-09 15:51:25,915 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Corbel' (corbell.ttf) normal normal 300 normal>) = 10.145
# 2022-05-09 15:51:25,916 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Century Gothic' (GOTHICBI.TTF) italic normal 700 normal>) = 11.335
# 2022-05-09 15:51:25,916 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Microsoft PhagsPa' (phagspa.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,917 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Candara' (Candarab.ttf) normal normal 700 normal>) = 10.335
# 2022-05-09 15:51:25,917 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'SimSun-ExtB' (simsunb.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,918 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Yu Gothic' (YuGothM.ttc) normal normal 500 normal>) = 10.145
# 2022-05-09 15:51:25,918 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Comic Sans MS' (comicbd.ttf) normal normal 700 normal>) = 10.335
# 2022-05-09 15:51:25,919 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Cambria' (cambriab.ttf) normal normal 700 normal>) = 10.335
# 2022-05-09 15:51:25,919 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Book Antiqua' (ANTQUABI.TTF) italic normal 700 normal>) = 11.335
# 2022-05-09 15:51:25,919 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'SimHei' (simhei.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,920 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Segoe UI' (segoeuil.ttf) normal normal 300 normal>) = 10.145
# 2022-05-09 15:51:25,920 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Arial' (ariblk.ttf) normal normal 900 normal>) = 6.888636363636364
# 2022-05-09 15:51:25,921 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'STXinwei' (STXINWEI.TTF) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,921 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Corbel' (corbel.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,922 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Candara' (Candarali.ttf) italic normal 400 normal>) = 11.05
# 2022-05-09 15:51:25,922 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Cambria' (cambriab.ttf) normal normal 700 normal>) = 10.335
# 2022-05-09 15:51:25,923 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Leelawadee UI' (LeelaUIb.ttf) normal normal 700 normal>) = 10.335
# 2022-05-09 15:51:25,923 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'MV Boli' (mvboli.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,924 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Calibri' (calibriz.ttf) italic normal 700 normal>) = 11.335
# 2022-05-09 15:51:25,924 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Arial' (arial.ttf) normal normal 400 normal>) = 6.413636363636363
# 2022-05-09 15:51:25,925 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Dubai' (DUBAI-LIGHT.TTF) normal normal 300 normal>) = 10.145
# 2022-05-09 15:51:25,925 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Microsoft JhengHei' (msjhbd.ttc) normal normal 700 normal>) = 10.335
# 2022-05-09 15:51:25,926 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Javanese Text' (javatext.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,926 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Ink Free' (Inkfree.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,927 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Palatino Linotype' (palabi.ttf) italic normal 700 normal>) = 11.335
# 2022-05-09 15:51:25,927 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'YouYuan' (SIMYOU.TTF) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,928 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Segoe UI' (segoeui.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,928 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Bookman Old Style' (BOOKOSI.TTF) italic normal 300 normal>) = 11.145
# 2022-05-09 15:51:25,929 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Yu Gothic' (YuGothB.ttc) normal normal 700 normal>) = 10.335
# 2022-05-09 15:51:25,930 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Bookman Old Style' (BOOKOSI.TTF) italic normal 300 normal>) = 11.145
# 2022-05-09 15:51:25,930 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'STKaiti' (STKAITI.TTF) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,931 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Microsoft PhagsPa' (phagspab.ttf) normal normal 700 normal>) = 10.335
# 2022-05-09 15:51:25,931 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Segoe Script' (segoescb.ttf) normal normal 700 normal>) = 10.335
# 2022-05-09 15:51:25,932 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Segoe UI' (segoeuil.ttf) normal normal 300 normal>) = 10.145
# 2022-05-09 15:51:25,932 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'STKaiti' (STKAITI.TTF) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,933 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Gabriola' (Gabriola.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,933 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Courier New' (cour.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,934 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Arial' (arialbd.ttf) normal normal 700 normal>) = 6.698636363636363
# 2022-05-09 15:51:25,934 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Monotype Corsiva' (MTCORSVA.TTF) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,935 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Candara' (Candaraz.ttf) italic normal 700 normal>) = 11.335
# 2022-05-09 15:51:25,935 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Constantia' (constan.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,936 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Comic Sans MS' (comic.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,936 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Malgun Gothic' (malgunsl.ttf) normal normal 300 normal>) = 10.145
# 2022-05-09 15:51:25,937 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Microsoft New Tai Lue' (ntailu.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,937 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Yu Gothic' (YuGothM.ttc) normal normal 500 normal>) = 10.145
# 2022-05-09 15:51:25,938 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Adobe Devanagari' (AdobeDevanagari-Bold.otf) normal normal 700 normal>) = 10.335
# 2022-05-09 15:51:25,938 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Arial' (ARIALNB.TTF) normal normal 700 condensed>) = 6.8986363636363635
# 2022-05-09 15:51:25,939 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Microsoft YaHei' (msyhbd.ttc) normal normal 700 normal>) = 10.335
# 2022-05-09 15:51:25,939 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Sitka Small' (SitkaI.ttc) italic normal 400 normal>) = 11.05
# 2022-05-09 15:51:25,940 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Myanmar Text' (mmrtextb.ttf) normal normal 700 normal>) = 10.335
# 2022-05-09 15:51:25,940 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Arial' (ARIALNBI.TTF) italic normal 700 condensed>) = 7.8986363636363635
# 2022-05-09 15:51:25,941 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Times New Roman' (timesi.ttf) italic normal 400 normal>) = 11.05
# 2022-05-09 15:51:25,941 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Microsoft New Tai Lue' (ntailu.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,942 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Verdana' (verdana.ttf) normal normal 400 normal>) = 3.6863636363636365
# 2022-05-09 15:51:25,942 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'STFangsong' (STFANGSO.TTF) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,943 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Palatino Linotype' (palai.ttf) italic normal 400 normal>) = 11.05
# 2022-05-09 15:51:25,943 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Adobe Devanagari' (AdobeDevanagari-Italic.otf) italic normal 400 normal>) = 11.05
# 2022-05-09 15:51:25,944 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Garamond' (GARA.TTF) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,944 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Microsoft JhengHei' (msjh.ttc) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,945 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Lucida Sans Unicode' (l_10646.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,945 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Nirmala UI' (NirmalaB.ttf) normal normal 700 normal>) = 10.335
# 2022-05-09 15:51:25,946 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Palatino Linotype' (palab.ttf) normal normal 700 normal>) = 10.335
# 2022-05-09 15:51:25,946 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'MT Extra' (MTEXTRA.TTF) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,947 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Microsoft PhagsPa' (phagspa.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,948 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Lucida Console' (lucon.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,948 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Sitka Small' (SitkaB.ttc) normal normal 700 normal>) = 10.335
# 2022-05-09 15:51:25,949 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Verdana' (verdanab.ttf) normal normal 700 normal>) = 3.9713636363636367
# 2022-05-09 15:51:25,949 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Corbel' (corbelz.ttf) italic normal 700 normal>) = 11.335
# 2022-05-09 15:51:25,950 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Microsoft YaHei' (msyhl.ttc) normal normal 290 normal>) = 10.1545
# 2022-05-09 15:51:25,951 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Cambria' (cambriaz.ttf) italic normal 700 normal>) = 11.335
# 2022-05-09 15:51:25,951 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Palatino Linotype' (pala.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,952 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Georgia' (georgia.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,952 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Segoe UI' (seguisb.ttf) normal normal 600 normal>) = 10.24
# 2022-05-09 15:51:25,953 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Arial' (ariali.ttf) italic normal 400 normal>) = 7.413636363636363
# 2022-05-09 15:51:25,953 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Segoe UI' (segoeuii.ttf) italic normal 400 normal>) = 11.05
# 2022-05-09 15:51:25,954 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Cambria' (cambriai.ttf) italic normal 400 normal>) = 11.05
# 2022-05-09 15:51:25,954 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Gadugi' (gadugi.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,955 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Georgia' (georgiai.ttf) italic normal 400 normal>) = 11.05
# 2022-05-09 15:51:25,955 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Microsoft New Tai Lue' (ntailub.ttf) normal normal 700 normal>) = 10.335
# 2022-05-09 15:51:25,956 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Tahoma' (tahoma.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,956 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Sylfaen' (sylfaen.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,957 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Cambria' (cambriai.ttf) italic normal 400 normal>) = 11.05
# 2022-05-09 15:51:25,958 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Nirmala UI' (Nirmala.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,958 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Candara' (Candaral.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,958 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Myanmar Text' (mmrtext.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,959 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'STXihei' (STXIHEI.TTF) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,960 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Garamond' (GARA.TTF) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,960 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Century Gothic' (GOTHICBI.TTF) italic normal 700 normal>) = 11.335
# 2022-05-09 15:51:25,961 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Nirmala UI' (NirmalaS.ttf) normal normal 350 normal>) = 10.0975
# 2022-05-09 15:51:25,961 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Consolas' (consolaz.ttf) italic normal 700 normal>) = 11.335
# 2022-05-09 15:51:25,962 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Bookshelf Symbol 7' (BSSYM7.TTF) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,962 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Franklin Gothic Medium' (framd.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,963 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Lucida Console' (lucon.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,963 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Candara' (Candarai.ttf) italic normal 400 normal>) = 11.05
# 2022-05-09 15:51:25,964 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Garamond' (GARABD.TTF) normal normal 700 normal>) = 10.335
# 2022-05-09 15:51:25,964 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Sitka Small' (Sitka.ttc) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,964 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Arial' (ARIALNI.TTF) italic normal 400 condensed>) = 7.613636363636363
# 2022-05-09 15:51:25,965 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Segoe MDL2 Assets' (segmdl2.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,966 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Book Antiqua' (ANTQUAB.TTF) normal normal 700 normal>) = 10.335
# 2022-05-09 15:51:25,966 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Yu Gothic' (YuGothR.ttc) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,967 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Microsoft Tai Le' (taile.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,967 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Segoe Print' (segoepr.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,968 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Arial' (arialbd.ttf) normal normal 700 normal>) = 6.698636363636363
# 2022-05-09 15:51:25,968 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Segoe UI' (seguili.ttf) italic normal 300 normal>) = 11.145
# 2022-05-09 15:51:25,969 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Palatino Linotype' (palai.ttf) italic normal 400 normal>) = 11.05
# 2022-05-09 15:51:25,970 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Arial' (ARIALNBI.TTF) italic normal 700 condensed>) = 7.8986363636363635
# 2022-05-09 15:51:25,970 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Dubai' (DUBAI-MEDIUM.TTF) normal normal 500 normal>) = 10.145
# 2022-05-09 15:51:25,971 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Century Gothic' (GOTHIC.TTF) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,971 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Georgia' (georgiab.ttf) normal normal 700 normal>) = 10.335
# 2022-05-09 15:51:25,972 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Webdings' (webdings.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,972 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Times New Roman' (timesi.ttf) italic normal 400 normal>) = 11.05
# 2022-05-09 15:51:25,972 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Georgia' (georgiaz.ttf) italic normal 700 normal>) = 11.335
# 2022-05-09 15:51:25,973 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Bookman Old Style' (BOOKOSB.TTF) normal normal 600 normal>) = 10.24
# 2022-05-09 15:51:25,973 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Lucida Sans Unicode' (l_10646.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,974 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'FZYaoTi' (FZYTK.TTF) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,974 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'YouYuan' (SIMYOU.TTF) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,975 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Myanmar Text' (mmrtext.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,975 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Corbel' (corbelz.ttf) italic normal 700 normal>) = 11.335
# 2022-05-09 15:51:25,976 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Ebrima' (ebrimabd.ttf) normal normal 700 normal>) = 10.335
# 2022-05-09 15:51:25,976 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'STXinwei' (STXINWEI.TTF) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,977 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Segoe UI' (seguisb.ttf) normal normal 600 normal>) = 10.24
# 2022-05-09 15:51:25,977 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Ink Free' (Inkfree.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,978 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Myanmar Text' (mmrtextb.ttf) normal normal 700 normal>) = 10.335
# 2022-05-09 15:51:25,978 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Calibri' (calibril.ttf) normal normal 300 normal>) = 10.145
# 2022-05-09 15:51:25,979 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Marlett' (marlett.ttf) normal normal 500 normal>) = 10.145
# 2022-05-09 15:51:25,979 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'MS Reference Sans Serif' (REFSAN.TTF) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,980 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Trebuchet MS' (trebuc.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,981 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Calibri' (calibrili.ttf) italic normal 300 normal>) = 11.145
# 2022-05-09 15:51:25,981 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Georgia' (georgia.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,982 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Microsoft JhengHei' (msjhl.ttc) normal normal 290 normal>) = 10.1545
# 2022-05-09 15:51:25,982 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'SimSun' (simsun.ttc) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,983 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Comic Sans MS' (comic.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,984 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'DengXian' (Deng.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,984 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Verdana' (verdanai.ttf) italic normal 400 normal>) = 4.6863636363636365
# 2022-05-09 15:51:25,985 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Segoe MDL2 Assets' (segmdl2.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,985 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Arial' (arialbi.ttf) italic normal 700 normal>) = 7.698636363636363
# 2022-05-09 15:51:25,986 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Impact' (impact.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,986 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'STSong' (STSONG.TTF) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,987 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Segoe UI' (segoeuiz.ttf) italic normal 700 normal>) = 11.335
# 2022-05-09 15:51:25,987 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'MV Boli' (mvboli.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,988 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Wingdings 3' (WINGDNG3.TTF) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,988 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'MT Extra' (MTEXTRA.TTF) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:25,989 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Arial' (ARIALNI.TTF) italic normal 400 condensed>) = 7.613636363636363
# 2022-05-09 15:51:25,989 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Yu Gothic' (YuGothL.ttc) normal normal 300 normal>) = 10.145
# ...
# 2022-05-09 15:51:26,036 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Consolas' (consolaz.ttf) italic normal 700 normal>) = 11.335
# 2022-05-09 15:51:26,036 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Constantia' (constan.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:26,037 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Leelawadee UI' (LeelawUI.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:26,037 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Georgia' (georgiab.ttf) normal normal 700 normal>) = 10.335
# 2022-05-09 15:51:26,038 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Segoe Script' (segoescb.ttf) normal normal 700 normal>) = 10.335
# 2022-05-09 15:51:26,038 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'MS Gothic' (msgothic.ttc) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:26,039 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Segoe Script' (segoesc.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:26,039 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Century' (CENTURY.TTF) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:26,040 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Courier New' (couri.ttf) italic normal 400 normal>) = 11.05
# 2022-05-09 15:51:26,040 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Leelawadee UI' (LeelaUIb.ttf) normal normal 700 normal>) = 10.335
# 2022-05-09 15:51:26,041 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Arial' (ARIALN.TTF) normal normal 400 condensed>) = 6.613636363636363
# 2022-05-09 15:51:26,041 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Candara' (Candaral.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:26,042 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'FZYaoTi' (FZYTK.TTF) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:26,042 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'STSong' (STSONG.TTF) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:26,043 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'DengXian' (Dengb.ttf) normal normal 700 normal>) = 10.335
# 2022-05-09 15:51:26,043 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Franklin Gothic Medium' (framd.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:26,044 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Segoe UI' (seguisli.ttf) italic normal 350 normal>) = 11.0975
# 2022-05-09 15:51:26,044 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Dubai' (DUBAI-REGULAR.TTF) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:26,045 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Calibri' (calibri.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:26,045 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Gadugi' (gadugi.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:26,046 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Arial' (arial.ttf) normal normal 400 normal>) = 6.413636363636363
# 2022-05-09 15:51:26,047 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Corbel' (corbelb.ttf) normal normal 700 normal>) = 10.335
# 2022-05-09 15:51:26,047 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Microsoft Yi Baiti' (msyi.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:26,048 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Calibri' (calibrib.ttf) normal normal 700 normal>) = 10.335
# 2022-05-09 15:51:26,048 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Segoe UI Symbol' (seguisym.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:26,049 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Calibri' (calibril.ttf) normal normal 300 normal>) = 10.145
# 2022-05-09 15:51:26,050 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Arial' (ARIALN.TTF) normal normal 400 condensed>) = 6.613636363636363
# 2022-05-09 15:51:26,050 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Corbel' (corbelli.ttf) italic normal 300 normal>) = 11.145
# 2022-05-09 15:51:26,051 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Comic Sans MS' (comici.ttf) italic normal 400 normal>) = 11.05
# 2022-05-09 15:51:26,051 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'STFangsong' (STFANGSO.TTF) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:26,052 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Segoe UI' (segoeuisl.ttf) normal normal 350 normal>) = 10.0975
# 2022-05-09 15:51:26,052 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Trebuchet MS' (trebucbi.ttf) italic normal 700 normal>) = 11.335
# 2022-05-09 15:51:26,053 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'FZShuTi' (FZSTK.TTF) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:26,053 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Trebuchet MS' (trebucbi.ttf) italic normal 700 normal>) = 11.335
# 2022-05-09 15:51:26,053 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'MS Reference Specialty' (REFSPCL.TTF) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:26,054 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Sitka Small' (SitkaZ.ttc) italic normal 700 normal>) = 11.335
# 2022-05-09 15:51:26,054 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Wingdings 2' (WINGDNG2.TTF) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:26,055 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'STZhongsong' (STZHONGS.TTF) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:26,055 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Candara' (Candarai.ttf) italic normal 400 normal>) = 11.05
# 2022-05-09 15:51:26,056 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Bookman Old Style' (BOOKOS.TTF) normal normal 300 normal>) = 10.145
# 2022-05-09 15:51:26,056 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Comic Sans MS' (comici.ttf) italic normal 400 normal>) = 11.05
# 2022-05-09 15:51:26,057 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Times New Roman' (timesbi.ttf) italic normal 700 normal>) = 11.335
# 2022-05-09 15:51:26,057 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'HoloLens MDL2 Assets' (holomdl2.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:26,058 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Candara' (Candarab.ttf) normal normal 700 normal>) = 10.335
# 2022-05-09 15:51:26,058 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Yu Gothic' (YuGothB.ttc) normal normal 700 normal>) = 10.335
# 2022-05-09 15:51:26,059 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Arial' (arialbi.ttf) italic normal 700 normal>) = 7.698636363636363
# 2022-05-09 15:51:26,059 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Comic Sans MS' (comicbd.ttf) normal normal 700 normal>) = 10.335
# 2022-05-09 15:51:26,060 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Nirmala UI' (NirmalaS.ttf) normal normal 350 normal>) = 10.0975
# 2022-05-09 15:51:26,060 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Segoe UI' (seguisli.ttf) italic normal 350 normal>) = 11.0975
# 2022-05-09 15:51:26,061 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Malgun Gothic' (malgunbd.ttf) normal normal 700 normal>) = 10.335
# 2022-05-09 15:51:26,061 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Book Antiqua' (ANTQUAB.TTF) normal normal 700 normal>) = 10.335
# 2022-05-09 15:51:26,062 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Tahoma' (tahomabd.ttf) normal normal 700 normal>) = 10.335
# 2022-05-09 15:51:26,062 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Calibri' (calibrili.ttf) italic normal 300 normal>) = 11.145
# 2022-05-09 15:51:26,063 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Segoe UI Historic' (seguihis.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:26,063 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Trebuchet MS' (trebuc.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:26,064 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Webdings' (webdings.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:26,064 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Book Antiqua' (ANTQUAI.TTF) italic normal 400 normal>) = 11.05
# 2022-05-09 15:51:26,065 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Malgun Gothic' (malgunsl.ttf) normal normal 300 normal>) = 10.145
# 2022-05-09 15:51:26,065 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Microsoft Himalaya' (himalaya.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:26,066 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Impact' (impact.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:26,066 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Dubai' (DUBAI-LIGHT.TTF) normal normal 300 normal>) = 10.145
# 2022-05-09 15:51:26,067 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Segoe UI' (segoeuii.ttf) italic normal 400 normal>) = 11.05
# 2022-05-09 15:51:26,068 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Courier New' (courbd.ttf) normal normal 700 normal>) = 10.335
# 2022-05-09 15:51:26,068 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Dubai' (DUBAI-BOLD.TTF) normal normal 700 normal>) = 10.335
# 2022-05-09 15:51:26,068 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Palatino Linotype' (pala.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:26,069 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Consolas' (consola.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:26,069 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Times New Roman' (timesbi.ttf) italic normal 700 normal>) = 11.335
# 2022-05-09 15:51:26,070 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Malgun Gothic' (malgunbd.ttf) normal normal 700 normal>) = 10.335
# 2022-05-09 15:51:26,070 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Century Gothic' (GOTHIC.TTF) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:26,071 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'STCaiyun' (STCAIYUN.TTF) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:26,071 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Times New Roman' (times.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:26,072 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Arial' (ariblk.ttf) normal normal 900 normal>) = 6.888636363636364
# 2022-05-09 15:51:26,072 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Mongolian Baiti' (monbaiti.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:26,073 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Bookman Old Style' (BOOKOSBI.TTF) italic normal 600 normal>) = 11.24
# 2022-05-09 15:51:26,073 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Georgia' (georgiaz.ttf) italic normal 700 normal>) = 11.335
# 2022-05-09 15:51:26,074 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'FangSong' (simfang.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:26,074 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'STXingkai' (STXINGKA.TTF) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:26,074 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Bahnschrift' (bahnschrift.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:26,075 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'MS Reference Specialty' (REFSPCL.TTF) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:26,075 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Bahnschrift' (bahnschrift.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:26,076 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Calibri' (calibrii.ttf) italic normal 400 normal>) = 11.05
# 2022-05-09 15:51:26,076 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Segoe UI' (seguibl.ttf) normal normal 900 normal>) = 10.525
# 2022-05-09 15:51:26,077 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Tahoma' (tahomabd.ttf) normal normal 700 normal>) = 10.335
# 2022-05-09 15:51:26,078 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Sitka Small' (SitkaZ.ttc) italic normal 700 normal>) = 11.335
# 2022-05-09 15:51:26,078 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Times New Roman' (times.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:26,078 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Cambria' (cambriaz.ttf) italic normal 700 normal>) = 11.335
# 2022-05-09 15:51:26,079 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'KaiTi' (simkai.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:26,079 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Symbol' (symbol.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:26,080 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Verdana' (verdanab.ttf) normal normal 700 normal>) = 3.9713636363636367
# 2022-05-09 15:51:26,081 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Microsoft Tai Le' (taile.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:26,081 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Microsoft YaHei' (msyhbd.ttc) normal normal 700 normal>) = 10.335
# 2022-05-09 15:51:26,082 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Palatino Linotype' (palab.ttf) normal normal 700 normal>) = 10.335
# 2022-05-09 15:51:26,082 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Gadugi' (gadugib.ttf) normal normal 700 normal>) = 10.335
# 2022-05-09 15:51:26,083 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'Calibri' (calibri.ttf) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:26,084 - DEBUG - font_manager.py - _findfont_cached - 1346 - findfont: score(<Font 'ZWAdobeF' (ZWAdobeF.TTF) normal normal 400 normal>) = 10.05
# 2022-05-09 15:51:26,084 - DEBUG - font_manager.py - _findfont_cached - 1367 - findfont: Matching sans\-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=10.0 to DejaVu Sans ('C:\\ProgramData\\Anaconda3\\envs\\tf1\\lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\DejaVuSans.ttf') with score of 0.050000.

# %%
from mbsh.core.xnet import mini_unet_model,xnet_predict_file

# %%
os.environ["CUDA_DEVICE_ORDER"] ="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="-1"  
import tensorflow as tf
tf.test.is_gpu_available()
# Out:
# True

# %% [markdown]
# ## 模型配置

# %%
# model_path = r'H:\ai_data\img_crop\train1227\cache\X_ca_region_19-12-27_10_16_19-0.996.hdf5'
# model_path = r'H:\ai_data\img_crop\纵隔超声/cache\X_ca_region_21-05-12_10_21_14-0.995.hdf5'
model_path = r'D:\共享文件\X_ca_region_21-09-07_14_07_17-0.995.hdf5'

img_size = (512, 512)
input_size = img_size + (3,)
use_unet = False

# 视频图转换后图像大小
# 不改变尺寸则设置为None
img_resize = None #(512, 512)

# %% [markdown]
# ## 加载模型及参数

# %%
# 创建模型并加载
if use_unet:
#     model = unet(input_size=input_size)
    model = Unet(input_shape=input_size, backbone_name='resnet50', encoder_weights='imagenet', decoder_block_type='transpose')
else:
    model = Xnet(input_shape=input_size, backbone_name='resnet50', encoder_weights='imagenet', decoder_block_type='transpose')

model.load_weights(model_path)
# Out:
# 2022-05-09 09:23:48,520 - WARNING - module_wrapper.py - _tfmw_add_deprecation_warning - 139 - From C:\ProgramData\Anaconda3\envs\tf1\lib\site-packages\keras\backend\tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# 2022-05-09 09:23:48,528 - WARNING - module_wrapper.py - _tfmw_add_deprecation_warning - 139 - From C:\ProgramData\Anaconda3\envs\tf1\lib\site-packages\keras\backend\tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# 2022-05-09 09:23:48,529 - WARNING - module_wrapper.py - _tfmw_add_deprecation_warning - 139 - From C:\ProgramData\Anaconda3\envs\tf1\lib\site-packages\keras\backend\tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# 2022-05-09 09:23:48,535 - WARNING - module_wrapper.py - _tfmw_add_deprecation_warning - 139 - From C:\ProgramData\Anaconda3\envs\tf1\lib\site-packages\keras\backend\tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# 2022-05-09 09:23:48,535 - WARNING - module_wrapper.py - _tfmw_add_deprecation_warning - 139 - From C:\ProgramData\Anaconda3\envs\tf1\lib\site-packages\keras\backend\tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# 2022-05-09 09:23:48,543 - WARNING - module_wrapper.py - _tfmw_add_deprecation_warning - 139 - From C:\ProgramData\Anaconda3\envs\tf1\lib\site-packages\keras\backend\tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# 2022-05-09 09:23:48,552 - WARNING - module_wrapper.py - _tfmw_add_deprecation_warning - 139 - From C:\ProgramData\Anaconda3\envs\tf1\lib\site-packages\keras\backend\tensorflow_backend.py:2041: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# 2022-05-09 09:23:48,583 - WARNING - module_wrapper.py - _tfmw_add_deprecation_warning - 139 - From C:\ProgramData\Anaconda3\envs\tf1\lib\site-packages\keras\backend\tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# 2022-05-09 09:23:48,594 - WARNING - module_wrapper.py - _tfmw_add_deprecation_warning - 139 - From C:\ProgramData\Anaconda3\envs\tf1\lib\site-packages\keras\backend\tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# 2022-05-09 09:23:48,640 - WARNING - module_wrapper.py - _tfmw_add_deprecation_warning - 139 - From C:\ProgramData\Anaconda3\envs\tf1\lib\site-packages\keras\backend\tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %% [markdown]
# ## 图片处理函数

# %%
cv2.__version__
# Out:
# '4.5.3'

# %%
# 根据轮廓点列表计算轮廓面积
def areaCal(contour):
    area = 0
    for i in range(len(contour)):
        area += cv2.contourArea(contour[i])
    return area


def takeLength(elem):
    return areaCal([elem])

def resize_image(img, size):
    """
    resize 保持原图的长宽比
    """
    image = Image.fromarray(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
#     print(image.size,image.shape,type(image))
    iw, ih = image.size
    w, h = size
    scale = min(w / iw, h / ih)
    nw = int(iw * scale)
    nh = int(ih * scale)

    image = image.resize((nw, nh), Image.BICUBIC)
    new_image = Image.new('RGB', size, (0, 0, 0))
    new_image.paste(image, ((w - nw) // 2, (h - nh) // 2))
    img = np.array(new_image)
    return (scale, nw, nh), img[:, :, ::-1]

def process_img(src_img, img_size):
    src_img_bak = src_img.copy()
    src_h = src_img_bak.shape[0]
    src_w = src_img_bak.shape[1]

    new_w, new_h = img_size

    (scale, nw, nh), img = resize_image(src_img, img_size)

    # trans.resize把img从numpy.uint8类型转换为numpy.float64
    img = trans.resize(img, img_size)

    # reshape把img从(512, 512, 3)转换为(1, 512, 512, 3)
    img = np.reshape(img,(1,)+img.shape)

    # 模型识别图片, results为(1, 512, 512, 1)，是灰度图片
    results = model.predict(np.array(img),verbose=1)

    # gray_img是（512，512）的灰度图，元素类型numpy.float32
    gray_img = results[0][:,:,0]
    gray_img[np.where(gray_img <= 0.3)] = 0

    # heatmap转为灰度图
    bw_heatmap = np.uint8(255 * gray_img)
    bw_heatmap[bw_heatmap != 0] = 255
    if cv2.__version__[0] == '4':
        ai_ctrs, _ = cv2.findContours(bw_heatmap.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    else:
        _, ai_ctrs, _ = cv2.findContours(bw_heatmap.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    
    if len(ai_ctrs) == 0:
        print('len ai ctrs 000000000000')
        return False,src_img
        
#     print(ai_ctrs, 'ppppppp')
    ai_ctrs = list(ai_ctrs)
    ai_ctrs.sort(key=takeLength, reverse=True)
    

    x,y,w,h = cv2.boundingRect(ai_ctrs[0])

    # 映射到原图尺寸的坐标系  
    x = x - (new_w - nw) // 2
    y = y - (new_h - nh) // 2
    
    new_x = 0 if x < 0 else x
    new_y = 0 if y < 0 else y
    
    x1 = int(new_x / scale)
    y1 = int(new_y / scale)
    w1 = int(w / scale)
    h1 = int(h / scale)
    
    img_out = src_img_bak[y1:y1+h1, x1:x1+w1, :]
#     print(x1, y1, w1, h1, '3333333333')
    return True,img_out, (x1, y1, w1, h1)
#     return True,img_out[: , : , : : -1], (x1, y1, w1, h1)

def predict_file(file, test_label_path=None):
    file_path,file_name = os.path.split(file)
    src_img,reg_ai_ctrs = xnet_predict_file(model=model, file=file, model_input_img_size=img_size, predict_area_num=2,
                                       min_area=0.001)
    
    src_img_w = src_img.shape[1]
    src_img_h = src_img.shape[0]
    
    black_mask_image = Image.new('RGB', (src_img_w, src_img_h), (0, 0, 0))
    black_mask_image = np.array(black_mask_image)
    
    last_ai_mask_image = black_mask_image.copy()
    last_ai_area = 0
    
#     for item in reg_ai_ctrs:
#         # 轮廓点稀疏化
#         sparse_ai_ctrs = sparse_ctrs([item], gap=points_gap)

#         # (78, 2)
#     #     print(sparse_ai_ctrs[0].shape)
#         sparse_ai_ctrs = np.expand_dims(sparse_ai_ctrs, axis=2)
#         # (78, 1, 2)

#         ai_mask_image = black_mask_image.copy()
#         cv2.fillPoly(ai_mask_image, sparse_ai_ctrs, (255, 255, 255))

#         # 识别得到的黑白图
#     #     save_img_file(os.path.join(result_path, file_name[:-4]+'_aimask'+file_name[-4:]), ai_mask_image)
#         ai_area = black_white_statistics(ai_mask_image, 'ai mask')
        
#         last_ai_area += ai_area
#         last_ai_mask_image += ai_mask_image
        
    cv2.drawContours(src_img, reg_ai_ctrs, -1, color=reg_color, thickness=2)
    save_img_file(os.path.join(r'D:\项目资料\胆结石',file_name),src_img)    
    
    
def process_path(imgs_path, labels_path, out_imgs_path, out_labels_path, img_size):
    files = os.listdir(imgs_path)
    for file in files:
        ext = file.split('.')[-1]
        if ext == 'csv':
            continue
            
        abs_file = os.path.join(imgs_path, file)
#         predict_file(abs_file)
#         continue
        
        
        
#         src_img = imread(abs_file)
        try:
            src_img = imread(abs_file)
        except:
            print('read error file: ', abs_file)
            return
        
#         print(src_img.shape)
        if src_img.shape[1] / src_img.shape[0] > 1.2 or src_img.shape[0] / src_img.shape[1] > 1.2:
            result, out_img, rect = process_img(src_img, img_size)
#             print(rect, 'kkkkkkkk')
        else:
#             continue
            result, out_img, rect = 1,src_img,None #[0,0,-1,-1]
#             result, out_img, rect = 1,src_img[: , : , : : -1],None #[0,0,-1,-1]
        if not result:
#             print('detect rect error file: ', abs_file)
            return

        if img_resize:
            _,out_img = resize_image(out_img, img_resize)
            
        # 处理label
        img_fn = os.path.join(labels_path, file[:])   
        if not os.path.exists(img_fn):
            continue
            
        new_fn = os.path.join(out_imgs_path, file)
#         cv2.imencode('.png', out_img[: , : , : : -1])[1].tofile(new_fn)
        cv2.imencode('.png', out_img)[1].tofile(new_fn)
        

        img = np.array(Image.open(img_fn))
        if rect:
            img = img[rect[1]:rect[1]+rect[3], rect[0]:rect[0]+rect[2]]

        if img_resize:
            _,img = resize_image(img, img_resize)
        
        new_fn = os.path.join(out_labels_path, file)
        img = Image.fromarray(img)
        img.save(new_fn)
    
    
# def process_files(path, target_dir, img_size):
#     img_fn = os.path.join(path,'img.png')
#     try:
#         src_img = imread(img_fn)
#     except:
#         print('read error file: ', img_fn)
#         return
    
#     result, out_img, rect = process_img(src_img, img_size)
#     if not result:
#         print('detect rect error file: ', img_fn)
#         return
    
#     if img_resize:
#         print(out_img.shape)
#         _,out_img = resize_image(out_img, img_resize)
            
# #     fpath,fname = os.path.split(file)
#     new_fn = os.path.join(target_dir, 'img_crop.png')
#     cv2.imencode('.png', out_img[: , : , : : -1])[1].tofile(new_fn)
        
        
#     img_fn = os.path.join(path,'label.png')
# #     img = Image.open(img_fn)
    
#     img = np.array(Image.open(img_fn))
#     img = img[rect[1]:rect[1]+rect[3], rect[0]:rect[0]+rect[2]]
# #     print(img.shape,'ttt')

#     if img_resize:
#         _,img = resize_image(img, img_resize)

#     img = Image.fromarray(img, mode='P')
#     colormap = label_colormap(255)
#     img.putpalette((colormap * 255).astype(np.uint8).flatten())

        
#     new_fn = os.path.join(target_dir, 'label_crop.png')
#     img.save(new_fn)

# %%
in_path = r'D:\项目资料\胆结石\胆结石分割模型_test'
out_path = in_path + '_out'
os.makedirs(out_path, exist_ok=True)

subs = os.listdir(in_path)
for sub in subs:
    if 'mask' in sub:
        imgs_path = os.path.join(in_path, sub[:-5])
        labels_path = os.path.join(in_path, sub)

        out_imgs_path = os.path.join(out_path, 'images')
        out_labels_path = os.path.join(out_path, 'labels')
        if not os.path.exists(out_imgs_path):
            os.makedirs(out_imgs_path, exist_ok=True)
        if not os.path.exists(out_labels_path):
            os.makedirs(out_labels_path, exist_ok=True)

        process_path(imgs_path, labels_path, out_imgs_path, out_labels_path, img_size)
# Out:
# 1/1 [==============================] - 5s 5s/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
