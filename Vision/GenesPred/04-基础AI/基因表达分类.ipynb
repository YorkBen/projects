# %%
import pandas as pd

# %%
tcga_data = pd.read_csv(r"Z:\模型算法组\训练数据\zhangkuo\05基因预测\Deep处理\TCGA-colon-表达处理数据-counts.txt",sep='\t',index_col=0)

# %%
cluster = pd.read_csv(r"Z:\模型算法组\训练数据\zhangkuo\05基因预测\Deep处理\cluster_new.csv")
cluster
# Out:
#                id  group  type1  type2
# 0    TCGA-AU-6004  MSI-H      0      0
# 1    TCGA-CK-5913  MSI-H      0      0
# 2    TCGA-CK-5916  MSI-H      0      0
# 3    TCGA-AA-A01Q  MSI-H      0      0
# 4    TCGA-A6-5661  MSI-H      0      0
# ..            ...    ...    ...    ...
# 407  TCGA-AA-3666    MSS      1      1
# 408  TCGA-DM-A282    MSS      1      1
# 409  TCGA-F4-6805    MSS      1      1
# 410  TCGA-A6-2680    MSS      1      1
# 411  TCGA-DM-A28G    MSS      1      1
#
# [412 rows x 4 columns]

# %%
tcga_data_new = tcga_data.T

# %%
cluster['type1']
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 407    1
# 408    1
# 409    1
# 410    1
# 411    1
# Name: type1, Length: 412, dtype: int64

# %%
tcga_data_new['label1'] =  list(cluster['type1'])
tcga_data_new['label2'] =  list(cluster['type2'])

# %%
tcga_data_new.to_csv(r'Z:\模型算法组\训练数据\zhangkuo\05基因预测\Deep处理\TCGA-colon-counts.csv', index=False)

# %%
tcga_data_new
# Out:
# Ensembl_ID    ENSG00000000003.13  ENSG00000000005.5  ENSG00000000419.11  \
# TCGA-A6-2671           11.356452           3.584963           10.390169
# TCGA-A6-2672           10.925554           1.000000            9.250298
# TCGA-A6-2674           11.932953           2.700440           10.715533
# TCGA-A6-2675           13.225810           6.523562           10.862637
# TCGA-A6-2676           10.645658           0.000000            9.255029
# ...                          ...                ...                 ...
# TCGA-G4-6588           10.745674           0.000000           10.348728
# TCGA-G4-6625           12.886078           3.000000           11.783408
# TCGA-G4-6626           12.462247           4.392317           11.977995
# TCGA-G4-6627           12.813581           9.174926           11.222795
# TCGA-G4-6628           11.598052           3.000000           10.585901
#
# Ensembl_ID    ENSG00000000457.12  ENSG00000000460.15  ENSG00000000938.11  \
# ...

# %%
cluster.loc[cluster['group']=='MSS', 'type2'] = 1

# %%
cluster.to_csv(r'Z:\模型算法组\训练数据\zhangkuo\05基因预测\Deep处理\cluster_new.csv', index=False)

# %%
cluster[cluster.group=="MSI-H"]['type1']=0
cluster[cluster.group=="MSI-L"]['type1']=0
cluster[cluster.group=="MSS"]['type1']=1
# Out:
# C:\Users\admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
cluster
# Out:
#                id  group  type1  type2
# 0    TCGA-AU-6004  MSI-H      0      0
# 1    TCGA-CK-5913  MSI-H      0      0
# 2    TCGA-CK-5916  MSI-H      0      0
# 3    TCGA-AA-A01Q  MSI-H      0      0
# 4    TCGA-A6-5661  MSI-H      0      0
# ..            ...    ...    ...    ...
# 407  TCGA-AA-3666    MSS      0      0
# 408  TCGA-DM-A282    MSS      0      0
# 409  TCGA-F4-6805    MSS      0      0
# 410  TCGA-A6-2680    MSS      0      0
# 411  TCGA-DM-A28G    MSS      0      0
#
# [412 rows x 4 columns]

# %%
tcga_data
# Out:
#                    Ensembl_ID  TCGA-A6-2671  TCGA-A6-2672  TCGA-A6-2674  \
# 0          ENSG00000000003.13     11.356452     10.925554     11.932953
# 1           ENSG00000000005.5      3.584963      1.000000      2.700440
# 2          ENSG00000000419.11     10.390169      9.250298     10.715533
# 3          ENSG00000000457.12      7.741467      7.982994      9.846274
# 4          ENSG00000000460.15      8.375039      7.562242      9.103288
# ...                       ...           ...           ...           ...
# 60483            __no_feature     20.101968     20.552967     23.545143
# 60484             __ambiguous     20.498766     20.327576     21.506956
# 60485         __too_low_aQual      0.000000      0.000000      0.000000
# 60486           __not_aligned      0.000000      0.000000      0.000000
# 60487  __alignment_not_unique     23.793495     23.579436     25.545653
#
#        TCGA-A6-2675  TCGA-A6-2676  TCGA-A6-2677  TCGA-A6-2678  TCGA-A6-2679  \
# ...
