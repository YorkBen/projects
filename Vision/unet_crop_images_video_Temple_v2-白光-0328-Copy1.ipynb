# %% [markdown]
# # Unet模型裁剪图片/视频黑边模板

# %% [markdown]
# ### 对每张图进行Unet识别图片区域，去黑边

# %%
import os
import sys
import shutil

sys.path.insert(0, r'D:\projects\Vision\Lib\trainer')
from mbsh.core.unet_pp.segmentation_models import Unet, Xnet
from mbsh.core.images import fetch_all_files, split_video, read_img_file, save_img_file, resize_image
from mbsh.core.xnet import xnet_predict_img, draw_outline_rect

import cv2
# Out:
# 2022-05-23 09:55:20,881 - INFO - __init__.py - init_logger - 58 - ini  logger file D:\projects\Vision\Lib\logs\kernel-08a98475-69a0-422c-8fb5-6a45b69b0f87.log
# use temp dir:d:\znyx\temp
# 2022-05-23 09:55:22,663 - DEBUG - tpu_cluster_resolver.py - <module> - 31 - Falling back to TensorFlow client; we recommended you install the Cloud TPU client directly with pip install cloud-tpu-client.
# 2022-05-23 09:55:22,952 - DEBUG - __init__.py - <module> - 47 - Creating converter from 7 to 5
# 2022-05-23 09:55:22,952 - DEBUG - __init__.py - <module> - 47 - Creating converter from 5 to 7
# 2022-05-23 09:55:22,953 - DEBUG - __init__.py - <module> - 47 - Creating converter from 7 to 5
# 2022-05-23 09:55:22,953 - DEBUG - __init__.py - <module> - 47 - Creating converter from 5 to 7
# 2022-05-23 09:55:24,635 - INFO - utils.py - _init_num_threads - 145 - Note: NumExpr detected 16 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# ...

# %% [markdown]
# ## 模型配置

# %%
# model_path = r'H:\ai_data\img_crop\train1227\cache\X_ca_region_19-12-27_10_16_19-0.996.hdf5'
# img_size = (512, 512)
# input_size = img_size + (3,)
# use_unet = False

# 视频图转换后图像大小
# 不改变尺寸则设置为None
img_resize = None #(224, 224)

# 是否进行裁边#
IS_CROP = 1

# 检查是否需要裁边
crop_check = 0
crop_check_size = 224
crop_check_ratio = 1.2


# 视频文件扩展名
video_ext = ['.mp4', '.MP4', '.avi', '.wmv', '.AVI']
# 每秒截取图片数，0表示抓所有帧
frame_per_sec = 0
# 是否每张截图都裁边，0表示每张都裁
frames_to_crop = 0

# %%
IS_CROP=1
frame_per_sec=15
# 需处理的视频文件
orig_video_file = r'\\192.168.0.111\息肉视频\2010.mp4'

# %%
def split_video_2_imgs(video_path,imgs_path):
    file_name = os.path.split(video_path)[-1]
        
    if not os.path.exists(imgs_path):
        os.makedirs(imgs_path)
        
        imgs,step = split_video(video_path, frame_per_sec)
        print(imgs_path, 'imgs:', len(imgs), 'step:', step, 'frame per sec:', frame_per_sec)
        
        i = 0
        x1,y1,x2,y2 = 517,36,1684,1042
        frames_to_crop = 60
        while i < len(imgs):
            if IS_CROP:
#                 if 0:
#                     ai_ctrs = xnet_predict_img(model, 'dd', imgs[i], img_size)
#                     if not len(ai_ctrs):
#                         print('detect error file: ',i)
#                         i += 1
#                         continue

#                     rect_list = draw_outline_rect(imgs[i], ai_ctrs, draw_line=False)
#                     x,y,w,h = rect_list[0]
#                     x1,y1,x2,y2 = x,y,x+w,y+h
#                     out_img = imgs[i][y1:y2,x1:x2]
#                 else:
                out_img = imgs[i][y1:y2,x1:x2]
            else:
                out_img = imgs[i]#[40:1040,522:1676]#[38:1040,522:1676]
            
            img_name  = file_name[:-4] + "_f" + str(step*i) + '.jpg'
            save_img_file(os.path.join(imgs_path, img_name), out_img)
            i += 1
        
#             break
        print('split files %s finished, output %s imgs' % (file_name, len(imgs)))
    else:
        print('split imgs already exists: %s' % imgs_path)
        
        
def split_video_file(orig_video_file):
    # 视频所在目录及视频文件名称
    video_path,video_name = os.path.split(orig_video_file)
        
    # 图片文件存放在和视频文件同一个目录下，视频文件名为子目录，imgs子目录中
    imgs_path = os.path.join(video_path, video_name[:-4], 'imgs')

    split_video_2_imgs(orig_video_file, imgs_path)

# %% [markdown]
# ## 单视频文件截图

# %%
split_video_file(orig_video_file)
# Out:
# 2022-05-23 10:22:48,259 - DEBUG - images.py - split_video - 472 - split video file:\\192.168.0.111\息肉视频\2010.mp4
# spit fished ,total imgs=5799
# \\192.168.0.111\息肉视频\2010\imgs imgs: 5799 step: 2 frame per sec: 15
# split files 2010.mp4 finished, output 5799 imgs
