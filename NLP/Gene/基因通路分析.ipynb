# %% [markdown]
# ### 读取数据

# %%
import os
import re

data_dir=r'D:\项目资料\基因表达\通路分析'
file_gene_path=os.path.join(data_dir, 'gene_names.txt')
file_wnt4_path=os.path.join(data_dir, '(cancer) AND (WNT4)文献.txt')
file_ca_path = os.path.join(data_dir, '(cancer) AND (Carbonic Anhydrase 1)文献.txt')

def read_gene_data_file(file_path):
    data = []
    whole_line = ''
    with open(file_path) as f:
        for line in f.readlines():
            line = line[:-1]
            whole_line = whole_line + line
            if not line.endswith(' '):
                data.append(whole_line)
                whole_line = ''
        data.append(whole_line)
    return data

def sel_item(gene_data):
    result, item = [], []
    start_nbr, i = 1, 0
    while i < len(gene_data):
        if gene_data[i].startswith('%s.' % start_nbr):
#             print('start nbr: %s match!' % start_nbr)
            if len(item) > 0:
                result.append(item)
                item = []
            
            start_nbr = start_nbr + 1
        item.append(gene_data[i])
        i = i + 1
        
    if len(item) > 0:
        result.append(item)
            
    print(len(result))
    return result

def proc_item(item_arr):
    results = []
    for item_idx, item in enumerate(item_arr):
        starts_search_flag = 'Author information:'
        ends_search_flag = '(^DOI:)|(^©)|(^PMID: )|(^Copyright)'
        # 标题
        result_item = [item[2]]
        for idx, line_str in enumerate(item):
            # 找Author Information
            if re.search(starts_search_flag, line_str):
                # 找空行
                no = idx + 1
                while not item[no] == '':
                    no = no + 1
                no = no + 1
                
                # 摘要前可能有Comment in
                if item[no].startswith('Comment in') or item[no].startswith('Erratum in'):
                    while not item[no] == '':
                        no = no + 1
                    no = no + 1
                
                # 找摘要
                while not item[no] == '':
                    result_item.append(item[no])
                    no = no + 1
                    
                results.append(result_item)
                break
                
            # 找到结束记号
            if re.search(ends_search_flag, line_str):
                # 找空行
                ends_no = idx - 1
                starts_no = idx - 2
                while not item[starts_no] == '':
                    starts_no = starts_no - 1
                    
                # 写内容
                result_item.extend(item[starts_no + 1:ends_no])
                
                results.append(result_item)
                break
                
            
    return results

# %%
# data_wnt4 = proc_item(sel_item(read_gene_data_file(file_wnt4_path)))
# data_ca = proc_item(sel_item(read_gene_data_file(file_ca_path)))
data_wnt4 = sel_item(read_gene_data_file(file_wnt4_path))
data_ca = sel_item(read_gene_data_file(file_ca_path))
# Out:
# 245
# 1818

# %%
# import xlwt
# workbook = xlwt.Workbook()
# sheet_ca = workbook.add_sheet("Sheet_ca")
# for idx, item in enumerate(data_ca):
#     sheet_ca.write(idx, 0, '\n'.join(item))
# sheet_wnt4 = workbook.add_sheet("Sheet_wnt4")
# for idx, item in enumerate(data_wnt4):
#     sheet_wnt4.write(idx, 0, '\n'.join(item))
# workbook.save(r'基因摘要表格.xlsx')

# %% [markdown]
# ### 生成Label Studio标记数据

# %%
import random
data_all = data_wnt4 + data_ca
random.seed(2345)
random.shuffle(data_all)
train_len = int(len(data_all) * 0.8)
train_data, test_data = data_all[:train_len], data_all[train_len:]

# %%
import json
from genLabeledData import *

gene_label_dict = {}
with open(file_gene_path) as f:
    for line in f.readlines():
        gene_label_dict[line.strip()] = 'Gene'

# %%
test_text_data = ['\n'.join(item) for item in test_data]
test_json_data = process_by_regex(gene_label_dict, test_text_data, language='EN')

with open(r'test_data.json', "w") as f:
    f.write(json.dumps(test_json_data, indent=1, separators=(',', ':'), ensure_ascii=False))
# Out:
# processing line: 1
# time cost: 7.021998882293701
# processing line: 2
# time cost: 7.772000074386597
# processing line: 3
# time cost: 7.988999366760254
# processing line: 4
# time cost: 8.153030633926392
# processing line: 5
# time cost: 7.8179709911346436
# processing line: 6
# time cost: 8.88599967956543
# processing line: 7
# time cost: 8.010002374649048
# processing line: 8
# time cost: 5.888026714324951
# processing line: 9
# time cost: 9.189970970153809
# processing line: 10
# time cost: 8.342000246047974
# processing line: 11
# time cost: 6.61400032043457
# processing line: 12
# time cost: 7.642001390457153
# processing line: 13
# time cost: 7.210998773574829
# processing line: 14
# time cost: 6.38399863243103
# processing line: 15
# time cost: 12.163000583648682
# processing line: 16
# time cost: 6.373033046722412
# processing line: 17
# time cost: 7.147967100143433
# processing line: 18
# time cost: 4.988030910491943
# processing line: 19
# time cost: 6.7069690227508545
# processing line: 20
# time cost: 7.397029876708984
# processing line: 21
# time cost: 6.478971004486084
# processing line: 22
# time cost: 7.330000400543213
# processing line: 23
# time cost: 7.600999116897583
# processing line: 24
# time cost: 6.498031139373779
# processing line: 25
# time cost: 7.998968124389648
# processing line: 26
# time cost: 6.976030588150024
# processing line: 27
# time cost: 7.825970649719238
# processing line: 28
# time cost: 7.004037380218506
# processing line: 29
# time cost: 6.8419623374938965
# processing line: 30
# time cost: 7.616999387741089
# processing line: 31
# time cost: 4.878000497817993
# processing line: 32
# time cost: 7.589001417160034
# processing line: 33
# time cost: 6.083997964859009
# processing line: 34
# time cost: 6.803999900817871
# processing line: 35
# time cost: 6.26200008392334
# processing line: 36
# time cost: 6.818002462387085
# processing line: 37
# time cost: 7.153998136520386
# processing line: 38
# time cost: 6.756999731063843
# processing line: 39
# time cost: 6.849000453948975
# processing line: 40
# time cost: 8.753029823303223
# processing line: 41
# time cost: 6.755969047546387
# processing line: 42
# time cost: 7.516000509262085
# processing line: 43
# time cost: 6.616000175476074
# processing line: 44
# time cost: 6.159000396728516
# processing line: 45
# time cost: 7.11199951171875
# processing line: 46
# time cost: 6.439002513885498
# processing line: 47
# time cost: 7.09699821472168
# processing line: 48
# time cost: 8.097999572753906
# processing line: 49
# time cost: 7.178001403808594
# processing line: 50
# time cost: 6.4750306606292725
# processing line: 51
# time cost: 8.238967418670654
# processing line: 52
# time cost: 7.1220011711120605
# processing line: 53
# time cost: 6.3189990520477295
# processing line: 54
# time cost: 6.592029333114624
# processing line: 55
# time cost: 8.497970581054688
# processing line: 56
# time cost: 6.719000816345215
# processing line: 57
# time cost: 6.2099997997283936
# processing line: 58
# time cost: 7.196000337600708
# processing line: 59
# time cost: 6.0959999561309814
# processing line: 60
# time cost: 7.921998739242554
# processing line: 61
# time cost: 6.121000051498413
# processing line: 62
# time cost: 6.821000099182129
# processing line: 63
# time cost: 7.816031217575073
# processing line: 64
# time cost: 7.275999307632446
# processing line: 65
# time cost: 7.338970184326172
# processing line: 66
# time cost: 6.942000150680542
# processing line: 67
# time cost: 7.392999172210693
# processing line: 68
# time cost: 8.784000158309937
# processing line: 69
# time cost: 8.013001203536987
# processing line: 70
# time cost: 7.603998422622681
# processing line: 71
# time cost: 6.0840003490448
# processing line: 72
# time cost: 6.688029766082764
# processing line: 73
# time cost: 9.008970260620117
# processing line: 74
# time cost: 8.141999959945679
# processing line: 75
# time cost: 7.669000148773193
# processing line: 76
# time cost: 6.321999788284302
# processing line: 77
# time cost: 6.298000335693359
# processing line: 78
# time cost: 7.075999736785889
# processing line: 79
# time cost: 8.818029880523682
# processing line: 80
# time cost: 7.071999788284302
# processing line: 81
# time cost: 7.0779736042022705
# processing line: 82
# time cost: 7.366996765136719
# processing line: 83
# time cost: 5.4150004386901855
# processing line: 84
# time cost: 7.511030197143555
# processing line: 85
# time cost: 7.093970775604248
# processing line: 86
# time cost: 7.1270058155059814
# processing line: 87
# time cost: 6.0540008544921875
# processing line: 88
# time cost: 6.936999559402466
# processing line: 89
# time cost: 7.191000699996948
# processing line: 90
# time cost: 7.224999189376831
# processing line: 91
# time cost: 5.849001884460449
# processing line: 92
# time cost: 7.010998725891113
# processing line: 93
# time cost: 6.7860002517700195
# processing line: 94
# time cost: 4.828000068664551
# processing line: 95
# time cost: 6.76400089263916
# processing line: 96
# time cost: 6.934030294418335
# processing line: 97
# time cost: 7.907999277114868
# processing line: 98
# time cost: 7.288969278335571
# processing line: 99
# time cost: 8.455999851226807
# processing line: 100
# time cost: 6.87800145149231
# processing line: 101
# time cost: 6.608000993728638
# processing line: 102
# time cost: 7.66499924659729
# processing line: 103
# time cost: 6.150998115539551
# processing line: 104
# time cost: 7.361999750137329
# processing line: 105
# time cost: 9.863022565841675
# processing line: 106
# time cost: 6.886001348495483
# processing line: 107
# time cost: 9.59299898147583
# processing line: 108
# time cost: 6.528002500534058
# processing line: 109
# time cost: 6.8450000286102295
# processing line: 110
# time cost: 6.335997104644775
# processing line: 111
# time cost: 7.067965507507324
# processing line: 112
# time cost: 5.657998561859131
# processing line: 113
# time cost: 6.655001640319824
# processing line: 114
# time cost: 6.443000555038452
# processing line: 115
# time cost: 6.599000453948975
# processing line: 116
# time cost: 7.488003730773926
# processing line: 117
# time cost: 8.183993816375732
# processing line: 118
# time cost: 8.093001127243042
# processing line: 119
# time cost: 7.837998867034912
# processing line: 120
# time cost: 8.01400113105774
# processing line: 121
# time cost: 7.504030466079712
# processing line: 122
# time cost: 7.488971948623657
# processing line: 123
# time cost: 6.113996744155884
# processing line: 124
# time cost: 7.375001668930054
# processing line: 125
# time cost: 7.8329994678497314
# processing line: 126
# time cost: 8.942999124526978
# processing line: 127
# time cost: 7.307029485702515
# processing line: 128
# time cost: 7.468000650405884
# processing line: 129
# time cost: 7.013969659805298
# processing line: 130
# time cost: 8.019000053405762
# processing line: 131
# time cost: 6.381000995635986
# processing line: 132
# time cost: 6.666029691696167
# processing line: 133
# time cost: 7.729999303817749
# processing line: 134
# time cost: 8.3429696559906
# processing line: 135
# time cost: 8.065001010894775
# processing line: 136
# time cost: 7.139000415802002
# processing line: 137
# time cost: 7.914998769760132
# processing line: 138
# time cost: 7.301030158996582
# processing line: 139
# time cost: 6.682971239089966
# processing line: 140
# time cost: 7.225000858306885
# processing line: 141
# time cost: 7.00502872467041
# processing line: 142
# time cost: 7.144969940185547
# processing line: 143
# time cost: 8.924998998641968
# processing line: 144
# time cost: 7.200000762939453
# processing line: 145
# time cost: 6.998000383377075
# processing line: 146
# time cost: 6.968001127243042
# processing line: 147
# time cost: 8.174046277999878
# processing line: 148
# time cost: 7.0829994678497314
# processing line: 149
# time cost: 6.444464921951294
# processing line: 150
# time cost: 5.846030235290527
# processing line: 151
# time cost: 6.672973155975342
# processing line: 152
# time cost: 6.822026491165161
# processing line: 153
# time cost: 8.966971397399902
# processing line: 154
# time cost: 8.062999725341797
# processing line: 155
# time cost: 7.723031044006348
# processing line: 156
# time cost: 6.512994766235352
# processing line: 157
# time cost: 7.150003433227539
# processing line: 158
# time cost: 8.480000019073486
# processing line: 159
# time cost: 10.237004041671753
# processing line: 160
# time cost: 7.053996801376343
# processing line: 161
# time cost: 6.713006496429443
# processing line: 162
# time cost: 7.825009822845459
# processing line: 163
# time cost: 7.063971042633057
# processing line: 164
# time cost: 7.043030738830566
# processing line: 165
# time cost: 7.286969900131226
# processing line: 166
# time cost: 7.418999433517456
# processing line: 167
# time cost: 6.725000619888306
# processing line: 168
# time cost: 7.529000282287598
# processing line: 169
# time cost: 9.426029443740845
# processing line: 170
# time cost: 7.5100085735321045
# processing line: 171
# time cost: 7.671972274780273
# processing line: 172
# time cost: 8.168997764587402
# processing line: 173
# time cost: 6.53300142288208
# processing line: 174
# time cost: 7.44600248336792
# processing line: 175
# time cost: 6.746996164321899
# processing line: 176
# time cost: 7.643000841140747
# processing line: 177
# time cost: 6.53075098991394
# processing line: 178
# time cost: 8.82599949836731
# processing line: 179
# time cost: 7.79100227355957
# processing line: 180
# time cost: 6.423507452011108
# processing line: 181
# time cost: 7.780000686645508
# processing line: 182
# time cost: 8.72000241279602
# processing line: 183
# time cost: 7.418998718261719
# processing line: 184
# time cost: 9.013001203536987
# processing line: 185
# time cost: 7.575027704238892
# processing line: 186
# time cost: 6.48099946975708
# processing line: 187
# time cost: 7.0320069789886475
# processing line: 188
# time cost: 4.887993335723877
# processing line: 189
# time cost: 6.971999645233154
# processing line: 190
# time cost: 7.8610007762908936
# processing line: 191
# time cost: 7.7579991817474365
# processing line: 192
# time cost: 7.591000556945801
# processing line: 193
# time cost: 6.979999542236328
# processing line: 194
# time cost: 7.560000419616699
# processing line: 195
# time cost: 7.12002968788147
# processing line: 196
# time cost: 6.791970252990723
# processing line: 197
# time cost: 7.3999998569488525
# processing line: 198
# time cost: 8.062000751495361
# processing line: 199
# time cost: 6.864029169082642
# processing line: 200
# time cost: 5.606970548629761
# processing line: 201
# time cost: 6.6650004386901855
# processing line: 202
# time cost: 8.642998695373535
# processing line: 203
# time cost: 5.753002882003784
# processing line: 204
# time cost: 7.811997413635254
# processing line: 205
# time cost: 8.089002847671509
# processing line: 206
# time cost: 7.78599739074707
# processing line: 207
# time cost: 8.926029682159424
# processing line: 208
# time cost: 7.574970006942749
# processing line: 209
# time cost: 6.400001049041748
# processing line: 210
# time cost: 8.044028759002686
# processing line: 211
# time cost: 8.195972204208374
# processing line: 212
# time cost: 7.4399988651275635
# processing line: 213
# time cost: 7.466999292373657
# processing line: 214
# time cost: 6.705000162124634
# processing line: 215
# time cost: 7.735999584197998
# processing line: 216
# time cost: 6.951030015945435
# processing line: 217
# time cost: 7.140369653701782
# processing line: 218
# time cost: 8.599026918411255
# processing line: 219
# time cost: 7.231973171234131
# processing line: 220
# time cost: 7.288997173309326
# processing line: 221
# time cost: 7.473999977111816
# processing line: 222
# time cost: 6.168001890182495
# processing line: 223
# time cost: 7.138033390045166
# processing line: 224
# time cost: 6.1519646644592285
# processing line: 225
# time cost: 5.822000503540039
# processing line: 226
# time cost: 7.976999521255493
# processing line: 227
# time cost: 7.072000503540039
# processing line: 228
# time cost: 7.4710023403167725
# processing line: 229
# time cost: 6.802998304367065
# processing line: 230
# time cost: 7.582999229431152
# processing line: 231
# time cost: 7.695020914077759
# processing line: 232
# time cost: 8.504998207092285
# processing line: 233
# time cost: 9.627999782562256
# processing line: 234
# time cost: 7.0530030727386475
# processing line: 235
# time cost: 6.668001413345337
# processing line: 236
# time cost: 6.376995801925659
# processing line: 237
# time cost: 7.726001262664795
# processing line: 238
# time cost: 6.780999422073364
# processing line: 239
# time cost: 7.259999513626099
# processing line: 240
# time cost: 6.656998634338379
# processing line: 241
# time cost: 7.0610010623931885
# processing line: 242
# time cost: 8.613842487335205
# processing line: 243
# time cost: 6.871999979019165
# processing line: 244
# time cost: 6.79496955871582
# processing line: 245
# time cost: 7.065000295639038
# processing line: 246
# time cost: 7.123000383377075
# processing line: 247
# time cost: 7.125001907348633
# processing line: 248
# time cost: 6.01202917098999
# processing line: 249
# time cost: 5.912969350814819
# processing line: 250
# time cost: 8.160000085830688
# processing line: 251
# time cost: 7.032002210617065
# processing line: 252
# time cost: 10.039996862411499
# processing line: 253
# time cost: 6.780000686645508
# processing line: 254
# time cost: 7.5119993686676025
# processing line: 255
# time cost: 7.234999179840088
# processing line: 256
# time cost: 10.159001588821411
# processing line: 257
# time cost: 7.838998794555664
# processing line: 258
# time cost: 6.367999792098999
# processing line: 259
# time cost: 7.740030288696289
# processing line: 260
# time cost: 7.133969783782959
# processing line: 261
# time cost: 7.012000560760498
# processing line: 262
# time cost: 6.71401047706604
# processing line: 263
# time cost: 7.311999559402466
# processing line: 264
# time cost: 8.44900369644165
# processing line: 265
# time cost: 6.625031232833862
# processing line: 266
# time cost: 7.795000314712524
# processing line: 267
# time cost: 6.496969699859619
# processing line: 268
# time cost: 7.397029638290405
# processing line: 269
# time cost: 7.107970952987671
# processing line: 270
# time cost: 7.423000335693359
# processing line: 271
# time cost: 6.971999406814575
# processing line: 272
# time cost: 6.866000652313232
# processing line: 273
# time cost: 7.12000036239624
# processing line: 274
# time cost: 6.377999782562256
# processing line: 275
# time cost: 7.521999359130859
# processing line: 276
# time cost: 7.364999294281006
# processing line: 277
# time cost: 7.068000078201294
# processing line: 278
# time cost: 7.256030082702637
# processing line: 279
# time cost: 10.121969938278198
# processing line: 280
# time cost: 7.773001194000244
# processing line: 281
# time cost: 7.4270288944244385
# processing line: 282
# time cost: 8.04597020149231
# processing line: 283
# time cost: 7.976001739501953
# processing line: 284
# time cost: 5.8739988803863525
# processing line: 285
# time cost: 6.619999170303345
# processing line: 286
# time cost: 6.93899941444397
# processing line: 287
# time cost: 7.498999834060669
# processing line: 288
# time cost: 9.543001413345337
# processing line: 289
# time cost: 7.114999771118164
# processing line: 290
# time cost: 9.54800033569336
# processing line: 291
# time cost: 6.62402868270874
# processing line: 292
# time cost: 7.204970836639404
# processing line: 293
# time cost: 5.526031494140625
# processing line: 294
# time cost: 7.351967096328735
# processing line: 295
# time cost: 8.447001934051514
# processing line: 296
# time cost: 8.53899884223938
# processing line: 297
# time cost: 7.411999940872192
# processing line: 298
# time cost: 7.880000829696655
# processing line: 299
# time cost: 6.0190300941467285
# processing line: 300
# time cost: 6.684969663619995
# processing line: 301
# time cost: 7.415999174118042
# processing line: 302
# time cost: 7.822000741958618
# processing line: 303
# time cost: 8.433999300003052
# processing line: 304
# time cost: 6.807001113891602
# processing line: 305
# time cost: 6.343999862670898
# processing line: 306
# time cost: 7.855999231338501
# processing line: 307
# time cost: 7.859999656677246
# processing line: 308
# time cost: 6.981000661849976
# processing line: 309
# time cost: 7.1969990730285645
# processing line: 310
# time cost: 6.9880006313323975
# processing line: 311
# time cost: 8.15402865409851
# processing line: 312
# time cost: 6.927971124649048
# processing line: 313
# time cost: 6.468028545379639
# processing line: 314
# time cost: 6.828000783920288
# processing line: 315
# time cost: 8.610969543457031
# processing line: 316
# time cost: 6.875000715255737
# processing line: 317
# time cost: 6.688002824783325
# processing line: 318
# time cost: 7.204025983810425
# processing line: 319
# time cost: 8.483971357345581
# processing line: 320
# time cost: 6.753000497817993
# processing line: 321
# time cost: 7.096999406814575
# processing line: 322
# time cost: 7.1999993324279785
# processing line: 323
# time cost: 6.752000093460083
# processing line: 324
# time cost: 9.51500153541565
# processing line: 325
# time cost: 7.315030336380005
# processing line: 326
# time cost: 7.337967395782471
# processing line: 327
# time cost: 7.566030502319336
# processing line: 328
# time cost: 7.292970180511475
# processing line: 329
# time cost: 7.328000783920288
# processing line: 330
# time cost: 7.728999614715576
# processing line: 331
# time cost: 9.70799970626831
# processing line: 332
# time cost: 7.000000476837158
# processing line: 333
# time cost: 6.791999340057373
# processing line: 334
# time cost: 7.474999904632568
# processing line: 335
# time cost: 7.315000534057617
# processing line: 336
# time cost: 7.003000497817993
# processing line: 337
# time cost: 7.365031957626343
# processing line: 338
# time cost: 7.552966356277466
# processing line: 339
# time cost: 7.882002115249634
# processing line: 340
# time cost: 7.3789989948272705
# processing line: 341
# time cost: 6.654029846191406
# processing line: 342
# time cost: 7.152999401092529
# processing line: 343
# time cost: 5.946969270706177
# processing line: 344
# time cost: 7.4479992389678955
# processing line: 345
# time cost: 7.149999380111694
# processing line: 346
# time cost: 5.7840001583099365
# processing line: 347
# time cost: 6.934999704360962
# processing line: 348
# time cost: 8.934999465942383
# processing line: 349
# time cost: 7.732029914855957
# processing line: 350
# time cost: 6.48497200012207
# processing line: 351
# time cost: 6.826999187469482
# processing line: 352
# time cost: 8.946999549865723
# processing line: 353
# time cost: 7.075000047683716
# processing line: 354
# time cost: 9.340001344680786
# processing line: 355
# time cost: 7.5669989585876465
# processing line: 356
# time cost: 8.234999895095825
# processing line: 357
# time cost: 6.0799994468688965
# processing line: 358
# time cost: 7.294001340866089
# processing line: 359
# time cost: 6.565999984741211
# processing line: 360
# time cost: 7.657027959823608
# processing line: 361
# time cost: 7.543970584869385
# processing line: 362
# time cost: 8.410000085830688
# processing line: 363
# time cost: 6.804030179977417
# processing line: 364
# time cost: 6.5939695835113525
# processing line: 365
# time cost: 7.206000089645386
# processing line: 366
# time cost: 6.321000099182129
# processing line: 367
# time cost: 6.657001733779907
# processing line: 368
# time cost: 6.384998559951782
# processing line: 369
# time cost: 7.988000154495239
# processing line: 370
# time cost: 8.481001377105713
# processing line: 371
# time cost: 5.782000541687012
# processing line: 372
# time cost: 8.800998449325562
# processing line: 373
# time cost: 7.166001319885254
# processing line: 374
# time cost: 7.491998910903931
# processing line: 375
# time cost: 5.90199875831604
# processing line: 376
# time cost: 6.570002555847168
# processing line: 377
# time cost: 5.658998250961304
# processing line: 378
# time cost: 6.419999361038208
# processing line: 379
# time cost: 8.015999794006348
# processing line: 380
# time cost: 6.563000917434692
# processing line: 381
# time cost: 5.868998765945435
# processing line: 382
# time cost: 8.045030117034912
# processing line: 383
# time cost: 8.224999904632568
# processing line: 384
# time cost: 7.5259788036346436
# processing line: 385
# time cost: 7.856036424636841
# processing line: 386
# time cost: 8.045999526977539
# processing line: 387
# time cost: 8.496999979019165
# processing line: 388
# time cost: 8.129998683929443
# processing line: 389
# time cost: 6.549999952316284
# processing line: 390
# time cost: 7.571035623550415
# processing line: 391
# time cost: 6.289963722229004
# processing line: 392
# time cost: 7.75100302696228
# processing line: 393
# time cost: 7.03299880027771
# processing line: 394
# time cost: 7.456998109817505
# processing line: 395
# time cost: 8.971000909805298
# processing line: 396
# time cost: 6.993029356002808
# processing line: 397
# time cost: 8.854970216751099
# processing line: 398
# time cost: 7.81000018119812
# processing line: 399
# time cost: 6.68899941444397
# processing line: 400
# time cost: 6.501999855041504
# processing line: 401
# time cost: 7.179000616073608
# processing line: 402
# time cost: 8.616000890731812
# processing line: 403
# time cost: 7.128998041152954
# processing line: 404
# time cost: 7.152029752731323
# processing line: 405
# time cost: 6.937001943588257
# processing line: 406
# time cost: 7.406970739364624
# processing line: 407
# time cost: 7.167997598648071
# processing line: 408
# time cost: 6.669002532958984
# processing line: 409
# time cost: 7.359997749328613
# processing line: 410
# time cost: 8.18000054359436
# processing line: 411
# time cost: 7.136027574539185
# processing line: 412
# time cost: 7.4110047817230225
# processing line: 413
# time cost: 8.96199655532837

# %%
train_text_data = ['\n'.join(item) for item in train_data]
train_json_data = process_by_regex(gene_label_dict, train_text_data, language='EN')

with open(r'train_data.json', "w") as f:
    f.write(json.dumps(train_json_data, indent=1, separators=(',', ':'), ensure_ascii=False))
# Out:
# processing line: 1
# time cost: 6.668998956680298
# processing line: 2
# time cost: 7.41013240814209
# processing line: 3
# time cost: 6.367000341415405
# processing line: 4
# time cost: 6.75800085067749
# processing line: 5
# time cost: 6.844999551773071
# processing line: 6
# time cost: 8.098999738693237
# processing line: 7
# time cost: 7.19499945640564
# processing line: 8
# time cost: 6.50100040435791
# processing line: 9
# time cost: 7.642999649047852
# processing line: 10
# time cost: 7.6490020751953125
# processing line: 11
# time cost: 8.877999544143677
# processing line: 12
# time cost: 6.572000980377197
# processing line: 13
# time cost: 7.196998596191406
# processing line: 14
# time cost: 8.638999938964844
# processing line: 15
# time cost: 6.926000595092773
# processing line: 16
# time cost: 6.865999460220337
# processing line: 17
# time cost: 8.131999492645264
# processing line: 18
# time cost: 6.768000841140747
# processing line: 19
# time cost: 7.617000102996826
# processing line: 20
# time cost: 7.072000980377197
# processing line: 21
# time cost: 7.3699986934661865
# processing line: 22
# time cost: 6.1140007972717285
# processing line: 23
# time cost: 8.565027713775635
# processing line: 24
# time cost: 7.585971117019653
# processing line: 25
# time cost: 7.712999582290649
# processing line: 26
# time cost: 7.177001237869263
# processing line: 27
# time cost: 7.704037427902222
# processing line: 28
# time cost: 7.530463218688965
# processing line: 29
# time cost: 7.229040145874023
# processing line: 30
# time cost: 6.680769920349121
# processing line: 31
# time cost: 6.782029867172241
# processing line: 32
# time cost: 7.410972356796265
# processing line: 33
# time cost: 7.323004484176636
# processing line: 34
# time cost: 8.196000337600708
# processing line: 35
# time cost: 6.6020002365112305
# processing line: 36
# time cost: 9.420998811721802
# processing line: 37
# time cost: 6.036001682281494
# processing line: 38
# time cost: 7.448998689651489
# processing line: 39
# time cost: 8.087000131607056
# processing line: 40
# time cost: 7.611392498016357
# processing line: 41
# time cost: 6.441970586776733
# processing line: 42
# time cost: 6.112999200820923
# processing line: 43
# time cost: 7.560000419616699
# processing line: 44
# time cost: 7.950999975204468
# processing line: 45
# time cost: 6.409999847412109
# processing line: 46
# time cost: 6.991002559661865
# processing line: 47
# time cost: 7.3390278816223145
# processing line: 48
# time cost: 7.157970905303955
# processing line: 49
# time cost: 8.515998601913452
# processing line: 50
# time cost: 5.78850245475769
# processing line: 51
# time cost: 7.301000595092773
# processing line: 52
# time cost: 7.021000862121582
# processing line: 53
# time cost: 6.783028602600098
# processing line: 54
# time cost: 6.0729734897613525
# processing line: 55
# time cost: 6.9969964027404785
# processing line: 56
# time cost: 6.827003240585327
# processing line: 57
# time cost: 8.271999835968018
# processing line: 58
# time cost: 6.385997772216797
# processing line: 59
# time cost: 7.799029111862183
# processing line: 60
# time cost: 6.036971092224121
# processing line: 61
# time cost: 6.792998552322388
# processing line: 62
# time cost: 7.345030069351196
# processing line: 63
# time cost: 7.281970262527466
# processing line: 64
# time cost: 7.075001001358032
# processing line: 65
# time cost: 7.161000728607178
# processing line: 66
# time cost: 7.216998815536499
# processing line: 67
# time cost: 7.195000886917114
# processing line: 68
# time cost: 7.519998550415039
# processing line: 69
# time cost: 7.9960010051727295
# processing line: 70
# time cost: 6.180000305175781
# processing line: 71
# time cost: 6.971039772033691
# processing line: 72
# time cost: 5.809027194976807
# processing line: 73
# time cost: 8.57597017288208
# processing line: 74
# time cost: 7.3580005168914795
# processing line: 75
# time cost: 5.790120840072632
# processing line: 76
# time cost: 7.005000829696655
# processing line: 77
# time cost: 6.170055150985718
# processing line: 78
# time cost: 8.853953123092651
# processing line: 79
# time cost: 4.754000902175903
# processing line: 80
# time cost: 6.950000047683716
# processing line: 81
# time cost: 7.853001356124878
# processing line: 82
# time cost: 7.111029624938965
# processing line: 83
# time cost: 6.9559690952301025
# processing line: 84
# time cost: 8.603580713272095
# processing line: 85
# time cost: 7.699998617172241
# processing line: 86
# time cost: 7.0040442943573
# processing line: 87
# time cost: 8.041972637176514
# processing line: 88
# time cost: 7.245998859405518
# processing line: 89
# time cost: 7.080033779144287
# processing line: 90
# time cost: 7.00100040435791
# processing line: 91
# time cost: 8.842000246047974
# processing line: 92
# time cost: 8.206012725830078
# processing line: 93
# time cost: 6.7060205936431885
# processing line: 94
# time cost: 6.719707489013672
# processing line: 95
# time cost: 6.297964811325073
# processing line: 96
# time cost: 6.203998565673828
# processing line: 97
# time cost: 9.173001050949097
# processing line: 98
# time cost: 7.795029401779175
# processing line: 99
# time cost: 8.171968460083008
# processing line: 100
# time cost: 7.527001142501831
# processing line: 101
# time cost: 6.946998596191406
# processing line: 102
# time cost: 7.1350038051605225
# processing line: 103
# time cost: 5.986997604370117
# processing line: 104
# time cost: 8.014002323150635
# processing line: 105
# time cost: 7.174996614456177
# processing line: 106
# time cost: 6.724000692367554
# processing line: 107
# time cost: 6.175999164581299
# processing line: 108
# time cost: 6.436000823974609
# processing line: 109
# time cost: 11.133000135421753
# processing line: 110
# time cost: 7.059998989105225
# processing line: 111
# time cost: 7.40000057220459
# processing line: 112
# time cost: 7.191999435424805
# processing line: 113
# time cost: 8.224998950958252
# processing line: 114
# time cost: 7.748002529144287
# processing line: 115
# time cost: 6.379019498825073
# processing line: 116
# time cost: 6.197979927062988
# processing line: 117
# time cost: 7.921997785568237
# processing line: 118
# time cost: 6.3409998416900635
# processing line: 119
# time cost: 7.398030996322632
# processing line: 120
# time cost: 7.5909717082977295
# processing line: 121
# time cost: 6.711047887802124
# processing line: 122
# time cost: 7.9889795780181885
# processing line: 123
# time cost: 6.6099700927734375
# processing line: 124
# time cost: 6.9360010623931885
# processing line: 125
# time cost: 7.476000070571899
# processing line: 126
# time cost: 7.416998863220215
# processing line: 127
# time cost: 6.797030448913574
# processing line: 128
# time cost: 7.397970199584961
# processing line: 129
# time cost: 8.354031801223755
# processing line: 130
# time cost: 6.3919677734375
# processing line: 131
# time cost: 8.073999404907227
# processing line: 132
# time cost: 6.770001649856567
# processing line: 133
# time cost: 6.260000228881836
# processing line: 134
# time cost: 7.304998159408569
# processing line: 135
# time cost: 6.7930006980896
# processing line: 136
# time cost: 7.759999990463257
# processing line: 137
# time cost: 8.505000114440918
# processing line: 138
# time cost: 6.768000841140747
# processing line: 139
# time cost: 9.747998237609863
# processing line: 140
# time cost: 6.2790000438690186
# processing line: 141
# time cost: 8.124030113220215
# processing line: 142
# time cost: 8.300970554351807
# processing line: 143
# time cost: 7.938003063201904
# processing line: 144
# time cost: 7.428996324539185
# processing line: 145
# time cost: 6.922034978866577
# processing line: 146
# time cost: 7.921964883804321
# processing line: 147
# time cost: 7.783000230789185
# processing line: 148
# time cost: 9.552002906799316
# processing line: 149
# time cost: 7.205026149749756
# processing line: 150
# time cost: 7.221998929977417
# processing line: 151
# time cost: 6.93503475189209
# processing line: 152
# time cost: 8.109965324401855
# processing line: 153
# time cost: 7.297012090682983
# processing line: 154
# time cost: 6.728036403656006
# processing line: 155
# time cost: 7.465028762817383
# processing line: 156
# time cost: 63.57736325263977
# processing line: 157
# time cost: 6.6809728145599365
# processing line: 158
# time cost: 4.757028102874756
# processing line: 159
# time cost: 6.9869704246521
# processing line: 160
# time cost: 7.739028692245483
# processing line: 161
# time cost: 7.593971490859985
# processing line: 162
# time cost: 7.23702597618103
# processing line: 163
# time cost: 6.978971719741821
# processing line: 164
# time cost: 7.905000448226929
# processing line: 165
# time cost: 6.291000127792358
# processing line: 166
# time cost: 7.0950281620025635
# processing line: 167
# time cost: 6.76897120475769
# processing line: 168
# time cost: 7.345999240875244
# processing line: 169
# time cost: 6.638000965118408
# processing line: 170
# time cost: 7.505998611450195
# processing line: 171
# time cost: 7.54302978515625
# processing line: 172
# time cost: 7.596970558166504
# processing line: 173
# time cost: 7.640001535415649
# processing line: 174
# time cost: 6.435999155044556
# processing line: 175
# time cost: 8.225999355316162
# processing line: 176
# time cost: 6.776999473571777
# processing line: 177
# time cost: 6.92799973487854
# processing line: 178
# time cost: 7.447000980377197
# processing line: 179
# time cost: 7.294999361038208
# processing line: 180
# time cost: 6.768030166625977
# processing line: 181
# time cost: 7.827972650527954
# processing line: 182
# time cost: 6.568027019500732
# processing line: 183
# time cost: 9.267308473587036
# processing line: 184
# time cost: 8.748970746994019
# processing line: 185
# time cost: 8.293027639389038
# processing line: 186
# time cost: 6.671971321105957
# processing line: 187
# time cost: 6.560086250305176
# processing line: 188
# time cost: 7.3329994678497314
# processing line: 189
# time cost: 6.531970262527466
# processing line: 190
# time cost: 11.565000772476196
# processing line: 191
# time cost: 7.147999048233032
# processing line: 192
# time cost: 7.874000549316406
# processing line: 193
# time cost: 7.0409996509552
# processing line: 194
# time cost: 8.407973527908325
# processing line: 195
# time cost: 7.112009763717651
# processing line: 196
# time cost: 7.888999700546265
# processing line: 197
# time cost: 8.867663145065308
# processing line: 198
# time cost: 7.285971641540527
# processing line: 199
# time cost: 8.52700662612915
# processing line: 200
# time cost: 7.495995998382568
# processing line: 201
# time cost: 7.2460010051727295
# processing line: 202
# time cost: 8.073116064071655
# processing line: 203
# time cost: 6.903000116348267
# processing line: 204
# time cost: 7.803005933761597
# processing line: 205
# time cost: 6.6770312786102295
# processing line: 206
# time cost: 7.424970626831055
# processing line: 207
# time cost: 8.15099835395813
# processing line: 208
# time cost: 7.479001522064209
# processing line: 209
# time cost: 7.541027784347534
# processing line: 210
# time cost: 9.463002681732178
# processing line: 211
# time cost: 6.77996826171875
# processing line: 212
# time cost: 7.883001327514648
# processing line: 213
# time cost: 7.642998695373535
# processing line: 214
# time cost: 7.606002330780029
# processing line: 215
# time cost: 10.907000303268433
# processing line: 216
# time cost: 6.7080254554748535
# processing line: 217
# time cost: 7.240973472595215
# processing line: 218
# time cost: 8.048998594284058
# processing line: 219
# time cost: 8.630998373031616
# processing line: 220
# time cost: 8.443007469177246
# processing line: 221
# time cost: 7.530999183654785
# processing line: 222
# time cost: 8.57003378868103
# processing line: 223
# time cost: 7.885965824127197
# processing line: 224
# time cost: 7.102037668228149
# processing line: 225
# time cost: 7.550987005233765
# processing line: 226
# time cost: 8.277998924255371
# processing line: 227
# time cost: 7.234032154083252
# processing line: 228
# time cost: 7.708806037902832
# processing line: 229
# time cost: 7.573030471801758
# processing line: 230
# time cost: 6.978970766067505
# processing line: 231
# time cost: 6.6060097217559814
# processing line: 232
# time cost: 7.559999704360962
# processing line: 233
# time cost: 6.512006998062134
# processing line: 234
# time cost: 6.731999397277832
# processing line: 235
# time cost: 7.729999303817749
# processing line: 236
# time cost: 7.4440295696258545
# processing line: 237
# time cost: 6.182971000671387
# processing line: 238
# time cost: 8.747000217437744
# processing line: 239
# time cost: 7.857535362243652
# processing line: 240
# time cost: 8.306011199951172
# processing line: 241
# time cost: 7.798969745635986
# processing line: 242
# time cost: 8.104040145874023
# processing line: 243
# time cost: 7.258389234542847
# processing line: 244
# time cost: 7.3690009117126465
# processing line: 245
# time cost: 9.07400107383728
# processing line: 246
# time cost: 6.817998170852661
# processing line: 247
# time cost: 8.622037172317505
# processing line: 248
# time cost: 6.942009449005127
# processing line: 249
# time cost: 4.973029613494873
# processing line: 250
# time cost: 7.3580002784729
# processing line: 251
# time cost: 8.5409996509552
# processing line: 252
# time cost: 7.412970304489136
# processing line: 253
# time cost: 6.460000514984131
# processing line: 254
# time cost: 7.945999622344971
# processing line: 255
# time cost: 7.319000005722046
# processing line: 256
# time cost: 6.996000289916992
# processing line: 257
# time cost: 6.955000162124634
# processing line: 258
# time cost: 7.402999401092529
# processing line: 259
# time cost: 6.583000421524048
# processing line: 260
# time cost: 10.263999700546265
# processing line: 261
# time cost: 7.220000743865967
# processing line: 262
# time cost: 7.020998477935791
# processing line: 263
# time cost: 6.891000747680664
# processing line: 264
# time cost: 7.083999872207642
# processing line: 265
# time cost: 7.4569995403289795
# processing line: 266
# time cost: 6.7750327587127686
# processing line: 267
# time cost: 6.574969291687012
# processing line: 268
# time cost: 8.927999258041382
# processing line: 269
# time cost: 9.765999794006348
# processing line: 270
# time cost: 6.747998952865601
# processing line: 271
# time cost: 8.176000595092773
# processing line: 272
# time cost: 7.240033864974976
# processing line: 273
# time cost: 9.25296664237976
# processing line: 274
# time cost: 7.057999610900879
# processing line: 275
# time cost: 7.965999126434326
# processing line: 276
# time cost: 7.991999864578247
# processing line: 277
# time cost: 6.812396764755249
# processing line: 278
# time cost: 8.687508821487427
# processing line: 279
# time cost: 7.88300085067749
# processing line: 280
# time cost: 7.365999698638916
# processing line: 281
# time cost: 7.592999696731567
# processing line: 282
# time cost: 9.110438823699951
# processing line: 283
# time cost: 9.400000095367432
# processing line: 284
# time cost: 6.344004154205322
# processing line: 285
# time cost: 7.023000955581665
# processing line: 286
# time cost: 8.227999210357666
# processing line: 287
# time cost: 7.894999980926514
# processing line: 288
# time cost: 8.603029727935791
# processing line: 289
# time cost: 7.0029683113098145
# processing line: 290
# time cost: 6.867999076843262
# processing line: 291
# time cost: 8.210031032562256
# processing line: 292
# time cost: 8.124999523162842
# processing line: 293
# time cost: 7.256969451904297
# processing line: 294
# time cost: 7.424036979675293
# processing line: 295
# time cost: 7.37999963760376
# processing line: 296
# time cost: 8.888971090316772
# processing line: 297
# time cost: 6.74199914932251
# processing line: 298
# time cost: 6.700033187866211
# processing line: 299
# time cost: 7.4969801902771
# processing line: 300
# time cost: 6.520029544830322
# processing line: 301
# time cost: 7.56497049331665
# processing line: 302
# time cost: 7.535000801086426
# processing line: 303
# time cost: 7.622999906539917
# processing line: 304
# time cost: 7.359969854354858
# processing line: 305
# time cost: 7.521001100540161
# processing line: 306
# time cost: 6.479000806808472
# processing line: 307
# time cost: 7.296027183532715
# processing line: 308
# time cost: 7.508000373840332
# processing line: 309
# time cost: 7.305971145629883
# processing line: 310
# time cost: 6.439029216766357
# processing line: 311
# time cost: 7.006972312927246
# processing line: 312
# time cost: 7.647998332977295
# processing line: 313
# time cost: 6.552029609680176
# processing line: 314
# time cost: 6.964036226272583
# processing line: 315
# time cost: 7.538970708847046
# processing line: 316
# time cost: 7.694999933242798
# processing line: 317
# time cost: 4.876000642776489
# processing line: 318
# time cost: 6.289999485015869
# processing line: 319
# time cost: 6.93002986907959
# processing line: 320
# time cost: 9.518970251083374
# processing line: 321
# time cost: 6.373000621795654
# processing line: 322
# time cost: 6.947000503540039
# processing line: 323
# time cost: 7.527028799057007
# processing line: 324
# time cost: 8.042970657348633
# processing line: 325
# time cost: 7.59403395652771
# processing line: 326
# time cost: 8.133965492248535
# processing line: 327
# time cost: 4.854000568389893
# processing line: 328
# time cost: 7.042030096054077
# processing line: 329
# time cost: 7.800970077514648
# processing line: 330
# time cost: 7.299999475479126
# processing line: 331
# time cost: 7.050029277801514
# processing line: 332
# time cost: 7.315970420837402
# processing line: 333
# time cost: 9.481001138687134
# processing line: 334
# time cost: 6.8040289878845215
# processing line: 335
# time cost: 8.351970195770264
# processing line: 336
# time cost: 7.676001071929932
# processing line: 337
# time cost: 9.00899887084961
# processing line: 338
# time cost: 7.827030181884766
# processing line: 339
# time cost: 7.636999845504761
# processing line: 340
# time cost: 8.326970100402832
# processing line: 341
# time cost: 6.71602988243103
# processing line: 342
# time cost: 7.627969980239868
# processing line: 343
# time cost: 6.71999979019165
# processing line: 344
# time cost: 7.378040552139282
# processing line: 345
# time cost: 6.236992120742798
# processing line: 346
# time cost: 7.860976457595825
# processing line: 347
# time cost: 7.379999876022339
# processing line: 348
# time cost: 8.572002649307251
# processing line: 349
# time cost: 7.524063587188721
# processing line: 350
# time cost: 8.207971334457397
# processing line: 351
# time cost: 8.136000633239746
# processing line: 352
# time cost: 7.534999132156372
# processing line: 353
# time cost: 6.910030126571655
# processing line: 354
# time cost: 6.358999252319336
# processing line: 355
# time cost: 8.598000049591064
# processing line: 356
# time cost: 6.03197169303894
# processing line: 357
# time cost: 6.864028453826904
# processing line: 358
# time cost: 4.891972064971924
# processing line: 359
# time cost: 6.154028415679932
# processing line: 360
# time cost: 7.104007005691528
# processing line: 361
# time cost: 6.006962537765503
# processing line: 362
# time cost: 6.990000009536743
# processing line: 363
# time cost: 7.083000659942627
# processing line: 364
# time cost: 6.451998949050903
# processing line: 365
# time cost: 6.955033779144287
# processing line: 366
# time cost: 7.844996213912964
# processing line: 367
# time cost: 6.670972585678101
# processing line: 368
# time cost: 6.877997875213623
# processing line: 369
# time cost: 6.682029962539673
# processing line: 370
# time cost: 8.775970458984375
# processing line: 371
# time cost: 7.728031635284424
# processing line: 372
# time cost: 7.556968450546265
# processing line: 373
# time cost: 6.232001066207886
# processing line: 374
# time cost: 7.654999256134033
# processing line: 375
# time cost: 7.110998868942261
# processing line: 376
# time cost: 7.04403018951416
# processing line: 377
# time cost: 7.407971143722534
# processing line: 378
# time cost: 8.010028839111328
# processing line: 379
# time cost: 7.853970766067505
# processing line: 380
# time cost: 7.227029800415039
# processing line: 381
# time cost: 7.867969512939453
# processing line: 382
# time cost: 9.054029941558838
# processing line: 383
# time cost: 7.18897008895874
# processing line: 384
# time cost: 7.9070000648498535
# processing line: 385
# time cost: 7.179006099700928
# processing line: 386
# time cost: 7.431030511856079
# processing line: 387
# time cost: 7.705999135971069
# processing line: 388
# time cost: 6.232000350952148
# processing line: 389
# time cost: 10.851970911026001
# processing line: 390
# time cost: 7.184999704360962
# processing line: 391
# time cost: 7.22599983215332
# processing line: 392
# time cost: 5.790000677108765
# processing line: 393
# time cost: 7.112028360366821
# processing line: 394
# time cost: 7.006970405578613
# processing line: 395
# time cost: 9.541000604629517
# processing line: 396
# time cost: 8.122028589248657
# processing line: 397
# time cost: 7.565973520278931
# processing line: 398
# time cost: 9.077998638153076
# processing line: 399
# time cost: 7.506006717681885
# processing line: 400
# time cost: 6.641027450561523
# processing line: 401
# time cost: 7.509002208709717
# processing line: 402
# time cost: 7.25503134727478
# processing line: 403
# time cost: 7.448968410491943
# processing line: 404
# time cost: 8.519999504089355
# processing line: 405
# time cost: 7.041029691696167
# processing line: 406
# time cost: 8.442999124526978
# processing line: 407
# time cost: 7.361970901489258
# processing line: 408
# time cost: 8.519001007080078
# processing line: 409
# time cost: 8.006197452545166
# processing line: 410
# time cost: 8.486002206802368
# processing line: 411
# time cost: 6.840972423553467
# processing line: 412
# time cost: 9.048027038574219
# processing line: 413
# time cost: 8.004971027374268
# processing line: 414
# time cost: 7.404021978378296
# processing line: 415
# time cost: 7.426015615463257
# processing line: 416
# time cost: 7.4729979038238525
# processing line: 417
# time cost: 7.6340012550354
# processing line: 418
# time cost: 6.504999876022339
# processing line: 419
# time cost: 8.120999574661255
# processing line: 420
# time cost: 8.891999244689941
# processing line: 421
# time cost: 6.875
# processing line: 422
# time cost: 6.727001428604126
# processing line: 423
# time cost: 7.024999141693115
# processing line: 424
# time cost: 9.88100790977478
# processing line: 425
# time cost: 7.382997989654541
# processing line: 426
# time cost: 7.266000747680664
# processing line: 427
# time cost: 7.710029363632202
# processing line: 428
# time cost: 7.318972587585449
# processing line: 429
# time cost: 7.349027156829834
# processing line: 430
# time cost: 8.207979440689087
# processing line: 431
# time cost: 7.698001146316528
# processing line: 432
# time cost: 8.105998754501343
# processing line: 433
# time cost: 7.560002088546753
# processing line: 434
# time cost: 10.355001449584961
# processing line: 435
# time cost: 7.41702675819397
# processing line: 436
# time cost: 7.179001092910767
# processing line: 437
# time cost: 7.701998949050903
# processing line: 438
# time cost: 7.12497091293335
# processing line: 439
# time cost: 5.000999927520752
# processing line: 440
# time cost: 6.548999309539795
# processing line: 441
# time cost: 7.1590001583099365
# processing line: 442
# time cost: 13.559000015258789
# processing line: 443
# time cost: 6.26400089263916
# processing line: 444
# time cost: 7.578028678894043
# processing line: 445
# time cost: 7.9729697704315186
# processing line: 446
# time cost: 7.877000093460083
# processing line: 447
# time cost: 8.994000673294067
# processing line: 448
# time cost: 10.180999994277954
# processing line: 449
# time cost: 10.49100136756897
# processing line: 450
# time cost: 7.8639976978302
# processing line: 451
# time cost: 5.609031677246094
# processing line: 452
# time cost: 7.100968360900879
# processing line: 453
# time cost: 6.7950005531311035
# processing line: 454
# time cost: 7.405001878738403
# processing line: 455
# time cost: 7.430998802185059
# processing line: 456
# time cost: 8.191998720169067
# processing line: 457
# time cost: 9.466001272201538
# processing line: 458
# time cost: 9.373999118804932
# processing line: 459
# time cost: 8.457000494003296
# processing line: 460
# time cost: 7.409029483795166
# processing line: 461
# time cost: 7.890972375869751
# processing line: 462
# time cost: 6.824996709823608
# processing line: 463
# time cost: 9.64014482498169
# processing line: 464
# time cost: 7.177028656005859
# processing line: 465
# time cost: 8.686970710754395
# processing line: 466
# time cost: 6.34102988243103
# processing line: 467
# time cost: 8.88000226020813
# processing line: 468
# time cost: 7.028088092803955
# processing line: 469
# time cost: 6.996001720428467
# processing line: 470
# time cost: 7.1989991664886475
# processing line: 471
# time cost: 9.91202974319458
# processing line: 472
# time cost: 7.615001916885376
# processing line: 473
# time cost: 7.940966844558716
# processing line: 474
# time cost: 7.13800573348999
# processing line: 475
# time cost: 6.130998849868774
# processing line: 476
# time cost: 7.5660014152526855
# processing line: 477
# time cost: 7.607999801635742
# processing line: 478
# time cost: 6.914496183395386
# processing line: 479
# time cost: 7.069004774093628
# processing line: 480
# time cost: 8.271000385284424
# processing line: 481
# time cost: 7.134378433227539
# processing line: 482
# time cost: 8.854970693588257
# processing line: 483
# time cost: 6.085000991821289
# processing line: 484
# time cost: 7.437998056411743
# processing line: 485
# time cost: 8.349029779434204
# processing line: 486
# time cost: 7.705970287322998
# processing line: 487
# time cost: 6.998999118804932
# processing line: 488
# time cost: 8.120000839233398
# processing line: 489
# time cost: 7.223999261856079
# processing line: 490
# time cost: 9.125000238418579
# processing line: 491
# time cost: 7.287029266357422
# processing line: 492
# time cost: 7.300970554351807
# processing line: 493
# time cost: 7.508000612258911
# processing line: 494
# time cost: 10.165998935699463
# processing line: 495
# time cost: 6.752000093460083
# processing line: 496
# time cost: 7.383000135421753
# processing line: 497
# time cost: 4.96602988243103
# processing line: 498
# time cost: 7.938969850540161
# processing line: 499
# time cost: 6.645000219345093
# processing line: 500
# time cost: 6.670001029968262
# processing line: 501
# time cost: 8.070998668670654
# processing line: 502
# time cost: 8.463008165359497
# processing line: 503
# time cost: 6.418998956680298
# processing line: 504
# time cost: 9.558000564575195
# processing line: 505
# time cost: 9.220000267028809
# processing line: 506
# time cost: 7.844000577926636
# processing line: 507
# time cost: 8.375000476837158
# processing line: 508
# time cost: 6.828999996185303
# processing line: 509
# time cost: 7.882999658584595
# processing line: 510
# time cost: 6.318029403686523
# processing line: 511
# time cost: 7.475970983505249
# processing line: 512
# time cost: 10.157028436660767
# processing line: 513
# time cost: 8.0299711227417
# processing line: 514
# time cost: 7.0290000438690186
# processing line: 515
# time cost: 7.657006025314331
# processing line: 516
# time cost: 8.196000576019287
# processing line: 517
# time cost: 8.220998287200928
# processing line: 518
# time cost: 9.765000581741333
# processing line: 519
# time cost: 6.789999485015869
# processing line: 520
# time cost: 7.451814889907837
# processing line: 521
# time cost: 8.28899884223938
# processing line: 522
# time cost: 7.58100152015686
# processing line: 523
# time cost: 7.417028188705444
# processing line: 524
# time cost: 8.695971012115479
# processing line: 525
# time cost: 6.487029314041138
# processing line: 526
# time cost: 7.449970006942749
# processing line: 527
# time cost: 8.133000135421753
# processing line: 528
# time cost: 9.8400297164917
# processing line: 529
# time cost: 7.3809709548950195
# processing line: 530
# time cost: 9.388000249862671
# processing line: 531
# time cost: 7.259998798370361
# processing line: 532
# time cost: 6.2190327644348145
# processing line: 533
# time cost: 7.0980048179626465
# processing line: 534
# time cost: 9.349992513656616
# processing line: 535
# time cost: 8.220999956130981
# processing line: 536
# time cost: 6.837970733642578
# processing line: 537
# time cost: 8.042999505996704
# processing line: 538
# time cost: 6.840000629425049
# processing line: 539
# time cost: 6.841999053955078
# processing line: 540
# time cost: 7.120000839233398
# processing line: 541
# time cost: 7.360000133514404
# processing line: 542
# time cost: 8.149999856948853
# processing line: 543
# time cost: 7.663029909133911
# processing line: 544
# time cost: 7.581976413726807
# processing line: 545
# time cost: 7.115998268127441
# processing line: 546
# time cost: 8.468000411987305
# processing line: 547
# time cost: 5.856002569198608
# processing line: 548
# time cost: 7.412997722625732
# processing line: 549
# time cost: 7.480999231338501
# processing line: 550
# time cost: 8.97200083732605
# processing line: 551
# time cost: 8.145000219345093
# processing line: 552
# time cost: 7.348025798797607
# processing line: 553
# time cost: 6.307973861694336
# processing line: 554
# time cost: 6.499028921127319
# processing line: 555
# time cost: 6.699970960617065
# processing line: 556
# time cost: 10.291029930114746
# processing line: 557
# time cost: 7.132998704910278
# processing line: 558
# time cost: 10.804001331329346
# processing line: 559
# time cost: 6.923969030380249
# processing line: 560
# time cost: 7.787029981613159
# processing line: 561
# time cost: 6.54797101020813
# processing line: 562
# time cost: 6.383027791976929
# processing line: 563
# time cost: 7.894001245498657
# processing line: 564
# time cost: 8.151968955993652
# processing line: 565
# time cost: 7.831000328063965
# processing line: 566
# time cost: 7.807000160217285
# processing line: 567
# time cost: 7.205999135971069
# processing line: 568
# time cost: 6.420000076293945
# processing line: 569
# time cost: 7.602032661437988
# processing line: 570
# time cost: 7.030970096588135
# processing line: 571
# time cost: 7.675997734069824
# processing line: 572
# time cost: 7.432999610900879
# processing line: 573
# time cost: 6.177000045776367
# processing line: 574
# time cost: 7.479029417037964
# processing line: 575
# time cost: 7.543999671936035
# processing line: 576
# time cost: 7.268000602722168
# processing line: 577
# time cost: 7.4679999351501465
# processing line: 578
# time cost: 7.3360021114349365
# processing line: 579
# time cost: 7.0049989223480225
# processing line: 580
# time cost: 7.155028343200684
# processing line: 581
# time cost: 7.762971878051758
# processing line: 582
# time cost: 8.714028358459473
# processing line: 583
# time cost: 8.99897027015686
# processing line: 584
# time cost: 7.173999547958374
# processing line: 585
# time cost: 7.581000566482544
# processing line: 586
# time cost: 7.612000942230225
# processing line: 587
# time cost: 6.723031044006348
# processing line: 588
# time cost: 8.430004119873047
# processing line: 589
# time cost: 8.622994422912598
# processing line: 590
# time cost: 6.738970994949341
# processing line: 591
# time cost: 7.599999666213989
# processing line: 592
# time cost: 9.078998565673828
# processing line: 593
# time cost: 6.608000040054321
# processing line: 594
# time cost: 7.40400242805481
# processing line: 595
# time cost: 7.606028318405151
# processing line: 596
# time cost: 9.063968896865845
# processing line: 597
# time cost: 8.76600193977356
# processing line: 598
# time cost: 7.742998361587524
# processing line: 599
# time cost: 7.765001058578491
# processing line: 600
# time cost: 6.778999090194702
# processing line: 601
# time cost: 12.812999963760376
# processing line: 602
# time cost: 7.686033725738525
# processing line: 603
# time cost: 6.792967081069946
# processing line: 604
# time cost: 6.957001447677612
# processing line: 605
# time cost: 7.970998764038086
# processing line: 606
# time cost: 8.006999254226685
# processing line: 607
# time cost: 9.349036693572998
# processing line: 608
# time cost: 8.524993181228638
# processing line: 609
# time cost: 9.297972440719604
# processing line: 610
# time cost: 8.546998262405396
# processing line: 611
# time cost: 7.828999757766724
# processing line: 612
# time cost: 7.2320005893707275
# processing line: 613
# time cost: 8.094000101089478
# processing line: 614
# time cost: 7.392998695373535
# processing line: 615
# time cost: 7.972001314163208
# processing line: 616
# time cost: 7.282999753952026
# processing line: 617
# time cost: 5.711000919342041
# processing line: 618
# time cost: 8.600027322769165
# processing line: 619
# time cost: 7.354971408843994
# processing line: 620
# time cost: 7.760999917984009
# processing line: 621
# time cost: 7.637033700942993
# processing line: 622
# time cost: 6.469702482223511
# processing line: 623
# time cost: 7.007999420166016
# processing line: 624
# time cost: 8.746000051498413
# processing line: 625
# time cost: 9.025002241134644
# processing line: 626
# time cost: 7.742997646331787
# processing line: 627
# time cost: 7.54900336265564
# processing line: 628
# time cost: 6.606996536254883
# processing line: 629
# time cost: 7.683000802993774
# processing line: 630
# time cost: 7.176029443740845
# processing line: 631
# time cost: 8.94597053527832
# processing line: 632
# time cost: 7.795999526977539
# processing line: 633
# time cost: 7.752999782562256
# processing line: 634
# time cost: 7.447999954223633
# processing line: 635
# time cost: 8.514001846313477
# processing line: 636
# time cost: 7.265000343322754
# processing line: 637
# time cost: 5.642029523849487
# processing line: 638
# time cost: 6.79196834564209
# processing line: 639
# time cost: 6.821000099182129
# processing line: 640
# time cost: 7.991000652313232
# processing line: 641
# time cost: 7.380969047546387
# processing line: 642
# time cost: 9.079030990600586
# processing line: 643
# time cost: 8.636969327926636
# processing line: 644
# time cost: 7.36799955368042
# processing line: 645
# time cost: 7.468029499053955
# processing line: 646
# time cost: 7.077969789505005
# processing line: 647
# time cost: 7.9170002937316895
# processing line: 648
# time cost: 8.257000923156738
# processing line: 649
# time cost: 7.36970067024231
# processing line: 650
# time cost: 7.654999256134033
# processing line: 651
# time cost: 8.980000495910645
# processing line: 652
# time cost: 7.958001375198364
# processing line: 653
# time cost: 7.284998416900635
# processing line: 654
# time cost: 6.40103006362915
# processing line: 655
# time cost: 8.035969495773315
# processing line: 656
# time cost: 7.360029697418213
# processing line: 657
# time cost: 8.695971488952637
# processing line: 658
# time cost: 7.417998552322388
# processing line: 659
# time cost: 6.807001829147339
# processing line: 660
# time cost: 7.6989991664886475
# processing line: 661
# time cost: 7.513000249862671
# processing line: 662
# time cost: 8.630029916763306
# processing line: 663
# time cost: 6.7739691734313965
# processing line: 664
# time cost: 6.5329999923706055
# processing line: 665
# time cost: 8.367999792098999
# processing line: 666
# time cost: 8.678000926971436
# processing line: 667
# time cost: 8.789001703262329
# processing line: 668
# time cost: 7.337997913360596
# processing line: 669
# time cost: 6.910029172897339
# processing line: 670
# time cost: 7.470972061157227
# processing line: 671
# time cost: 8.382999658584595
# processing line: 672
# time cost: 8.417002201080322
# processing line: 673
# time cost: 7.120999336242676
# processing line: 674
# time cost: 6.81602931022644
# processing line: 675
# time cost: 6.3679986000061035
# processing line: 676
# time cost: 6.850011110305786
# processing line: 677
# time cost: 6.729959726333618
# processing line: 678
# time cost: 7.661999464035034
# processing line: 679
# time cost: 7.383031845092773
# processing line: 680
# time cost: 7.3839967250823975
# processing line: 681
# time cost: 7.934000015258789
# processing line: 682
# time cost: 7.262002468109131
# processing line: 683
# time cost: 7.234027147293091
# processing line: 684
# time cost: 7.062970399856567
# processing line: 685
# time cost: 6.696029186248779
# processing line: 686
# time cost: 7.953970193862915
# processing line: 687
# time cost: 8.823001623153687
# processing line: 688
# time cost: 5.939998626708984
# processing line: 689
# time cost: 7.115000247955322
# processing line: 690
# time cost: 6.735000133514404
# processing line: 691
# time cost: 7.930031776428223
# processing line: 692
# time cost: 7.2040016651153564
# processing line: 693
# time cost: 7.029966592788696
# processing line: 694
# time cost: 7.37899923324585
# processing line: 695
# time cost: 7.831002950668335
# processing line: 696
# time cost: 8.149996757507324
# processing line: 697
# time cost: 6.837030649185181
# processing line: 698
# time cost: 7.440999507904053
# processing line: 699
# time cost: 7.294970273971558
# processing line: 700
# time cost: 6.6960015296936035
# processing line: 701
# time cost: 7.961028575897217
# processing line: 702
# time cost: 7.122972249984741
# processing line: 703
# time cost: 7.349998474121094
# processing line: 704
# time cost: 7.523032903671265
# processing line: 705
# time cost: 9.807148933410645
# processing line: 706
# time cost: 7.060999870300293
# processing line: 707
# time cost: 7.654000282287598
# processing line: 708
# time cost: 6.625030279159546
# processing line: 709
# time cost: 7.110969305038452
# processing line: 710
# time cost: 7.067000865936279
# processing line: 711
# time cost: 7.422001123428345
# processing line: 712
# time cost: 6.948999643325806
# processing line: 713
# time cost: 7.536000728607178
# processing line: 714
# time cost: 7.915998458862305
# processing line: 715
# time cost: 7.281001806259155
# processing line: 716
# time cost: 8.057999610900879
# processing line: 717
# time cost: 6.694998741149902
# processing line: 718
# time cost: 9.176000118255615
# processing line: 719
# time cost: 8.27899980545044
# processing line: 720
# time cost: 8.328028440475464
# processing line: 721
# time cost: 7.803967475891113
# processing line: 722
# time cost: 8.627000093460083
# processing line: 723
# time cost: 7.205999851226807
# processing line: 724
# time cost: 7.306999921798706
# processing line: 725
# time cost: 7.560119867324829
# processing line: 726
# time cost: 7.417028903961182
# processing line: 727
# time cost: 7.239970684051514
# processing line: 728
# time cost: 8.544000148773193
# processing line: 729
# time cost: 7.188999652862549
# processing line: 730
# time cost: 7.9690001010894775
# processing line: 731
# time cost: 7.3420000076293945
# processing line: 732
# time cost: 7.191000699996948
# processing line: 733
# time cost: 6.983998775482178
# processing line: 734
# time cost: 8.14500117301941
# processing line: 735
# time cost: 7.021000146865845
# processing line: 736
# time cost: 7.019999265670776
# processing line: 737
# time cost: 7.730999708175659
# processing line: 738
# time cost: 7.230999946594238
# processing line: 739
# time cost: 7.140030860900879
# processing line: 740
# time cost: 6.376998662948608
# processing line: 741
# time cost: 8.571001052856445
# processing line: 742
# time cost: 7.1349968910217285
# processing line: 743
# time cost: 6.313975811004639
# processing line: 744
# time cost: 6.8769989013671875
# processing line: 745
# time cost: 8.016998291015625
# processing line: 746
# time cost: 7.5
# processing line: 747
# time cost: 9.545999526977539
# processing line: 748
# time cost: 8.497999906539917
# processing line: 749
# time cost: 10.21000051498413
# processing line: 750
# time cost: 7.089569568634033
# processing line: 751
# time cost: 7.9210288524627686
# processing line: 752
# time cost: 7.531999826431274
# processing line: 753
# time cost: 10.690999984741211
# processing line: 754
# time cost: 7.07597017288208
# processing line: 755
# time cost: 7.446999788284302
# processing line: 756
# time cost: 8.013000726699829
# processing line: 757
# time cost: 6.671030759811401
# processing line: 758
# time cost: 7.0189690589904785
# processing line: 759
# time cost: 6.810000896453857
# processing line: 760
# time cost: 7.675999164581299
# processing line: 761
# time cost: 6.046031713485718
# processing line: 762
# time cost: 7.382968187332153
# processing line: 763
# time cost: 7.404001474380493
# processing line: 764
# time cost: 7.317999362945557
# processing line: 765
# time cost: 7.348029851913452
# processing line: 766
# time cost: 9.765973329544067
# processing line: 767
# time cost: 7.361996173858643
# processing line: 768
# time cost: 8.608038187026978
# processing line: 769
# time cost: 7.07796311378479
# processing line: 770
# time cost: 7.053999662399292
# processing line: 771
# time cost: 7.339029550552368
# processing line: 772
# time cost: 8.17197036743164
# processing line: 773
# time cost: 8.520030498504639
# processing line: 774
# time cost: 6.957970142364502
# processing line: 775
# time cost: 7.211002349853516
# processing line: 776
# time cost: 7.108999729156494
# processing line: 777
# time cost: 7.027998447418213
# processing line: 778
# time cost: 6.946999788284302
# processing line: 779
# time cost: 9.313000202178955
# processing line: 780
# time cost: 8.947999477386475
# processing line: 781
# time cost: 6.130999803543091
# processing line: 782
# time cost: 8.571000337600708
# processing line: 783
# time cost: 6.982999801635742
# processing line: 784
# time cost: 7.061001300811768
# processing line: 785
# time cost: 7.533998727798462
# processing line: 786
# time cost: 7.370999813079834
# processing line: 787
# time cost: 9.011000394821167
# processing line: 788
# time cost: 7.3949995040893555
# processing line: 789
# time cost: 7.373030185699463
# processing line: 790
# time cost: 7.436970233917236
# processing line: 791
# time cost: 7.211000204086304
# processing line: 792
# time cost: 6.6659996509552
# processing line: 793
# time cost: 7.46999979019165
# processing line: 794
# time cost: 10.811001300811768
# processing line: 795
# time cost: 6.580028772354126
# processing line: 796
# time cost: 5.968971252441406
# processing line: 797
# time cost: 7.434028625488281
# processing line: 798
# time cost: 7.724970579147339
# processing line: 799
# time cost: 6.562999963760376
# processing line: 800
# time cost: 7.852999448776245
# processing line: 801
# time cost: 7.056999683380127
# processing line: 802
# time cost: 9.067031383514404
# processing line: 803
# time cost: 6.786969900131226
# processing line: 804
# time cost: 8.228028297424316
# processing line: 805
# time cost: 7.482970476150513
# processing line: 806
# time cost: 6.678999662399292
# processing line: 807
# time cost: 6.7480010986328125
# processing line: 808
# time cost: 6.7940287590026855
# processing line: 809
# time cost: 7.349999666213989
# processing line: 810
# time cost: 7.88097071647644
# processing line: 811
# time cost: 4.9619996547698975
# processing line: 812
# time cost: 8.191002368927002
# processing line: 813
# time cost: 6.512033939361572
# processing line: 814
# time cost: 6.283964157104492
# processing line: 815
# time cost: 7.056999683380127
# processing line: 816
# time cost: 7.940000295639038
# processing line: 817
# time cost: 6.821000576019287
# processing line: 818
# time cost: 7.228074550628662
# processing line: 819
# time cost: 7.580029249191284
# processing line: 820
# time cost: 8.442970752716064
# processing line: 821
# time cost: 6.774999141693115
# processing line: 822
# time cost: 6.361403465270996
# processing line: 823
# time cost: 8.093969345092773
# processing line: 824
# time cost: 6.8200294971466064
# processing line: 825
# time cost: 7.194970369338989
# processing line: 826
# time cost: 8.913029670715332
# processing line: 827
# time cost: 7.950000047683716
# processing line: 828
# time cost: 8.458999872207642
# processing line: 829
# time cost: 7.890000343322754
# processing line: 830
# time cost: 6.98600697517395
# processing line: 831
# time cost: 7.125963449478149
# processing line: 832
# time cost: 8.141999244689941
# processing line: 833
# time cost: 5.9660022258758545
# processing line: 834
# time cost: 4.718027353286743
# processing line: 835
# time cost: 7.844000339508057
# processing line: 836
# time cost: 7.135000467300415
# processing line: 837
# time cost: 6.337000608444214
# processing line: 838
# time cost: 7.598999261856079
# processing line: 839
# time cost: 7.761970043182373
# processing line: 840
# time cost: 9.127999544143677
# processing line: 841
# time cost: 6.398000240325928
# processing line: 842
# time cost: 7.556000471115112
# processing line: 843
# time cost: 6.867999076843262
# processing line: 844
# time cost: 7.56602931022644
# processing line: 845
# time cost: 6.4270007610321045
# processing line: 846
# time cost: 7.3829710483551025
# processing line: 847
# time cost: 8.292000532150269
# processing line: 848
# time cost: 8.387969970703125
# processing line: 849
# time cost: 4.756999969482422
# processing line: 850
# time cost: 7.579000473022461
# processing line: 851
# time cost: 6.83299994468689
# processing line: 852
# time cost: 7.020000219345093
# processing line: 853
# time cost: 9.215027570724487
# processing line: 854
# time cost: 7.56897234916687
# processing line: 855
# time cost: 7.759000778198242
# processing line: 856
# time cost: 7.363029479980469
# processing line: 857
# time cost: 7.398970603942871
# processing line: 858
# time cost: 5.889999866485596
# processing line: 859
# time cost: 7.493000268936157
# processing line: 860
# time cost: 7.882000207901001
# processing line: 861
# time cost: 7.371000051498413
# processing line: 862
# time cost: 6.891029357910156
# processing line: 863
# time cost: 6.667970657348633
# processing line: 864
# time cost: 9.573999404907227
# processing line: 865
# time cost: 7.633032321929932
# processing line: 866
# time cost: 6.900340795516968
# processing line: 867
# time cost: 9.79800033569336
# processing line: 868
# time cost: 7.211000442504883
# processing line: 869
# time cost: 7.5679991245269775
# processing line: 870
# time cost: 7.947000503540039
# processing line: 871
# time cost: 8.256000280380249
# processing line: 872
# time cost: 7.386030912399292
# processing line: 873
# time cost: 7.404969692230225
# processing line: 874
# time cost: 7.180999755859375
# processing line: 875
# time cost: 7.624999046325684
# processing line: 876
# time cost: 6.210000038146973
# processing line: 877
# time cost: 6.389000654220581
# processing line: 878
# time cost: 6.980999231338501
# processing line: 879
# time cost: 8.551000118255615
# processing line: 880
# time cost: 8.95500111579895
# processing line: 881
# time cost: 6.813999652862549
# processing line: 882
# time cost: 6.298025608062744
# processing line: 883
# time cost: 7.692999362945557
# processing line: 884
# time cost: 7.195000648498535
# processing line: 885
# time cost: 7.475999593734741
# processing line: 886
# time cost: 7.692007303237915
# processing line: 887
# time cost: 6.073000192642212
# processing line: 888
# time cost: 7.345000267028809
# processing line: 889
# time cost: 7.6060004234313965
# processing line: 890
# time cost: 7.851999759674072
# processing line: 891
# time cost: 6.886999130249023
# processing line: 892
# time cost: 7.2059996128082275
# processing line: 893
# time cost: 7.56999945640564
# processing line: 894
# time cost: 9.973000288009644
# processing line: 895
# time cost: 8.45300030708313
# processing line: 896
# time cost: 6.5929999351501465
# processing line: 897
# time cost: 9.793999671936035
# processing line: 898
# time cost: 7.754000902175903
# processing line: 899
# time cost: 6.863999605178833
# processing line: 900
# time cost: 7.789000034332275
# processing line: 901
# time cost: 6.067029237747192
# processing line: 902
# time cost: 6.936970949172974
# processing line: 903
# time cost: 8.558000326156616
# processing line: 904
# time cost: 6.9790003299713135
# processing line: 905
# time cost: 7.205999851226807
# processing line: 906
# time cost: 8.62600064277649
# processing line: 907
# time cost: 7.334998846054077
# processing line: 908
# time cost: 7.294000148773193
# processing line: 909
# time cost: 6.615000486373901
# processing line: 910
# time cost: 7.84499979019165
# processing line: 911
# time cost: 7.741000175476074
# processing line: 912
# time cost: 7.466000556945801
# processing line: 913
# time cost: 7.494999408721924
# processing line: 914
# time cost: 5.618000507354736
# processing line: 915
# time cost: 7.344000577926636
# processing line: 916
# time cost: 6.948999404907227
# processing line: 917
# time cost: 7.428999185562134
# processing line: 918
# time cost: 9.061000108718872
# processing line: 919
# time cost: 7.203000545501709
# processing line: 920
# time cost: 7.299000024795532
# processing line: 921
# time cost: 6.377999544143677
# processing line: 922
# time cost: 8.772000789642334
# processing line: 923
# time cost: 6.843000173568726
# processing line: 924
# time cost: 8.713000297546387
# processing line: 925
# time cost: 7.339999437332153
# processing line: 926
# time cost: 7.3559393882751465
# processing line: 927
# time cost: 9.916999816894531
# processing line: 928
# time cost: 7.23199987411499
# processing line: 929
# time cost: 8.333000183105469
# processing line: 930
# time cost: 9.579999923706055
# processing line: 931
# time cost: 8.500029802322388
# processing line: 932
# time cost: 7.332969427108765
# processing line: 933
# time cost: 7.547000885009766
# processing line: 934
# time cost: 9.424999237060547
# processing line: 935
# time cost: 7.772000551223755
# processing line: 936
# time cost: 7.076000213623047
# processing line: 937
# time cost: 6.92799973487854
# processing line: 938
# time cost: 7.620000123977661
# processing line: 939
# time cost: 9.34499979019165
# processing line: 940
# time cost: 6.487000226974487
# processing line: 941
# time cost: 7.491999864578247
# processing line: 942
# time cost: 7.142999649047852
# processing line: 943
# time cost: 8.039000034332275
# processing line: 944
# time cost: 7.87399959564209
# processing line: 945
# time cost: 8.078999757766724
# processing line: 946
# time cost: 8.519001483917236
# processing line: 947
# time cost: 8.035209655761719
# processing line: 948
# time cost: 9.027970552444458
# processing line: 949
# time cost: 8.234999418258667
# processing line: 950
# time cost: 6.974000453948975
# processing line: 951
# time cost: 7.298001289367676
# processing line: 952
# time cost: 7.8999998569488525
# processing line: 953
# time cost: 7.4261274337768555
# processing line: 954
# time cost: 7.1279988288879395
# processing line: 955
# time cost: 8.392000198364258
# processing line: 956
# time cost: 7.056000471115112
# processing line: 957
# time cost: 9.760999202728271
# processing line: 958
# time cost: 8.239000082015991
# processing line: 959
# time cost: 7.612000942230225
# processing line: 960
# time cost: 7.595998764038086
# processing line: 961
# time cost: 8.64400053024292
# processing line: 962
# time cost: 7.00700044631958
# processing line: 963
# time cost: 5.80199933052063
# ...
# time cost: 6.485969543457031
# processing line: 1338
# time cost: 6.449002265930176
# processing line: 1339
# time cost: 7.0919976234436035
# processing line: 1340
# time cost: 7.640002489089966
# processing line: 1341
# time cost: 7.377963304519653
# processing line: 1342
# time cost: 6.759002447128296
# processing line: 1343
# time cost: 7.646100759506226
# processing line: 1344
# time cost: 6.936002254486084
# processing line: 1345
# time cost: 6.563000917434692
# processing line: 1346
# time cost: 6.649999141693115
# processing line: 1347
# time cost: 7.878000259399414
# processing line: 1348
# time cost: 6.6741063594818115
# processing line: 1349
# time cost: 6.487000465393066
# processing line: 1350
# time cost: 6.987000942230225
# processing line: 1351
# time cost: 7.152998447418213
# processing line: 1352
# time cost: 6.808000087738037
# processing line: 1353
# time cost: 5.559007883071899
# processing line: 1354
# time cost: 6.496991872787476
# processing line: 1355
# time cost: 7.577999830245972
# processing line: 1356
# time cost: 6.632396697998047
# processing line: 1357
# time cost: 7.641997814178467
# processing line: 1358
# time cost: 7.153000116348267
# processing line: 1359
# time cost: 6.062032461166382
# processing line: 1360
# time cost: 6.4689671993255615
# processing line: 1361
# time cost: 6.9960010051727295
# processing line: 1362
# time cost: 7.565001726150513
# processing line: 1363
# time cost: 6.73999810218811
# processing line: 1364
# time cost: 7.789999485015869
# processing line: 1365
# time cost: 6.502000331878662
# processing line: 1366
# time cost: 8.345000982284546
# processing line: 1367
# time cost: 7.131000995635986
# processing line: 1368
# time cost: 7.009997606277466
# processing line: 1369
# time cost: 7.691001892089844
# processing line: 1370
# time cost: 6.943000078201294
# processing line: 1371
# time cost: 6.563997983932495
# processing line: 1372
# time cost: 6.814000129699707
# processing line: 1373
# time cost: 5.875000715255737
# processing line: 1374
# time cost: 6.991029977798462
# processing line: 1375
# time cost: 5.842969655990601
# processing line: 1376
# time cost: 7.43800163269043
# processing line: 1377
# time cost: 7.936998605728149
# processing line: 1378
# time cost: 6.372030019760132
# processing line: 1379
# time cost: 8.14096975326538
# processing line: 1380
# time cost: 6.85610818862915
# processing line: 1381
# time cost: 7.6080005168914795
# processing line: 1382
# time cost: 7.624999523162842
# processing line: 1383
# time cost: 8.546000957489014
# processing line: 1384
# time cost: 7.743999481201172
# processing line: 1385
# time cost: 5.818000316619873
# processing line: 1386
# time cost: 6.918996810913086
# processing line: 1387
# time cost: 6.446002721786499
# processing line: 1388
# time cost: 6.962971210479736
# processing line: 1389
# time cost: 6.496028661727905
# processing line: 1390
# time cost: 7.1379714012146
# processing line: 1391
# time cost: 5.679035425186157
# processing line: 1392
# time cost: 5.967993259429932
# processing line: 1393
# time cost: 5.993000745773315
# processing line: 1394
# time cost: 5.968042612075806
# processing line: 1395
# time cost: 6.720999717712402
# processing line: 1396
# time cost: 7.505997657775879
# processing line: 1397
# time cost: 6.621002197265625
# processing line: 1398
# time cost: 6.513000011444092
# processing line: 1399
# time cost: 9.53902816772461
# processing line: 1400
# time cost: 6.368999719619751
# processing line: 1401
# time cost: 7.429972887039185
# processing line: 1402
# time cost: 7.493999242782593
# processing line: 1403
# time cost: 6.7750256061553955
# processing line: 1404
# time cost: 6.427006959915161
# processing line: 1405
# time cost: 6.354995250701904
# processing line: 1406
# time cost: 6.405001163482666
# processing line: 1407
# time cost: 7.157000780105591
# processing line: 1408
# time cost: 6.969998598098755
# processing line: 1409
# time cost: 7.590001344680786
# processing line: 1410
# time cost: 6.253999948501587
# processing line: 1411
# time cost: 8.099239110946655
# processing line: 1412
# time cost: 6.23900294303894
# processing line: 1413
# time cost: 7.327997922897339
# processing line: 1414
# time cost: 6.172999382019043
# processing line: 1415
# time cost: 7.9690046310424805
# processing line: 1416
# time cost: 6.75520920753479
# processing line: 1417
# time cost: 8.581028938293457
# processing line: 1418
# time cost: 6.438971042633057
# processing line: 1419
# time cost: 6.50600004196167
# processing line: 1420
# time cost: 8.254000425338745
# processing line: 1421
# time cost: 6.99299955368042
# processing line: 1422
# time cost: 8.079998016357422
# processing line: 1423
# time cost: 7.020000219345093
# processing line: 1424
# time cost: 7.138031244277954
# processing line: 1425
# time cost: 6.698998928070068
# processing line: 1426
# time cost: 7.127971649169922
# processing line: 1427
# time cost: 7.390027761459351
# processing line: 1428
# time cost: 6.9740002155303955
# processing line: 1429
# time cost: 7.20697021484375
# processing line: 1430
# time cost: 6.999001979827881
# processing line: 1431
# time cost: 6.299999475479126
# processing line: 1432
# time cost: 6.537000417709351
# processing line: 1433
# time cost: 7.143999338150024
# processing line: 1434
# time cost: 7.254997968673706
# processing line: 1435
# time cost: 7.370113849639893
# processing line: 1436
# time cost: 7.20703125
# processing line: 1437
# time cost: 6.475028038024902
# processing line: 1438
# time cost: 6.520970106124878
# processing line: 1439
# time cost: 5.75700044631958
# processing line: 1440
# time cost: 6.744001865386963
# processing line: 1441
# time cost: 7.462029695510864
# processing line: 1442
# time cost: 7.3039679527282715
# processing line: 1443
# time cost: 6.5490028858184814
# processing line: 1444
# time cost: 7.029034614562988
# processing line: 1445
# time cost: 7.221995830535889
# processing line: 1446
# time cost: 6.64596962928772
# processing line: 1447
# time cost: 6.110999584197998
# processing line: 1448
# time cost: 9.118000268936157
# processing line: 1449
# time cost: 6.4049999713897705
# processing line: 1450
# time cost: 6.880028009414673
# processing line: 1451
# time cost: 8.17497181892395
# processing line: 1452
# time cost: 6.088999271392822
# processing line: 1453
# time cost: 10.23399829864502
# processing line: 1454
# time cost: 8.210002660751343
# processing line: 1455
# time cost: 6.52499794960022
# processing line: 1456
# time cost: 6.815029859542847
# processing line: 1457
# time cost: 9.073972225189209
# processing line: 1458
# time cost: 6.326997995376587
# processing line: 1459
# time cost: 8.009999752044678
# processing line: 1460
# time cost: 7.559002876281738
# processing line: 1461
# time cost: 6.490026950836182
# processing line: 1462
# time cost: 10.141972303390503
# processing line: 1463
# time cost: 7.36899995803833
# processing line: 1464
# time cost: 6.501997232437134
# processing line: 1465
# time cost: 6.185002565383911
# processing line: 1466
# time cost: 6.687000036239624
# processing line: 1467
# time cost: 5.754028081893921
# processing line: 1468
# time cost: 6.795000076293945
# processing line: 1469
# time cost: 7.258971929550171
# processing line: 1470
# time cost: 7.154999017715454
# processing line: 1471
# time cost: 7.419001340866089
# processing line: 1472
# time cost: 9.220027923583984
# processing line: 1473
# time cost: 6.896972179412842
# processing line: 1474
# time cost: 7.908998489379883
# processing line: 1475
# time cost: 6.825001239776611
# processing line: 1476
# time cost: 5.526028633117676
# processing line: 1477
# time cost: 7.309971809387207
# processing line: 1478
# time cost: 6.746999263763428
# processing line: 1479
# time cost: 6.569000720977783
# processing line: 1480
# time cost: 6.7120280265808105
# processing line: 1481
# time cost: 6.804971933364868
# processing line: 1482
# time cost: 8.236035585403442
# processing line: 1483
# time cost: 8.117963790893555
# processing line: 1484
# time cost: 6.681028127670288
# processing line: 1485
# time cost: 6.19599986076355
# processing line: 1486
# time cost: 6.299970626831055
# processing line: 1487
# time cost: 7.992020845413208
# processing line: 1488
# time cost: 5.510009050369263
# processing line: 1489
# time cost: 6.140971899032593
# processing line: 1490
# time cost: 6.56803035736084
# processing line: 1491
# time cost: 7.492969512939453
# processing line: 1492
# time cost: 7.941999435424805
# processing line: 1493
# time cost: 6.868001461029053
# processing line: 1494
# time cost: 7.212999582290649
# processing line: 1495
# time cost: 6.987026929855347
# processing line: 1496
# time cost: 8.417972326278687
# processing line: 1497
# time cost: 6.807998180389404
# processing line: 1498
# time cost: 7.125001430511475
# processing line: 1499
# time cost: 6.957028150558472
# processing line: 1500
# time cost: 7.285970211029053
# processing line: 1501
# time cost: 6.223256349563599
# processing line: 1502
# time cost: 8.54699182510376
# processing line: 1503
# time cost: 8.085999965667725
# processing line: 1504
# time cost: 6.930002689361572
# processing line: 1505
# time cost: 8.413999795913696
# processing line: 1506
# time cost: 7.058002710342407
# processing line: 1507
# time cost: 5.848994016647339
# processing line: 1508
# time cost: 7.786982536315918
# processing line: 1509
# time cost: 7.298017740249634
# processing line: 1510
# time cost: 6.788999319076538
# processing line: 1511
# time cost: 6.242003679275513
# processing line: 1512
# time cost: 6.584004163742065
# processing line: 1513
# time cost: 6.8899924755096436
# processing line: 1514
# time cost: 8.03200101852417
# processing line: 1515
# time cost: 6.529044151306152
# processing line: 1516
# time cost: 7.00400185585022
# processing line: 1517
# time cost: 8.279998540878296
# processing line: 1518
# time cost: 7.5350022315979
# processing line: 1519
# time cost: 7.187026739120483
# processing line: 1520
# time cost: 6.616000175476074
# processing line: 1521
# time cost: 8.707972764968872
# processing line: 1522
# time cost: 8.36699914932251
# processing line: 1523
# time cost: 6.759998321533203
# processing line: 1524
# time cost: 7.3410303592681885
# processing line: 1525
# time cost: 8.173972129821777
# processing line: 1526
# time cost: 6.094998359680176
# processing line: 1527
# time cost: 7.069001197814941
# processing line: 1528
# time cost: 6.894999742507935
# processing line: 1529
# time cost: 7.196000337600708
# processing line: 1530
# time cost: 7.408999919891357
# processing line: 1531
# time cost: 6.547000169754028
# processing line: 1532
# time cost: 7.467000246047974
# processing line: 1533
# time cost: 6.999027729034424
# processing line: 1534
# time cost: 5.919970273971558
# processing line: 1535
# time cost: 7.698002099990845
# processing line: 1536
# time cost: 6.99010157585144
# processing line: 1537
# time cost: 6.545000314712524
# processing line: 1538
# time cost: 6.871969938278198
# processing line: 1539
# time cost: 7.126031875610352
# processing line: 1540
# time cost: 7.71796989440918
# processing line: 1541
# time cost: 6.8250274658203125
# processing line: 1542
# time cost: 7.806999921798706
# processing line: 1543
# time cost: 7.063971757888794
# processing line: 1544
# time cost: 7.831028699874878
# processing line: 1545
# time cost: 7.85099983215332
# processing line: 1546
# time cost: 6.67600154876709
# processing line: 1547
# time cost: 7.900041818618774
# processing line: 1548
# time cost: 10.627971172332764
# processing line: 1549
# time cost: 7.815030336380005
# processing line: 1550
# time cost: 6.772998094558716
# processing line: 1551
# time cost: 6.790052890777588
# processing line: 1552
# time cost: 7.0929999351501465
# processing line: 1553
# time cost: 5.604031801223755
# processing line: 1554
# time cost: 8.935996532440186
# processing line: 1555
# time cost: 6.934046268463135
# processing line: 1556
# time cost: 6.5720274448394775
# processing line: 1557
# time cost: 8.129006624221802
# processing line: 1558
# time cost: 7.930996417999268
# processing line: 1559
# time cost: 6.102541923522949
# processing line: 1560
# time cost: 7.523972034454346
# processing line: 1561
# time cost: 6.863998174667358
# processing line: 1562
# time cost: 7.1680357456207275
# processing line: 1563
# time cost: 6.483994245529175
# processing line: 1564
# time cost: 7.24899959564209
# processing line: 1565
# time cost: 7.0899717807769775
# processing line: 1566
# time cost: 7.4500274658203125
# processing line: 1567
# time cost: 8.304001331329346
# processing line: 1568
# time cost: 7.277971506118774
# processing line: 1569
# time cost: 8.527999877929688
# processing line: 1570
# time cost: 7.0350341796875
# processing line: 1571
# time cost: 7.053994655609131
# processing line: 1572
# time cost: 7.648998975753784
# processing line: 1573
# time cost: 9.900969982147217
# processing line: 1574
# time cost: 7.4040303230285645
# processing line: 1575
# time cost: 6.634999990463257
# processing line: 1576
# time cost: 5.988003730773926
# processing line: 1577
# time cost: 7.834967851638794
# processing line: 1578
# time cost: 6.180028676986694
# processing line: 1579
# time cost: 7.243000268936157
# processing line: 1580
# time cost: 7.473971366882324
# processing line: 1581
# time cost: 6.103028059005737
# processing line: 1582
# time cost: 7.04997181892395
# processing line: 1583
# time cost: 6.202028512954712
# processing line: 1584
# time cost: 6.944999694824219
# processing line: 1585
# time cost: 5.954001426696777
# processing line: 1586
# time cost: 7.220970392227173
# processing line: 1587
# time cost: 6.6430277824401855
# processing line: 1588
# time cost: 6.538015365600586
# processing line: 1589
# time cost: 7.497999906539917
# processing line: 1590
# time cost: 7.921001195907593
# processing line: 1591
# time cost: 8.649999856948853
# processing line: 1592
# time cost: 5.78399920463562
# processing line: 1593
# time cost: 5.6600000858306885
# processing line: 1594
# time cost: 8.09299921989441
# processing line: 1595
# time cost: 8.098000288009644
# processing line: 1596
# time cost: 7.608000040054321
# processing line: 1597
# time cost: 5.891999959945679
# processing line: 1598
# time cost: 7.615000486373901
# processing line: 1599
# time cost: 6.395031452178955
# processing line: 1600
# time cost: 6.676969528198242
# processing line: 1601
# time cost: 6.917999267578125
# processing line: 1602
# time cost: 6.533999443054199
# processing line: 1603
# time cost: 7.921001195907593
# processing line: 1604
# time cost: 7.303999900817871
# processing line: 1605
# time cost: 6.8459999561309814
# processing line: 1606
# time cost: 7.261999845504761
# processing line: 1607
# time cost: 6.625999927520752
# processing line: 1608
# time cost: 7.398999929428101
# processing line: 1609
# time cost: 5.466030120849609
# processing line: 1610
# time cost: 7.638969898223877
# processing line: 1611
# time cost: 9.950999975204468
# processing line: 1612
# time cost: 7.363000154495239
# processing line: 1613
# time cost: 6.618000268936157
# processing line: 1614
# time cost: 8.944999694824219
# processing line: 1615
# time cost: 5.4920313358306885
# processing line: 1616
# time cost: 6.609969854354858
# processing line: 1617
# time cost: 6.524998903274536
# processing line: 1618
# time cost: 7.610999822616577
# processing line: 1619
# time cost: 6.683000087738037
# processing line: 1620
# time cost: 6.876999855041504
# processing line: 1621
# time cost: 6.420029878616333
# processing line: 1622
# time cost: 7.702971458435059
# processing line: 1623
# time cost: 6.471998929977417
# processing line: 1624
# time cost: 7.254999876022339
# processing line: 1625
# time cost: 7.0320000648498535
# processing line: 1626
# time cost: 7.597999811172485
# processing line: 1627
# time cost: 6.707032203674316
# processing line: 1628
# time cost: 7.696967601776123
# processing line: 1629
# time cost: 6.598000526428223
# processing line: 1630
# time cost: 7.114999771118164
# processing line: 1631
# time cost: 6.304999828338623
# processing line: 1632
# time cost: 5.973999977111816
# processing line: 1633
# time cost: 4.560001373291016
# processing line: 1634
# time cost: 10.244999170303345
# processing line: 1635
# time cost: 6.908000707626343
# processing line: 1636
# time cost: 6.481001377105713
# processing line: 1637
# time cost: 7.328969955444336
# processing line: 1638
# time cost: 8.553000450134277
# processing line: 1639
# time cost: 8.081000089645386
# processing line: 1640
# time cost: 6.569999694824219
# processing line: 1641
# time cost: 7.059000492095947
# processing line: 1642
# time cost: 6.532999515533447
# processing line: 1643
# time cost: 8.017029285430908
# processing line: 1644
# time cost: 7.780970811843872
# processing line: 1645
# time cost: 7.108210563659668
# processing line: 1646
# time cost: 7.715998411178589
# processing line: 1647
# time cost: 5.9330010414123535
# processing line: 1648
# time cost: 9.430003643035889
# processing line: 1649
# time cost: 6.894995450973511
# processing line: 1650
# time cost: 8.132000207901001

# %%
### 文本转化为句子
data_all = data_wnt4 + data_ca
data_cls = []
for item in data_all:
    item_sent = []
    for line in item:
        arr = line.split('. ')
        for sent in arr:
            sent = sent.strip()
            if sent != '':
                if sent[-1] != '.':
                    item_sent.append(sent + '.')
                else:
                    item_sent.append(sent)
    data_cls.append(item_sent)

# %%
with open(r'D:\项目资料\基因表达\通路分析\gene_data_sentences.txt', 'w') as f:
    for item in data_cls:
        for sent in item:
            f.write('%s\n' % sent)

# %% [markdown]
# ### 选择基因

# %%
word_list = []
for item in data_all:
    item_str = ' '.join(item)
    word_arr = item_str.replace(',', '').replace('.', '').split(' ')
    word_list.extend(list(set(word_arr)))
word_list = list(set(word_list))
print(len(word_list))
word_str = ' '.join(word_list)
# Out:
# 37487

# %%
gr = '([ ]|^)' + 'NDRG1'.replace('.', '\.').replace('-', '\-') + '([ ,]|$)'
s = 'Rapid detection of the hypoxia-regulated CA-IX and NDRG1 gene expression in different glioblastoma cells in vitro.'
re.search(gr, word_str, re.I)
# Out:
# <re.Match object; span=(197401, 197408), match=' NDRG1 '>

# %%
data_gene_names = []
with open(file_gene_path) as f:
    for line in f.readlines():
        data_gene_names.append(line.strip())

gene_sel = []
for idx, gene_name in enumerate(data_gene_names):
    if idx % 100 == 0:
        print(idx)
    gene_name_regex = '([ ]|^)' + gene_name.replace('.', '\.').replace('-', '\-') + '([ ,]|$)'
    if re.search(gene_name_regex, word_str, re.I):
        print(gene_name, 'in')
        gene_sel.append(gene_name)
gene_sel.append('Carbonic anhydrase IX')
# Out:
# 0
# 100
# DVL1 in
# PRDM16 in
# 200
# 300
# ENO1 in
# CA6 in
# MIR34A in
# CTNNBIP1 in
# MTOR in
# 400
# 500
# SDHB in
# 600
# PADI4 in
# 700
# WNT4 in
# EPHB2 in
# 800
# RHD in
# ARID1A in
# SFN in
# 900
# 1000
# HPCA in
# 1100
# GJB5 in
# 1200
# RSPO1 in
# 1300
# SLC2A1 in
# CDC20 in
# 1400
# PTPRF in
# 1500
# CYP4B1 in
# 1600
# LRP8 in
# 1700
# C8B in
# JUN in
# 1800
# 1900
# WLS in
# 2000
# DNAJB4 in
# 2100
# 2200
# 2300
# F3 in
# 2400
# COL11A1 in
# 2500
# MYBPHL in
# GSTM1 in
# CSF1 in
# 2600
# WNT2B in
# RHOC in
# 2700
# NRAS in
# NGF in
# 2800
# HSD3B1 in
# NOTCH2 in
# 2900
# PIAS3 in
# TXNIP in
# 3000
# 3100
# 3200
# S100A10 in
# S100A11 in
# CRNN in
# S100A9 in
# S100A6 in
# 3300
# S100A4 in
# S100A1 in
# RAB13 in
# SHE in
# 3400
# MUC1 in
# SYT11 in
# RAB25 in
# NES in
# HDGF in
# 3500
# PRCC in
# CD1D in
# AIM2 in
# 3600
# CRP in
# SDHC in
# 3700
# RGS5 in
# 3800
# F5 in
# KIFAP3 in
# 3900
# 4000
# TNR in
# 4100
# LAMC2 in
# 4200
# PDC in
# 4300
# LHX9 in
# ELF3 in
# 4400
# REN in
# 4500
# CD55 in
# CD46 in
# CD34 in
# 4600
# HSD11B1 in
# IRF6 in
# ATF3 in
# 4700
# TGFB2 in
# 4800
# ENAH in
# LEFTY2 in
# 4900
# WNT9A in
# WNT3A in
# 5000
# RHOU in
# RAB4A in
# AGT in
# 5100
# 5200
# FH in
# AKT3 in
# 5300
# NLRP3 in
# 5400
# 5500
# 5600
# RRM2 in
# ROCK2 in
# GREB1 in
# 5700
# OSR1 in
# SDC1 in
# GDF7 in
# 5800
# 5900
# CAD in
# ALK in
# 6000
# XDH in
# 6100
# MTA3 in
# 6200
# SIX3 in
# SIX2 in
# EPCAM in
# MSH2 in
# MSH6 in
# 6300
# FSHR in
# EFEMP1 in
# 6400
# XPO1 in
# 6500
# 6600
# FIGLA in
# 6700
# HK2 in
# 6800
# TCF7L1 in
# 6900
# 7000
# 7100
# 7200
# TSGA10 in
# 7300
# POU3F3 in
# 7400
# 7500
# PAX8 in
# FAM138B in
# 7600
# INHBB in
# GLI2 in
# 7700
# 7800
# 7900
# CXCR4 in
# 8000
# LRP1B in
# ZEB2 in
# 8100
# KIF5C in
# TNFAIP6 in
# NR4A2 in
# 8200
# FAP in
# 8300
# LRP2 in
# DLX2 in
# 8400
# PDK1 in
# OLA1 in
# HOXD11 in
# 8500
# NFE2L2 in
# FRZB in
# 8600
# GLS in
# STAT1 in
# 8700
# PCGEM1 in
# 8800
# CLK1 in
# 8900
# CD28 in
# CTLA4 in
# CPO in
# FZD5 in
# 9000
# IDH1 in
# ERBB4 in
# ATIC in
# FN1 in
# 9100
# CXCR2 in
# WNT6 in
# WNT10A in
# 9200
# DES in
# INHA in
# 9300
# COL4A4 in
# CCL20 in
# 9400
# INPP5D in
# 9500
# 9600
# 9700
# 9800
# VHL in
# WNT7A in
# 9900
# EAF1 in
# 10000
# 10100
# MLH1 in
# 10200
# CTNNB1 in
# CCK in
# 10300
# CCR1 in
# 10400
# CDC25A in
# CAMP in
# SLC26A6 in
# 10500
# GPX1 in
# RHOA in
# CAMKV in
# RASSF1 in
# 10600
# TLR9 in
# BAP1 in
# STAB1 in
# PBRM1 in
# ITIH4 in
# PRKCD in
# 10700
# WNT5A in
# FHIT in
# PTPRG in
# 10800
# MITF in
# 10900
# 11000
# 11100
# 11200
# CD47 in
# 11300
# 11400
# CD80 in
# GSK3B in
# CD86 in
# 11500
# 11600
# RHO in
# 11700
# 11800
# FOXL2 in
# RBP1 in
# ATR in
# 11900
# CP in
# WWTR1 in
# 12000
# GPR87 in
# 12100
# SCHIP1 in
# 12200
# SI in
# BCHE in
# 12300
# 12400
# ZMAT3 in
# PIK3CA in
# SOX2 in
# 12500
# DVL3 in
# 12600
# SST in
# FGF12 in
# 12700
# LINC00887 in
# MUC4 in
# TFRC in
# 12800
# 12900
# FGFR3 in
# 13000
# PPP2R2C in
# S100P in
# 13100
# 13200
# PROM1 in
# 13300
# SLC34A2 in
# 13400
# RFC1 in
# 13500
# TEC in
# 13600
# PDGFRA in
# KIT in
# KDR in
# CLOCK in
# 13700
# REST in
# 13800
# SULT1E1 in
# 13900
# MUC7 in
# MOB1B in
# SLC4A4 in
# GC in
# AFP in
# AREG in
# CXCL9 in
# CXCL10 in
# 14000
# CXCL13 in
# 14100
# SPP1 in
# 14200
# 14300
# 14400
# LEF1 in
# EGF in
# 14500
# 14600
# IL2 in
# FGF2 in
# SPRY1 in
# 14700
# SLC7A11 in
# 14800
# MAML3 in
# 14900
# 15000
# TLR2 in
# SFRP2 in
# 15100
# 15200
# HAND2 in
# 15300
# 15400
# TLR3 in
# 15500
# SDHA in
# TERT in
# 15600
# MTRR in
# 15700
# 15800
# 15900
# 16000
# NPR3 in
# AMACR in
# PRLR in
# 16100
# GDNF in
# C9 in
# C7 in
# C6 in
# 16200
# FGF10 in
# ESM1 in
# 16300
# GZMA in
# MAP3K1 in
# 16400
# PIK3R1 in
# 16500
# CCNB1 in
# TNPO1 in
# 16600
# 16700
# DHFR in
# SSBP2 in
# 16800
# 16900
# NR2F1 in
# CAST in
# 17000
# 17100
# APC in
# MCC in
# ATG12 in
# 17200
# LOX in
# 17300
# 17400
# GDF9 in
# TCF7 in
# PITX1 in
# 17500
# WNT8A in
# 17600
# SLC4A9 in
# 17700
# 17800
# 17900
# PDGFRB in
# CAMK2A in
# SPARC in
# 18000
# EBF1 in
# 18100
# FOXI1 in
# 18200
# 18300
# FGFR4 in
# PROP1 in
# 18400
# RACK1 in
# 18500
# IRF4 in
# 18600
# BMP6 in
# 18700
# EDN1 in
# 18800
# PRL in
# 18900
# 19000
# 19100
# MICE in
# 19200
# 19300
# TNF in
# C2 in
# 19400
# AGER in
# NOTCH4 in
# 19500
# SRPK1 in
# ETV7 in
# 19600
# CDKN1A in
# 19700
# TFEB in
# SRF in
# 19800
# VEGFA in
# RUNX2 in
# CD2AP in
# 19900
# 20000
# 20100
# 20200
# 20300
# 20400
# 20500
# CD24 in
# SOBP in
# FOXO3 in
# 20600
# 20700
# 20800
# RSPO3 in
# ARG1 in
# 20900
# MYB in
# 21000
# CITED2 in
# 21100
# LATS1 in
# 21200
# ESR1 in
# OPRM1 in
# 21300
# SOD2 in
# SOD2 in
# WTAP in
# 21400
# PLG in
# RNASET2 in
# 21500
# DLL1 in
# 21600
# 21700
# PMS2 in
# RAC1 in
# 21800
# TWIST1 in
# 21900
# IL6 in
# SNX10 in
# 22000
# HOXA10 in
# HOXA11 in
# 22100
# AQP1 in
# 22200
# SFRP4 in
# 22300
# INHBA in
# GLI3 in
# 22400
# IGFBP1 in
# IGFBP3 in
# 22500
# EGFR in
# PSPH in
# 22600
# 22700
# 22800
# 22900
# FZD9 in
# CCL24 in
# POR in
# 23000
# FGL2 in
# 23100
# HGF in
# ABCB1 in
# 23200
# CDK6 in
# HEPACAM2 in
# PON1 in
# 23300
# MCM7 in
# 23400
# EPO in
# ACHE in
# SERPINE1 in
# 23500
# 23600
# NRCAM in
# DOCK4 in
# TES in
# MET in
# 23700
# WNT2 in
# CFTR in
# WNT16 in
# 23800
# SMO in
# 23900
# 24000
# 24100
# BRAF in
# 24200
# 24300
# NOBOX in
# EZH2 in
# 24400
# GIMAP7 in
# GIMAP6 in
# 24500
# SHH in
# 24600
# CD99 in
# STS in
# 24700
# HCCS in
# CA5B in
# 24800
# 24900
# NR0B1 in
# 25000
# 25100
# RGN in
# TIMP1 in
# 25200
# PORCN in
# WAS in
# TFE3 in
# FOXP3 in
# 25300
# BMP15 in
# 25400
# 25500
# MSN in
# AR in
# 25600
# MED12 in
# CXCR3 in
# 25700
# PGK1 in
# 25800
# 25900
# 26000
# 26100
# 26200
# 26300
# XIAP in
# 26400
# 26500
# 26600
# 26700
# FMR1 in
# 26800
# 26900
# L1CAM in
# 27000
# ANGPT2 in
# 27100
# DEFB1 in
# 27200
# 27300
# GATA4 in
# 27400
# 27500
# HR in
# LOXL2 in
# STC1 in
# 27600
# BNIP3L in
# CLU in
# FZD3 in
# 27700
# 27800
# STAR in
# FGFR1 in
# SFRP1 in
# ANK1 in
# 27900
# 28000
# MCM4 in
# SNAI2 in
# 28100
# PLAG1 in
# CA8 in
# CHD7 in
# 28200
# ADHFE1 in
# MYBL1 in
# 28300
# PRDM14 in
# EYA1 in
# MSC in
# TRPA1 in
# 28400
# 28500
# CA1 in
# CA3 in
# CA2 in
# 28600
# CCNE2 in
# 28700
# STK3 in
# 28800
# FZD6 in
# CTHRC1 in
# 28900
# RSPO2 in
# 29000
# 29100
# MYC in
# PVT1 in
# 29200
# NDRG1 in
# 29300
# ARC in
# PSCA in
# CYP11B2 in
# 29400
# 29500
# 29600
# 29700
# RPS6 in
# 29800
# CDKN2A in
# 29900
# DDX58 in
# 30000
# CA9 in
# 30100
# 30200
# 30300
# 30400
# 30500
# ALDH1A1 in
# 30600
# GOLM1 in
# 30700
# ROR2 in
# 30800
# FBP1 in
# 30900
# TGFBR1 in
# NR4A3 in
# 31000
# KLF4 in
# 31100
# 31200
# TNC in
# TLR4 in
# 31300
# NR5A1 in
# HSPA5 in
# 31400
# CDK9 in
# LCN2 in
# SET in
# PHYHD1 in
# 31500
# PTGES in
# SETX in
# TTF1 in
# TSC1 in
# 31600
# 31700
# NOTCH1 in
# NDOR1 in
# 31800
# IFITM3 in
# HRAS in
# 31900
# CD151 in
# MUC6 in
# MUC2 in
# MUC5AC in
# MUC5B in
# H19 in
# IGF2 in
# TH in
# 32000
# 32100
# 32200
# ILK in
# 32300
# ADM in
# DKK3 in
# PTH in
# 32400
# SPON1 in
# LDHA in
# 32500
# 32600
# PAX6 in
# WT1 in
# CD59 in
# 32700
# CAT in
# CD44 in
# 32800
# CD82 in
# F2 in
# 32900
# 33000
# 33100
# 33200
# 33300
# CD5 in
# 33400
# BAD in
# 33500
# MEN1 in
# NEAT1 in
# MALAT1 in
# 33600
# PC in
# 33700
# AIP in
# GSTP1 in
# LRP5 in
# GAL in
# 33800
# CCND1 in
# FGF19 in
# 33900
# 34000
# WNT11 in
# 34100
# PRSS23 in
# 34200
# FZD4 in
# 34300
# 34400
# PGR in
# YAP1 in
# MMP7 in
# MMP1 in
# MMP12 in
# 34500
# SLN in
# ATM in
# FDX1 in
# 34600
# CRYAB in
# SDHD in
# PTS in
# NNMT in
# 34700
# 34800
# 34900
# 35000
# ETS1 in
# 35100
# 35200
# 35300
# GATA3 in
# 35400
# VIM in
# 35500
# BMI1 in
# 35600
# BAMBI in
# 35700
# ZEB1 in
# 35800
# 35900
# RET in
# CXCL12 in
# 36000
# MAPK8 in
# WDFY4 in
# 36100
# DKK1 in
# CDK1 in
# 36200
# SIRT1 in
# TET1 in
# SRGN in
# HK1 in
# 36300
# NODAL in
# SPOCK2 in
# DDIT4 in
# ECD in
# 36400
# 36500
# 36600
# BMPR1A in
# GLUD1 in
# PTEN in
# 36700
# ACTA2 in
# FAS in
# TNKS2 in
# 36800
# 36900
# SFRP5 in
# GOT1 in
# ABCC2 in
# WNT8B in
# PAX2 in
# FGF8 in
# 37000
# LDB1 in
# NFKB2 in
# 37100
# PDCD4 in
# ACSL5 in
# 37200
# EMX2 in
# 37300
# FGFR2 in
# DHX32 in
# 37400
# BNIP3 in
# 37500
# CYP2E1 in
# WNK1 in
# WNT5B in
# FBXL14 in
# 37600
# FOXM1 in
# VWF in
# LTBR in
# GAPDH in
# 37700
# CD4 in
# CDCA3 in
# NANOG in
# 37800
# 37900
# LRP6 in
# CDKN1B in
# 38000
# GPRC5A in
# 38100
# KRAS in
# 38200
# 38300
# 38400
# 38500
# VDR in
# 38600
# WNT10B in
# WNT1 in
# DHH in
# 38700
# 38800
# SP1 in
# HOTAIR in
# 38900
# RDH5 in
# CD63 in
# CDK2 in
# ERBB3 in
# 39000
# STAT6 in
# NDUFA4L2 in
# GLI1 in
# DDIT3 in
# CDK4 in
# 39100
# 39200
# HMGA2 in
# CAND1 in
# IFNG in
# MDM2 in
# CPM in
# 39300
# LGR5 in
# 39400
# NTS in
# 39500
# DUSP6 in
# 39600
# 39700
# IGF1 in
# 39800
# ISCU in
# 39900
# 40000
# PTPN11 in
# SDS in
# 40100
# 40200
# ORAI1 in
# 40300
# UBC in
# 40400
# FZD10 in
# 40500
# POLE in
# 40600
# LATS2 in
# 40700
# FGF9 in
# 40800
# CDX2 in
# FLT1 in
# HMGB1 in
# 40900
# BRCA2 in
# SOHLH2 in
# SMAD9 in
# 41000
# FOXO1 in
# TNFSF11 in
# 41100
# RB1 in
# 41200
# CAB39L in
# DLEU1 in
# 41300
# 41400
# 41500
# 41600
# 41700
# 41800
# 41900
# MCF2L in
# 42000
# 42100
# APEX1 in
# ANG in
# 42200
# 42300
# MMP14 in
# PRMT5 in
# 42400
# 42500
# 42600
# FOXA1 in
# 42700
# 42800
# BMP4 in
# 42900
# DAAM1 in
# 43000
# HIF1A in
# 43100
# MAX in
# ARG2 in
# 43200
# 43300
# 43400
# 43500
# 43600
# GSC in
# 43700
# 43800
# 43900
# 44000
# AKT1 in
# 44100
# 44200
# 44300
# 44400
# SNHG14 in
# 44500
# 44600
# 44700
# GREM1 in
# 44800
# 44900
# RAD51 in
# DLL4 in
# 45000
# 45100
# SHC4 in
# 45200
# RAB27A in
# 45300
# ADAM10 in
# CCNB2 in
# 45400
# ANXA2 in
# CA12 in
# 45500
# ANKDD1A in
# 45600
# 45700
# CYP11A1 in
# 45800
# CSPG4 in
# 45900
# 46000
# 46100
# MFGE8 in
# 46200
# IDH2 in
# PRC1 in
# 46300
# IGF1R in
# 46400
# 46500
# AXIN1 in
# 46600
# TSC2 in
# PKD1 in
# PGP in
# 46700
# 46800
# 46900
# 47000
# 47100
# 47200
# GP2 in
# 47300
# PLK1 in
# CHP2 in
# 47400
# 47500
# MVP in
# ALDOA in
# 47600
# 47700
# 47800
# 47900
# 48000
# NKD1 in
# SALL1 in
# 48100
# MMP2 in
# MT1G in
# CCL22 in
# 48200
# KIFC3 in
# 48300
# CA7 in
# CTCF in
# 48400
# NFATC3 in
# CDH3 in
# CDH1 in
# CYB5B in
# NFAT5 in
# NQO1 in
# 48500
# TAT in
# HP in
# 48600
# 48700
# ADAMTS18 in
# 48800
# 48900
# FOXC2 in
# MVD in
# 49000
# 49100
# TRPV1 in
# 49200
# CXCL16 in
# 49300
# DVL2 in
# 49400
# CD68 in
# TP53 in
# 49500
# 49600
# TRIM16 in
# 49700
# SHMT1 in
# 49800
# 49900
# 50000
# FOXN1 in
# 50100
# CPD in
# 50200
# EVI2B in
# 50300
# 50400
# TBC1D3 in
# 50500
# ERBB2 in
# TOP2A in
# 50600
# 50700
# STAT5A in
# STAT3 in
# BRCA1 in
# 50800
# FZD2 in
# GFAP in
# 50900
# WNT3 in
# WNT9B in
# 51000
# NGFR in
# 51100
# COL1A1 in
# TOB1 in
# CA10 in
# 51200
# MMD in
# NOG in
# COIL in
# 51300
# CA4 in
# 51400
# ACE in
# PECAM1 in
# 51500
# AXIN2 in
# PRKCA in
# 51600
# PRKAR1A in
# SOX9 in
# 51700
# FDXR in
# 51800
# 51900
# CBX2 in
# CBX4 in
# 52000
# FASN in
# SLC16A3 in
# 52100
# 52200
# 52300
# 52400
# 52500
# IMPACT in
# 52600
# CDH2 in
# DSG2 in
# TTR in
# 52700
# 52800
# SMAD2 in
# 52900
# SMAD4 in
# DCC in
# TCF4 in
# 53000
# GRP in
# PMAIP1 in
# 53100
# BCL2 in
# 53200
# 53300
# NFATC1 in
# CSNK2A1 in
# 53400
# PRNP in
# 53500
# PCNA in
# BMP2 in
# PLCB1 in
# JAG1 in
# 53600
# 53700
# INSM1 in
# FOXA2 in
# 53800
# 53900
# ID1 in
# BCL2L1 in
# 54000
# E2F1 in
# GDF5 in
# 54100
# NFS1 in
# TGM2 in
# 54200
# 54300
# STK4 in
# MMP9 in
# CD40 in
# 54400
# SNAI1 in
# 54500
# BMP7 in
# 54600
# GNAS in
# 54700
# 54800
# PALM in
# 54900
# TCF3 in
# AMH in
# 55000
# SIRT6 in
# EBI3 in
# 55100
# C3 in
# 55200
# ANGPTL4 in
# 55300
# 55400
# SPC24 in
# EPOR in
# 55500
# BEST2 in
# JUNB in
# 55600
# NOTCH3 in
# BRD4 in
# 55700
# KLF2 in
# PGLS in
# 55800
# JUND in
# GDF15 in
# COPE in
# 55900
# 56000
# 56100
# CCNE1 in
# 56200
# HPN in
# 56300
# 56400
# MAP4K1 in
# 56500
# DLL3 in
# FCGBP in
# AKT2 in
# 56600
# MIA in
# AXL in
# TGFB1 in
# PAFAH1B3 in
# 56700
# CEACAM1 in
# 56800
# PVR in
# APOE in
# ERCC1 in
# 56900
# HIF3A in
# PRKD2 in
# BBC3 in
# 57000
# BAX in
# 57100
# AKT1S1 in
# KLK6 in
# KLK7 in
# 57200
# 57300
# 57400
# 57500
# IL11 in
# 57600
# 57700
# 57800
# SRY in
# 57900
# 58000
# 58100
# 58200
# 58300
# 58400
# BID in
# 58500
# 58600
# MAPK1 in
# 58700
# 58800
# SMARCB1 in
# MIF in
# 58900
# XBP1 in
# 59000
# EWSR1 in
# LIF in
# 59100
# C22orf42 in
# TIMP3 in
# 59200
# MB in
# APOL2 in
# 59300
# SOX10 in
# BAIAP2L2 in
# PDGFB in
# ATF4 in
# 59400
# 59500
# PRR5 in
# WNT7B in
# 59600
# 59700
# 59800
# 59900
# 60000
# 60100
# SOD1 in
# 60200
# RUNX1 in
# 60300
# ERG in
# MX1 in
# 60400
# TFF3 in
# TFF1 in
# 60500
# COL18A1 in
# COL6A1 in
# 60600
# MT-CO1 in

# %%
 'NDRG1' in gene_sel
# Out:
# True

# %%
print(len(gene_sel))
gene_sel = list(set(gene_sel))
print(len(gene_sel))
gene_sel=sorted(gene_sel, reverse=True)
# Out:
# 768
# 767

# %%
print(gene_sel)
# Out:
# ['WWOX-AS1', 'WWOX', 'VSTM2L', 'VDAC1P9', 'VAT1L', 'TTI1', 'TLDC2', 'TGM2', 'TGIF2-RAB5IF', 'TGIF2', 'SRC', 'SPTA1', 'SOGA1', 'SNORA71E', 'SNORA71D', 'SNORA71C', 'SNORA71B', 'SNORA71A', 'SNORA60', 'SNHG17', 'SNHG11', 'SMU1P1', 'SLC32A1', 'SLA2', 'SH2D2A', 'SDR42E1', 'SCAND1', 'SAMHD1', 'RPS3P7', 'RPS3P2', 'RPS3AP3', 'RPS27AP3', 'RPRD1B', 'RPN2', 'RPL7AP14', 'RPF2P1', 'ROMO1', 'RNU6-937P', 'RNU6-1191P', 'RNU4-40P', 'RNA5SP60', 'RNA5SP431', 'RN7SL612P', 'RN7SL237P', 'RN7SL156P', 'RN7SL116P', 'RN7SKP185', 'RN7SKP176', 'RN7SKP173', 'RBM39', 'RBL1', 'RALGAPB', 'RAD1P2', 'RAB5IF', 'PYHIN5P', 'PYHIN1', 'PRCC', 'PPP1R16B', 'PPIAP51', 'PPIAP50', 'PPIAP3', 'PLCG2', 'PKD1L2', 'PHF20', 'PEAR1', 'OR6Y1', 'OR6P1', 'OR6N2', 'OR6N1', 'OR6K6', 'OR6K5P', 'OR6K4P', 'OR6K3', 'OR6K2', 'OR6K1P', 'OR2AQ1P', 'OR10Z1', 'OR10X1', 'OR10T2', 'OR10T1P', 'OR10R3P', 'OR10R2', 'OR10R1P', 'OR10K2', 'OR10K1', 'OR10J9P', 'OR10J8P', 'OR10J7P', 'OR10J6P', 'OR10J5', 'OR10J4', 'OR10J3', 'OR10J2P', 'OR10J1', 'OR10AE1P', 'OR10AA1P', 'NUDT7', 'NTRK1', 'NORAD', 'NNAT', 'NFS1', 'NDRG3', 'MYL9', 'MTCYBP28', 'MRPS21P2', 'MROH8', 'MPTX1', 'MPHOSPH6', 'MNDA', 'MIR7854', 'MIR765', 'MIR6504', 'MIR548O2', 'MIR4720', 'MANBAL', 'MAFTRR', 'MAF', 'LSM3P5', 'LRRC71', 'LINC02819', 'LINC02772', 'LINC02131', 'LINC01746', 'LINC01704', 'LINC01229', 'LINC01228', 'LINC01227', 'LINC00489', 'LBP', 'KRT8P45', 'KRT8P22', 'KIRREL1-IT1', 'KIRREL1', 'KIAA1755', 'INSRR', 'IFI16', 'HSD17B2', 'HNRNPA3P2', 'HMGN1P5', 'HMGB3P2', 'HIGD1AP16', 'GLRXP1', 'GHRH', 'GCSH', 'GAN', 'FCRL5', 'FCRL4', 'FCRL3', 'FCRL2', 'FCRL1', 'FCER1A', 'FAM83D', 'ETV3L', 'ETV3', 'EPB41L1', 'ELL2P1', 'EI24P2', 'DYNLRB2', 'DSN1', 'DLGAP4-AS1', 'DLGAP4', 'CYCSP52', 'CTNNBL1', 'COX7BP2', 'CNBD2', 'CMIP', 'CMC2', 'CLEC3A', 'CENPN', 'CDYL2', 'CD5L', 'CD1E', 'CD1D', 'CD1C', 'CD1B', 'CD1A', 'CADM3-AS1', 'CADM3', 'C16orf46', 'BPI', 'BLCAP', 'BCO1', 'ATMIN', 'ARLNC1', 'ARHGEF11', 'ARHGAP40', 'APCS', 'AL732406.1', 'AL606752.1', 'AL590666.5', 'AL513323.1', 'AL445528.2', 'AL391095.5', 'AL391095.4', 'AL391095.3', 'AL391095.2', 'AL391095.1', 'AL365440.2', 'AL365440.1', 'AL359555.4', 'AL359555.3', 'AL359555.2', 'AL359555.1', 'AL357374.1', 'AL357143.2', 'AL357143.1', 'AL356276.2', 'AL356276.1', 'AL353899.1', 'AL162293.1', 'AL139010.1', 'AL138900.2', 'AL138900.1', 'AL138899.3', 'AL138899.2', 'AL138899.1', 'AL136172.1', 'AL135929.2', 'AL135929.1', 'AL133519.1', 'AL121895.2', 'AL121895.1', 'AL109614.1', 'AL078461.1', 'AL050318.1', 'AL035420.3', 'AL035420.2', 'AL035420.1', 'AL035419.1', 'AL034422.1', 'AL031662.1', 'AL031659.1', 'AL031651.2', 'AL031651.1', 'AIM2', 'ADIG', 'ADAMTS18', 'ACTR5', 'ACKR1', 'AC136603.1', 'AC131888.1', 'AC108097.1', 'AC106743.1', 'AC105411.1', 'AC099524.1', 'AC099313.1', 'AC092724.1', 'AC092718.9', 'AC092718.8', 'AC092718.7', 'AC092718.6', 'AC092718.5', 'AC092718.4', 'AC092718.3', 'AC092718.2', 'AC092718.1', 'AC092376.3', 'AC092376.2', 'AC092376.1', 'AC092332.1', 'AC092142.2', 'AC092142.1', 'AC092139.3', 'AC092139.2', 'AC092139.1', 'AC092135.3', 'AC092135.2', 'AC092135.1', 'AC092134.3', 'AC092134.2', 'AC092134.1', 'AC092130.1', 'AC084064.1', 'AC079414.3', 'AC079414.2', 'AC079414.1', 'AC046158.4', 'AC046158.3', 'AC046158.2', 'AC046158.1', 'AC027279.4', 'AC027279.3', 'AC027279.2', 'AC027279.1', 'AC025284.1', 'AC022166.2', 'AC022166.1', 'AC009159.4', 'AC009159.3', 'AC009159.2', 'AC009159.1', 'AC009148.1', 'AC009145.4', 'AC009145.3', 'AC009145.2', 'AC009145.1', 'AC009141.1', 'AC009070.1', 'AC009044.1', 'AAR2']

# %%
gene_sel.append('Carbonic anhydrase IX')
gene_sel.append('carbonic anhydrase IX')

# %% [markdown]
# ### 拆分训练测试集

# %%
import random
random.shuffle(data_cls)
train_len = int(len(data_cls) * 0.8)
data_train, data_test = data_cls[:train_len], data_cls[train_len:]

# %%
len(data_train), len(data_test)
# Out:
# (1650, 413)

# %% [markdown]
# ### 训练集分析

# %%
import re
gene_sel_trans = [gene.replace('.', '\.').replace('-', '\-') for gene in gene_sel]
gene_regex = '((([ ]|^)' + '([ .,]|$))|(([ ]|^)'.join(gene_sel_trans) + '([ .,]|$)))'

# %%
result = []
for item in data_train:
#     print(item)
    print('---------------------')
    item_result = []
    for line in item:
        line_match = re.findall(gene_regex, line)
        line_res = []
        if len(line_match) >= 2:
            for match in line_match:
                match_str = match[0].strip()
                match_str = match_str[:-1] if match_str[-1] in ['.', ','] else match_str
                line_res.append(match_str)
            line_res = list(set(line_res))
            if len(line_res) >= 2:
                item_result.append((line, line_res))
                print((line, line_res))
    result.append((item, item_result))
# Out:
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# (' Compared to normal adult colon, all mouse and human tumors over-expressed a large cluster of genes highly enriched for functional association to the control of cell cycle progression, proliferation, and migration, including those encoding MYC, AKT2, PLK1 and SPARC.', ['AKT2', 'SPARC', 'PLK1', 'MYC'])
# (' Human CRC adenocarcinomas lost an additional suppressor module (IGFBP4, MAP4K1, PDGFRA, STAB1 and WNT4).', ['PDGFRA', 'STAB1', 'MAP4K1'])
# (' Many human tumor samples also gained expression of a coordinately regulated module associated with advanced malignancy (ABCC1, FOXO3A, LIF, PIK3R1, PRNP, TNC, TIMP3 and VEGF).', ['TIMP3', 'PRNP', 'LIF', 'PIK3R1', 'TNC'])
# ---------------------
# (' Genes overexpressed in breast carcinoma included TFF1, TFF3, FOXA1, CA12, GATA3, SDC1, PITX1, TH, EHFD1, EFEMP1, TOB1 and KLF2.', ['TFF3', 'KLF2', 'TH', 'PITX1', 'TOB1', 'EFEMP1', 'TFF1', 'CA12', 'GATA3', 'SDC1', 'FOXA1'])
# (' Genes overexpressed in ovarian/peritoneal carcinoma included SPON1, RBP1, MFGE8, TM4SF12, MMP7, KLK5/6/7, FOLR1/3,PAX8, APOL2 and NRCAM.', ['APOL2', 'SPON1', 'RBP1', 'MFGE8', 'MMP7', 'NRCAM'])
# ---------------------
# (' Several members of the WNT pathway, including WNT5A, FZD5, and DKK1 were highly up-regulated in PCa tissue from patients with advanced PCa.', ['FZD5', 'WNT5A', 'DKK1'])
# (' While WNT5A, FZD5, and DKK1 were highly expressed in PC3 cells, WNT1 and SFRP1 mRNA levels were higher in DU145 cells.', ['FZD5', 'SFRP1', 'WNT5A', 'DKK1', 'WNT1'])
# (' Moreover, zoledronic acid down-regulated mRNA levels of WNT5A (-34%), FZD5 (-60%), and DKK1 (-46%) in PC3 cells.', ['FZD5', 'WNT5A', 'DKK1'])
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# (' In addition, fenofibrate-enhanced HO-1 upregulation activates SIRT1 and leads to subsequent accumulation of SIRT1 in the nucleus, which further promotes HIF-1α deacetylation and inhibits CA9 expression.', ['CA9', 'SIRT1'])
# ---------------------
# ---------------------
# ---------------------
# (' Immunohistochemical staining of tumor tissue sections confirmed the increased expression of CAIX, HK2 and LDHA in ccRCC, validating the microarray data and supporting their potential as the energetic metabolism-related biomarkers of the ccRCC.', ['LDHA', 'HK2'])
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# (' The present study additionally identified 3 potential genes (lysyl oxidase, ankyrin repeat domain 37, B-cell lymphoma 2 interacting protein 3 like) previously identified in other studies, which may be considered as universal hypoxia genes along with HIF1α, EPO, VEGF, glucose transporter 1 (GLUT1), CA9, and LDH.', ['CA9', 'EPO'])
# ---------------------
# ---------------------
# ('RESULTS: ZEB1 bound to the promoter of CA9 to positively regulate CA9 expression in tongue cancer cells.', ['CA9', 'ZEB1'])
# (' Knockdown of CA9 using short interfering RNA (siRNA) abolished the chemoresistance resulting from ZEB1 overexpression in Tca8113 and SCC-25 cells, and CA9 overexpression attenuated chemosensitivity induced by ZEB1 knockdown in Tca8113/PYM cells.', ['CA9', 'ZEB1'])
# (' CA9 knockdown also prevented maintenance of pHi mediated by overexpression of ZEB1 in Tca8113 and SCC-25 cells following chemotherapy, associated with increased apoptosis and caspase-3 activation.', ['CA9', 'ZEB1'])
# (' Conversely, ectopic expression of CA9 suppressed decrease in pHi mediated by ZEB1 knockdown in Tca8113/PYM cells following chemotherapy, accompanied by decreased apoptosis and caspase-3 activation.', ['CA9', 'ZEB1'])
# (' Importantly, a positive correlation was observed between ZEB1 and CA9 protein expression in tongue cancer tissues, and expression of these proteins associated with a poor prognosis for patients.', ['CA9', 'ZEB1'])
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# (' In this study, human MMNK-1 cholangiocytes with repressed CFTR function were used to induce SULT1E1 expression in human HepG2 hepatocytes to investigate whether SULT1E1 can be increased in human CF liver.', ['SULT1E1', 'CFTR'])
# (' Results demonstrate that inhibition of CFTR expression in MMNK-1 cells results in the induction of SULT1E1 message and activity in HepG2 cells in the Transwell system.', ['SULT1E1', 'CFTR'])
# (' Thus, we have shown that co-culture of HepG2 hepatocytes with MMNK-1 cholangiocytes with siRNA repressed CFTR expression results in the selective induction of SULT1E1 in the HepG2 cells.', ['SULT1E1', 'CFTR'])
# (' Loss of CFTR function in cholangiocytes may have a paracrine regulatory effect on hepatocytes via the induction of SULT1E1 and the increased sulfation of beta-estradiol.', ['SULT1E1', 'CFTR'])
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# (' The TST15 gene panel and HRAS sequencing revealed no pathogenic mutations in BRAF, KRAS, EGFR, AKT1, or HRAS.', ['EGFR', 'AKT1', 'HRAS', 'KRAS', 'BRAF'])
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# (' Therefore, we analyzed the CA9 promoter activity in transfected tumor cells expressing RET and/or the HIF-α subunit.', ['CA9', 'RET'])
# (' We showed that overexpression of both wild-type and mutant RET can increase the CA9 promoter activity induced by HIF-1 (but not HIF-2) in hypoxia.', ['CA9', 'RET'])
# (' Moreover, inhibition of the major kinase pathways, which transmit signals from RET and regulate HIF-1, abrogated their cooperative effect on the CA9 promoter.', ['CA9', 'RET'])
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ("RESULTS: Cancer and Alzheimer's disease have inverse relationship in many aspects such as P53, estrogen, neurotrophins and growth factors, growth and proliferation, cAMP, EGFR, Bcl-2, apoptosis pathways, IGF-1, HSV, TDP-43, APOE variants, notch signals and presenilins, NCAM, TNF alpha, PI3K/AKT/MTOR pathway, telomerase, ROS, ACE levels.", ['EGFR', 'ACE', 'TNF', 'APOE'])
# ---------------------
# ---------------------
# ---------------------
# (' CA4, PECAM1, DNAJB4, AGER, GIMAP6, C10orf54 and DOCK4 were expressed at lower levels in the tumor samples, whereas GOLM1 and PAFAH1B3 were highly expressed in tumor samples.', ['DOCK4', 'DNAJB4', 'AGER', 'GIMAP6', 'PECAM1', 'GOLM1', 'CA4', 'PAFAH1B3'])
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# (' RT-qPCR was used to measure mRNA levels of WNT family members (WNT1, WNT3, WNT4, WNT5, sFRP4 and sFRP5).', ['WNT3', 'WNT4'])
# (' The PCOS group had higher transcript levels of WNT1, WNT3 and WNT4 (p<0.', ['WNT1', 'WNT3', 'WNT4'])
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# (' Among them, six up-regulated proteins (carbonic anhydrase 3 (Ca 3), Hsp-27, S100A6, galectin-7, S100A9, S100A11) and one down-regulated protein (superoxide dismutase [Cu-Zn] (Sod 1)) are associated with cancer-related key processes.', ['S100A6', 'S100A9'])
# (' Comparative studies showed that Ca 3, S100A6, S100A9, S100A11 and Sod 1 are specific for stages of development and progression of tumors whereas Hsp-27 and galectin-7 are specific for tumor promotion stage by cypermethrin in mouse skin.', ['S100A11', 'S100A6', 'S100A9'])
# ---------------------
# (' The purpose of this study was to investigate mutations in 50 oncogenes and tumor suppressor genes, including APC and CTNNB1, in which mutations in COF have been previously reported.', ['APC', 'CTNNB1'])
# ('RESULTS: The expression assay revealed 12 differentially expressed Wnt/β-catenin pathway genes in COF, including the upregulation of CTNNB1, TCF7, NKD1, and WNT5 A, and downregulation of CTNNBIP1, FRZB, FZD6, RHOU, SFRP4, WNT10 A, WNT3 A, and WNT4, suggesting activation of the Wnt/β-catenin signaling pathway.', ['WNT4', 'NKD1', 'RHOU', 'CTNNBIP1', 'CTNNB1', 'FZD6', 'WNT3', 'FRZB', 'TCF7', 'SFRP4'])
# (' NGS revealed 5 single nucleotide variants: TP53 (rs1042522), PIK3 CA (rs2230461), MET (rs33917957), KIT (rs3822214), and APC (rs33974176), but none of them was pathogenic.', ['TP53', 'MET', 'APC', 'KIT'])
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# (' Leptin signaling increased the expression of tumorigenesis and chemoresistance-related genes (ABCB1, WNT4, ADHFE1, TBC1D3, LL22NC03, RDH5, and ITGB3) and impaired chemotherapeutic effects in TNBC cells.', ['ADHFE1', 'WNT4', 'TBC1D3', 'RDH5'])
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# (' The downregulation of ETS1 expression with small interfering RNA (siRNA) inhibited the upregulation of CA9 and NDRG1/Cap43 caused by increased cell density.', ['CA9', 'ETS1'])
# ---------------------
# ---------------------
# (' Among familial cases, mutations of the succinate dehydrogenase (SDH) subunit genes (succinate dehydrogenase subunit [SDH]B, SDHC, SDHD, succinate dehydrogenase subunit AF2 [SDHAF2] , and SDHA) are the most common cause.', ['SDHD', 'SDHC'])
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# (' Under equivalent dosage of Dox, free Dox substantially changed the expression of ANK1, ACTA2, GPR87, GDF15, FZD6, and WNT4 in MCF-7 cells.', ['WNT4', 'ACTA2', 'ANK1', 'FZD6', 'GDF15', 'GPR87'])
# ---------------------
# ---------------------
# ---------------------
# (' BRCA1 inhibits NEAT1 expression potentially through binding to its genomic binding site upstream of the NEAT1 gene.', ['BRCA1', 'NEAT1'])
# (' BRCA1 deficiency in human normal/cancerous breast cells and mouse mammary glands leads to NEAT1 overexpression.', ['BRCA1', 'NEAT1'])
# (' Our studies show that NEAT1 upregulation resulting from BRCA1 deficiency stimulates in vitro and in vivo breast tumorigenicity.', ['BRCA1', 'NEAT1'])
# (' Silencing of miR-129-5p expression by NEAT1 results in upregulation of WNT4 expression, a target of miR-129-5p, which leads to activation of oncogenic WNT signaling.', ['WNT4', 'NEAT1'])
# ---------------------
# ---------------------
# (' We examined 4 OS cell lines for WNT1, WNT4, WNT5A, WNT7A, WNT11, FZD1-10 and LRP5 expression by reverse transcription polymerase chain reaction (RT-PCR).', ['WNT4', 'WNT11', 'WNT7A', 'WNT5A', 'WNT1', 'LRP5'])
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# (' Xuan-Fu-Hua decoction treatment significantly increased the transcription levels of DDIT3, PMAIP1, and ZMAT3 genes while decreasing that of WNT4, AXIN2, NFE2L2, TGFBR1, MITF, and IGFBP3 genes.', ['ZMAT3', 'WNT4', 'NFE2L2', 'DDIT3', 'AXIN2', 'IGFBP3', 'TGFBR1', 'MITF', 'PMAIP1'])
# ---------------------
# ('2, CD10, c-erbB-2, EGFR, HIF-1a, Ki67, MDM2, PAX-2 y 8, p53, survivin and VEGFR 1 and 2).', ['EGFR', 'MDM2'])
# (' Deletion-duplication of genes increased the likelihood: of death (APC, Bcl-2 and CDKN2A by 11, 7 and 4 respectively and SMAD4 reduced the probability by 88%); tumor recurrence (CDKN2A by fifteen fold and VHL reduced the probability by 87%); pT greater than 2 (CCND2, MDM2 and WT1 multiplied by 6, 7 and 9); risk of N+ (CDK4 and EBF1 by 13); distant metastases (BRCA2 and DLEU1 by 5); Fuhrman grade ≥3 (BRCA1, BRCA2 and p53 by 40, 75 and 34 respectively, while that FHIT reduced by 96%).', ['WT1', 'VHL', 'FHIT', 'DLEU1', 'EBF1', 'SMAD4', 'BRCA2', 'MDM2', 'CDKN2A'])
# (' Deletion-duplication of CDK4 and DCC increased survival by a factor of 13 and 16, while that DLEU1 and RUNX1 decreased survival time by 80%.', ['DCC', 'CDK4', 'DLEU1', 'RUNX1'])
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# (' Experimental studies have suggested that herbal compounds regulate the expression of many lncRNAs involved in cancer, such as HOTAIR (HOX transcript antisense RNA), H19, MALAT1 (metastasis-associated lung adenocarcinoma transcript 1), PCGEM1 (Prostate cancer gene expression marker 1), PVT1, etc.', ['PCGEM1', 'MALAT1', 'PVT1', 'H19', 'HOTAIR'])
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# (' Furthermore, ectopic expression of DVL1, LRP8 and Notch2 in malignant lung tissue validates the biological impact of these genetic alterations.', ['DVL1', 'LRP8'])
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# (' The effects of sustained production of WNT4 were concomitant with upregulation of proliferative markers (c-Myc, Cyclin D1), the survival marker BCL-XL, the putative WNT4 receptor FZD6 and activation of ERK1 and STAT3.', ['FZD6', 'WNT4', 'STAT3'])
# (' In xenograft studies, tumors with autocrine hGH expressed higher levels of WNT4 and FZD6 when compared with control tumors.', ['FZD6', 'WNT4'])
# ---------------------
# ---------------------
# ---------------------
# ('Silencing PTEN in the fallopian tube promotes enrichment of cancer stem cell-like function through loss of PAX2.', ['PAX2', 'PTEN'])
# (' In the present study, loss of PTEN in FTE led to the enrichment of cancer stem cell markers such as LGR5, WNT4, ALDH1, CD44.', ['CD44', 'WNT4', 'PTEN', 'LGR5'])
# (' Taken together, these data suggest that loss of PTEN induces reprogramming of the FTE cells into a more stem-like phenotype due to loss of PAX2 and provides a model to study early events during the FTE-driven ovarian cancer tumor formation.', ['PAX2', 'PTEN'])
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# (' PBMC expressions of six genes from our previous study (ANXA3, ARG1, CA5B, F5, SSBP2, and TBC1D8) along with four new genes (MIC1, NGAL, MUC1, and MUC16) were analyzed using multiplex Q-RT PCR.', ['SSBP2', 'ARG1', 'MUC1', 'F5', 'CA5B'])
# (" We found that addition of PBMC CA5B, F5, SSBP2, and MIC1 expression levels to CA19-9 significantly improved CA19-9's diagnostic abilities when comparing resectable PC to CP patients (p=0.", ['PC', 'SSBP2', 'CP', 'F5', 'CA5B'])
# (' We identified a score-based model that can differentiate resectable PC from CP better than CA19-9, potentiating that PBMC differential expression analysis may offer a novel tool for early PC diagnosis.', ['PC', 'CP'])
# ---------------------
# ---------------------
# ---------------------
# (' We performed a precise characterization of mesenchymal differentiation using PAX2, WNT4 and WT1 as a marker, which revealed that impairment of the differentiation process preceded the development of cysts in Pkd1(-/-) mice.', ['WT1', 'WNT4', 'PAX2'])
# ---------------------
# ---------------------
# ---------------------
# (' Low levels of WNT2, WNT4, WNT5A have also been observed.', ['WNT4', 'WNT2', 'WNT5A'])
# (' Decreased expression of WNT2 and WNT5A may be caused by miR-331-3p and miR-200b-5p, respectively.', ['WNT2', 'WNT5A'])
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# (' Immunohistochemistry showed that atypical cells were positive for cytokeratin AE1&3, CK7, CD10, GATA3, glypican 3, Hep Par 1, carbonic anhydrase 9 (focal), and vimentin (focal) but negative for CK20, CD56, chromogranin A, synaptophysin, TTF1, HMB45, melan A, and PSA.', ['GATA3', 'TTF1'])
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# (' A direct association of CA9 expression with epidermal growth factor receptor, c-erbB-2, and MUC1 expression was also noted (P < 0.', ['CA9', 'MUC1'])
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# (' Tumors were negative for cytokeratin 20, carbonic anhydrase IX, parvalbumin, HMB45, TTF1, TFE3, chromogranin A, thyroglobulin, PAX8, and ALK.', ['ALK', 'PAX8', 'TFE3', 'TTF1'])
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ('PADI4 stimulates esophageal squamous cell carcinoma tumor growth and up-regulates CA9 expression.', ['CA9', 'PADI4'])
# (' Immunohistochemistry detected the increased expression and co-localization of PADI4 and CA9 in ESCC tissues compared with adjacent non-tumor tissues and normal tissue controls.', ['CA9', 'PADI4'])
# (' The above findings suggest that increased PADI4 expression in ESCC stimulates tumor growth and up-regulates CA9 expression, which is known to promote metastatic properties in tumor cells.', ['CA9', 'PADI4'])
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# (' Finally, COX-2 and PTGES were colocalized in primary tumors along with HIF-1alpha and IGFBP3.', ['PTGES', 'IGFBP3'])
# ---------------------
# ---------------------
# (' It was also demonstrated that MB was upregulated in hypoxic microregions of glioblastoma tumor xenografts that were stained in matched tumor regions of serial tumor sections with the hypoxia markers, pimonidazole, CAIX, VEGF and LDHA.', ['LDHA', 'MB'])
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# (' The low MVD, increased HIF-1alpha protein levels, dissociation of hypoxia, and TP53 protein induction in the metastatic tumor cells (AN3CA) support a role for hypoxia in the development of recurrent endometrial carcinoma.', ['TP53', 'MVD'])
# ---------------------
# ---------------------
# ---------------------
# (' Previously we showed that LOX is strongly induced upon hypoxia in nasopharyngeal carcinoma (NPC) cell lines CNE2 and HONE1 but only slightly in HK1 and not in C666-1.', ['HK1', 'LOX'])
# (' LOX was expressed in most NPC cell lines except for C666-1, while HK1 and FaDu (laryngeal cancer) only expressed low level of LOX.', ['HK1', 'LOX'])
# (' Methylation analysis showed that the LOX promoter was methylated in C666-1 and partially methylated in HK1.', ['HK1', 'LOX'])
# (' Carbonic anhydrase IX (CA9) mRNA level was obviously decreased in HK1 cells after transfection with LOX.', ['HK1', 'Carbonic anhydrase IX', 'LOX'])
# (' The elevation of CA9 protein upon hypoxia was inhibited in LOX-transfected HK1 cells.', ['CA9', 'HK1'])
# ---------------------
# ---------------------
# ---------------------
# (" CA4 interacted with Wilms' tumour 1-associating protein (WTAP) and induced WTAP protein degradation through polyubiquitination.", ['CA4', 'WTAP'])
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# (' We tested the contribution of four SF-inducible/c-Akt-dependent genes (AMPD3, EPHB2, MX1 and WNT4) to protection against adriamycin (a DNA topoisomerase IIalpha inhibitor) using RNA interference.', ['MX1', 'EPHB2'])
# ---------------------
# (' These positive effects of SIRT6 were associated with downregulation of the circulatory chemokine, CXCL10, and the myokine, WNT4.', ['WNT4', 'SIRT6', 'CXCL10'])
# ---------------------
# ---------------------
# (' Furthermore, HIF-1α, CA9, CD34, VEGFR1 and -3 and PDGRFα showed significant associations with progression-free survival (PFS) and overall survival (OS).', ['CA9', 'CD34'])
# (' Frequently observed copy number loss and mutation of VHL gene lead to altered expression of VHL, HIF-1α, CA9, and VEGF.', ['CA9', 'VHL'])
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# (' Both up-regulated and down-regulated proteins were selected and identified as follows: heat shock protein 70 protein 2; Cyclin M3, alpha 1 antichymotrypsin precursor; carbonic anhydrase I, cancer antigen 1; SOBP protein; Rho GDP dissociation inhibitor alpha; glyoxalase I with benzyl glutathione inhibitor; lipid-free human apolipoprotein A-I and RAB4A member RAS oncogene family.', ['SOBP', 'RAB4A'])
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# (' We have studied the expression of toll-like receptors (TLR) TLR2, TLR4 and TLR9, and hypoxia markers HIF-1alpha and Carbonic anhydrase IX (CAIX) in normal and inflamed pancreatic ducts, in PanINs and in cancers.', ['Carbonic anhydrase IX', 'TLR2', 'TLR4', 'TLR9'])
# (' We found TLR2, TLR9, HIF-1alpha and CAIX to be prominently expressed in pancreatic intraepithelial neoplasia.', ['TLR2', 'TLR9'])
# (' Expression of TLR2 showed a linear increase from PanIN1 to PanIN3, while the highest TLR4 expression was detected in inflamed ducts, and TLR9 expression in PanIN1 lesions.', ['TLR2', 'TLR4', 'TLR9'])
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# (' The present study aimed to determine the role of CA4 in GC tumorigenesis and its underlying molecular mechanism.', ['CA4', 'GC'])
# (' The levels of CA4 in GC cells and tissues were evaluated by reverse transcription-quantitative PCR and immunohistochemistry.', ['CA4', 'GC'])
# (' CA4 expression was suppressed in GC cells and tissues compared with adjacent healthy tissues and normal human gastric epithelial cells, respectively.', ['CA4', 'GC'])
# (' Analyses with a real-time cell analyzer and clonogenic assays were conducted to validate the impact of CA4 on GC cell lines (AGS and HGC-27) and normal human gastric epithelial cell line (GES-1) proliferation.', ['CA4', 'GC'])
# (' The effects of CA4 on the cell cycle in GC cells were determined by flow cytometry.', ['CA4', 'GC'])
# (' CA4 overexpression inhibited GC cell proliferation and reduced colony-forming ability, arrested the cell cycle in the G2/M phase, inhibited cyclin B1 and cyclin-dependent kinase 2 expression and induced p21 expression.', ['CA4', 'GC'])
# (' These results indicate that CA4 may serve an important role in GC tumorigenesis by inhibiting cellular proliferation via regulating the expression of cell cycle-associated proteins.', ['CA4', 'GC'])
# (' CA4 may serve as a diagnostic biomarker and a potential therapeutic target in GC.', ['CA4', 'GC'])
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# (' CA9 suppression by inhibitors (S4 and U104) decreased viability and migration of MM cells, accompanied by overexpression of TFRC, IREB1/2 and FPN1(SLC40A1) and by downregulation of FTH/FTL.', ['CA9', 'TFRC'])
# ---------------------
# (' Among these intersection genes, CA9, EBI3, SPOCK2, WDFY4, CD1D, and CCL22 were significantly correlated with overall survival in PDAC patients.', ['WDFY4', 'CD1D', 'CA9', 'SPOCK2', 'EBI3', 'CCL22'])
# (' Moreover, multivariate Cox analysis revealed that CA9, SPOCK2, and CD1D were the most significant prognostic genes, and were closely correlated with immune infiltration in TCGA cohort.', ['CA9', 'CD1D', 'SPOCK2'])
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# (" Moreover, expression of four methylated genes (PLCXD3 (Phosphatidylinositol-Specific Phospholipase C, X Domain Containing 3), BAIAP2L2 (BAR/IMD Domain Containing Adaptor Protein 2 Like 2), NPR3 (Natriuretic Peptide Receptor 3), SNX10 (Sorting Nexin 10)) can influence patients' prognosis.", ['SNX10', 'NPR3', 'BAIAP2L2'])
# (' Protein products of nine genes were identified as potential druggable targets, of which the tumorigenic potential of XDH (Xanthine Dehydrogenase), ATIC (5-Aminoimidazole-4-Carboxamide Ribonucleotide Formyltransferase/IMP Cyclohydrolase), CA9 (Carbonic Anhydrase 9), SLC7A11 (Solute Carrier Family 7 Member 11), and GAPDH (Glyceraldehyde-3-Phosphate Dehydrogenase) have been demonstrated in previous studies.', ['ATIC', 'SLC7A11', 'GAPDH', 'CA9', 'XDH'])
# ---------------------
# ---------------------
# (' The present study aimed to evaluate the effects of E7070 on CA9 and CA12 enzymes in GBM cells as well as in the tumor cell growth, migration, invasion, and resistance to radiotherapy and chemotherapy.', ['CA9', 'CA12'])
# (' We showed that CA9 and CA12 represent potentially valuable therapeutic targets that should be further investigated as useful diagnostic and prognostic biomarkers for GBM tailored therapy.', ['CA9', 'CA12'])
# ---------------------
# (' The expression of CA1 mRNA strongly correlated with that of sucrase-isomaltase, and inversely with that of MUC5AC in isolated IM glands.', ['MUC5AC', 'CA1'])
# (' In conclusion, CA1 could be colocalized with small intestinal proteins such as sucrase, but only rarely with the gastric mucin, MUC5AC.', ['MUC5AC', 'CA1'])
# ---------------------
# ---------------------
# ---------------------
# (' Finally, it inhibited genes and/or proteins expression of TGF-β1, 2 and 3, SMAD2, SMAD4, Wnt4, β-Catenin, LRP6, AXIN2 and Cyclin D1 in UL stem cells, all are key drivers of the TGF-β3/SMAD2 and Wnt4/β-Catenin pathways.', ['LRP6', 'SMAD4', 'AXIN2', 'SMAD2'])
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# (' We have previously demonstrated that therapeutically relevant concentrations/doses of oxaliplatin lead to a reduction in intracellular pH in mouse dorsal root ganglion (DRG) neurons in vitro and in vivo and that this alteration sensitizes TRPA1 and TRPV1 channels, which most likely mediate the allodynia associated with treatment.', ['TRPA1', 'TRPV1'])
# (' Furthermore, we show that FDA-approved drugs that inhibit carbonic anhydrase (an enzyme that is linked to haemoglobin in intracellular pH homeostasis), ie, topiramate and acetazolamide, revert (1) oxaliplatin-induced cytosolic acidification and TRPA1 and TRPV1 modulation in DRG neurons in culture, (2) oxaliplatin-induced cytosolic acidification of DRG of treated animals, and (3) oxaliplatin-induced acute cold allodynia in mice while not affecting OHP-induced cytotoxicity on cancer cells.', ['TRPA1', 'TRPV1'])
# ---------------------
# (' The two most commonly involved genes are FGFR1 and CHD7.', ['FGFR1', 'CHD7'])
# (' In eugonadal disorders, activating FSHR mutations have been identified for spontaneous ovarian hyperstimulation syndrome; and WNT4 mutations have been described in mullerian aplasia.', ['FSHR', 'WNT4'])
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# (' Using tissue microarray, IHC staining for CA9 and CA12 was performed.', ['CA9', 'CA12'])
# (' Lymphatic invasion, the Ki-67 labelling index of primary tumours, and CA9 staining of stromal cells, were independent risk factors for SLN metastasis in the multivariate analysis.', ['CA9', 'SLN'])
# (' In 80 patients without lymphatic invasion of primary tumours or CA9 staining of stromal cells, only four patients (5%) had positive SLN.', ['CA9', 'SLN'])
# ('CONCLUSION: CA9 staining of stromal cells is an independent risk factor for SLN metastasis as well as lymphatic invasion and a low Ki-67 labelling index of primary tumours in patients with early breast cancer.', ['CA9', 'SLN'])
# ---------------------
# ---------------------
# ---------------------
# (' The expression level of NF-κB p65, NF-κB p50, HIF-1, HIF-2, growth factor VEGF, VEGFR2, CAIX, as well as AR, ERα, ERβ, PR, Brn-3α, TRIM16 were quantified by RT-PCR.', ['AR', 'TRIM16'])
# (' Its mRNA level depended on the expression of AR, Brn-3α, and TRIM16, components of the AKT/mTOR signaling pathway, transcription, and growth factors.', ['AR', 'TRIM16'])
# (' We revealed the growth in PR expression was accompanied by the suppression of the signaling cascade activity, AR, Brn-3α mRNA level, and the enhanced PTEN expression in PCa tissues.', ['PTEN', 'AR'])
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# (' Owing to the emergence of additional markers for RCCs, we have evaluated the immunohistochemical staining patterns of a series of 7 papillary cystadenomas using CK7, RCC, PAX8, carbonic anhydrase IX, and AMACR.', ['PAX8', 'AMACR'])
# ---------------------
# ---------------------
# ---------------------
# ('2, we identify four more variants with statistically significant evidence of involvement in both endometriosis and WHRadjBMI (in/near KIFAP3, CAB39L, WNT4, GRB14); two of these, KIFAP3 and CAB39L, are novel associations for both traits.', ['CAB39L', 'KIFAP3', 'WNT4'])
# (' KIFAP3, WNT4 and 7p15.', ['KIFAP3', 'WNT4'])
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# (' Gene expression of Wnt pathway activator (WNT4), inhibitors (SFRP1, DKK3, AXIN1, and APC), transcriptional activator (TCF7), target genes (MYC, WISP2, and, CDH1), and Wnt modulator (TP53) was evaluated by qPCR.', ['AXIN1', 'DKK3'])
# (' The transcription levels of all genes studied, except APC, were higher in aCPs as compared to controls and TCF7 mRNA levels correlated with CTNNB1 mutation.', ['CTNNB1', 'APC', 'TCF7'])
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# (' Here we studied the expression of ARG2 in pancreatic ductal carcinoma (PDC) tissue clinicopathologically by examining over 200 cases of PDC.', ['PDC', 'ARG2'])
# (' In contrast to prostate cancer, ARG2 expression was rarely demonstrated in PDC cells by immunohistochemistry, and instead ARG2 was characteristically expressed in α-smooth muscle actin-positive cancer-associated fibroblasts (CAFs), especially those located within and around necrotic areas in PDC.', ['PDC', 'ARG2'])
# (' In addition to the characteristic distribution of ARG2-expressing CAFs, such CAFs co-expressed carbonic anhydrase IX, SLC2A1, or HIF-1α, markers of hypoxia, in PDC tissue.', ['SLC2A1', 'PDC'])
# (' Furthermore, in vitro experiments revealed that cultured fibroblasts extracted from PDC tissue expressed the ARG2 transcript after exposure to hypoxia, which had arginase activity.', ['PDC', 'ARG2'])
# (' These results indicate that cancer cell-mediated immune suppression through ARG2 expression is not a general event and that the presence of ARG2-expressing CAFs is an indicator of poor prognosis, as well as hypoxia, in PDC tissue.', ['PDC', 'ARG2'])
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# (' By searching the TCGA database, we showed that CA9, CXCL9, and GIMAP7 from the 8-mRNA signature were associated with the infiltration levels of immunocytes by regulating FOXO1 expression in PAAD.', ['CA9', 'FOXO1', 'CXCL9', 'GIMAP7'])
# (' Most importantly, we identified CA9, CXCL9, and GIMAP7 from the above eight genes as regulators of immunocyte infiltration by adjusting the expression of FOXO1 in PAAD.', ['CA9', 'FOXO1', 'CXCL9', 'GIMAP7'])
# (' Thus, CA9, CXCL9, and GIMAP7 might be the ideal targets of immune therapy of PAAD.', ['CA9', 'CXCL9', 'GIMAP7'])
# ---------------------
# ---------------------
# ---------------------
# (' Furthermore, inhibition of EGFR signaling intermediaries WNK1 and AKT1S1, members identified in the kinase array and previously unreported to play a role in the endometrium, also attenuate decidualization.', ['EGFR', 'AKT1S1', 'WNK1'])
# ---------------------
# (' One tumor each had somatic FH mutation and SMARCB1 mutation.', ['FH', 'SMARCB1'])
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# (' DNA was isolated from peripheral blood and used to genotype functional polymorphisms at the corresponding genes (HIF1A +1772 C\u2009>\u2009T, rs11549465; CA9\u2009+\u2009201 A\u2009>\u2009G; rs2071676; LOX +473\xa0G\u2009>\u2009A, rs1800449; KDR - 604\xa0T\u2009>\u2009C, rs2071559).', ['KDR', 'LOX'])
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# (' We validated 27 genes using qRT-PCR and found their expression patterns were mostly similar to those of RNA-seq, including 12 novel ICM-dominant (HNF4A, CCL24, FGFR4, IFITM3, PTCHD2, GJB5, FN1, KLK7, PRDM14, GRP, FGF19 and GCM1) and two novel TE-dominant (SLC10A1 and WNT4) genes.', ['FGF19', 'KLK7', 'FN1', 'PRDM14', 'FGFR4', 'IFITM3', 'GRP', 'GJB5', 'CCL24'])
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# (' MVD and CA-9 expression were assessed immunohistologically by using the CD34 antibody and the MN/CA9 M75 antibody, respectively.', ['MVD', 'CD34'])
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# (' In 46,XY gonadal dysgenesis, lack of testis development may be triggered by sex determining region Y, NR5A1, DHH or testis-determining gene loss-of-function mutations, DAX1 or WNT4 duplication or MAP3K1 gain-of-function mutations.', ['DHH', 'WNT4', 'MAP3K1', 'NR5A1'])
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# (' In the current study, we investigated the expression profiles of WNT/β-catenin signalling pathway genes (AXIN2, FZD4, TCF4, WNT3, WNT4, WNT5A, WNT7A, WNT1, APC, GSK3B and β-catenin) in a total of 13 oocyte samples.', ['FZD4', 'WNT4', 'GSK3B', 'WNT7A', 'TCF4', 'WNT3', 'WNT5A', 'APC', 'WNT1'])
# (' The results of this study displayed the absence of expression of AXIN2, FZD4, TCF4, WNT5A, WNT3, WNT4 and WNT7A genes in ovaries from women with PCOS and from healthy women.', ['FZD4', 'WNT4', 'AXIN2', 'WNT7A', 'TCF4', 'WNT3', 'WNT5A'])
# (' While APC and β-catenin expression levels were similar in the oocytes of both patients and controls, conversely, WNT1 and GSK3β genes both showed elevated expression in the oocytes of patients with PCOS, therefore suggesting an association between aberrant expression of WNT1 and GSK3β and the pathogenesis of PCOS.', ['WNT1', 'APC'])
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# (' Fusion-positive tumors had intense MAML3 nuclear staining and increased β-catenin by IHC and showed increased WNT4 expression.', ['WNT4', 'MAML3'])
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ('METHODS: A series of 98 tissue samples of primary non-small-cell lung carcinomas (NSCLC) from patients treated with surgery were analysed for the expression of CA9 and programmed-death ligand PD-L1 by cancer cells, and of FOXP3 by tumour-infiltrating lymphocytes (TILs).', ['CA9', 'FOXP3'])
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# (' EGF did not stimulate tyrosine phosphorylation of CAIX, although EGFR and down-stream signaling pathways were activated by EGF.', ['EGFR', 'EGF'])
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# (', PROM1, CD44, and EPCAM), it is found that CD44 positive population may render drug resistance in HCC272.', ['CD44', 'PROM1'])
# (' CellphoneDB analysis further implies that metabolism advantage organoids with enrichment of hypoxia signal upregulate NEAT1 expression in CD44 subgroup and mediate drug resistance that relies on Jak-STAT pathway.', ['CD44', 'NEAT1'])
# (' Moreover, metabolism advantage clusters shared in several organoids have similar characteristic genes (GAPDH, NDRG1 (N-Myc downstream regulated 1), ALDOA, and CA9).', ['NDRG1', 'ALDOA'])
# (' The combination of GAPDH and NDRG1 is an independent risk factor and predictor for patient survival.', ['NDRG1', 'GAPDH'])
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# (' Nickel exposure increased the level of H3K4 trimethylation in both the promoters and coding regions of several genes including CA9 and NDRG1 that were increased in expression in A549 cells.', ['CA9', 'NDRG1'])
# (' We have also compared the extent of the H3K4 trimethylation in the absence and presence of formaldehyde crosslinking and observed that crosslinking of chromatin was required to observe H3K4 trimethylation in the coding regions immediately downstream of TSSs of some nickel-induced genes including ADM and IGFBP3.', ['ADM', 'IGFBP3'])
# ---------------------
# (' We found that both CYP4B1 and RAB25 are downregulated with promoter hypermethylation and CA9 is upregulated with promoter hypomethylation, and we validated their mRNA differential expressions in 19 ccRCCs and 10 GEO datasets.', ['CA9', 'CYP4B1', 'RAB25'])
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# (', PLK1, CXCR4, and AXL.', ['CXCR4', 'AXL', 'PLK1'])
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# (' Activation of MT1G also inhibited CA9 transcription through the suppression of HIF1A as mediated by KLF4.', ['CA9', 'HIF1A', 'KLF4', 'MT1G'])
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# (' The spectrum of mutations in the NZBR lines was generally similar to that found in commonly used breast cancer cell lines but TP53 mutations were absent and mutations in EVI2B, LRP1B, and PMS2, which have not been reported in other breast cancer lines, were detected.', ['TP53', 'LRP1B', 'PMS2', 'EVI2B'])
# ---------------------
# ---------------------
# (' Our data support a model whereby FGF8 and WNT4 function in concert to induce the expression of Lim1 for MM survival and tubulogenesis.', ['FGF8', 'WNT4'])
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# (' We measured levels and stability of the hypoxia-inducible factor 1 subunit alpha (HIF1A), endothelial PAS domain 1 protein (EPAS1, also called HIF2A), CA9, solute carrier family 16 member 4 (SLC16A4, also called MCT4), and SLC2A1 (also called GLUT1) by immunoblot analyses.', ['CA9', 'SLC2A1'])
# ('RESULTS: Under hypoxic conditions, PDAC cells had increased levels of HIF1A and HIF2A, upregulated expression of CA9, and activated glycolysis.', ['CA9', 'HIF1A'])
# (' Knockdown of KRAS in PDAC cells, or incubation with trametinib, reduced the posttranscriptional stabilization of HIF1A and HIF2A, upregulation of CA9, pHi, and glycolysis in response to hypoxia.', ['CA9', 'HIF1A', 'KRAS'])
# ('CONCLUSIONS: In response to hypoxia, PDAC cells that express activated KRAS increase expression of CA9, via stabilization of HIF1A and HIF2A, to regulate pH and glycolysis.', ['CA9', 'HIF1A', 'KRAS'])
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ('METHODS: Nontumoral pancreas of 18 VHL patients operated on for PET, was examined for microadenomatosis (<or=5 mm) and compared with pancreatic specimen obtained from non-VHL patients or MEN1 patients.', ['VHL', 'MEN1'])
# (' The immunohistochemical expression of chromogranin, insulin, glucagon, HIF-1alpha, HIF-2alpha, VEGF, CA9, cyclin D1, and CD34 was assessed.', ['CA9', 'CD34'])
# (' Expression of HIF-1alpha and CA9 was not found in islets of controls and in MEN1 microadenomas.', ['CA9', 'MEN1'])
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# (' Downregulated PAX8 and upregulated EZH2 expression was found in GIST tissues.', ['PAX8', 'EZH2'])
# (' Overexpression of PAX8 or suppression of PAX8 methylation using DNA methyltransferase inhibitor 5-Aza-dC inhibited the proliferation, migration, and invasion of GIST cells while promoting their apoptosis (diminished PCNA, Ki67 and Bcl-2, elevated Bax, and cleaved caspase-3).', ['PAX8', 'PCNA'])
# (' EZH2 promoted PAX8 methylation to inhibit its expression.', ['PAX8', 'EZH2'])
# (' Collectively, EZH2 inhibits PAX8 expression by promoting its methylation, which thus downregulates Wnt4 expression, thereby promoting the development of GIST.', ['PAX8', 'EZH2'])
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# (' NR2F1 expression was positively regulated by p38α signaling and repressed by HER2 and WNT4 pathways.', ['WNT4', 'NR2F1'])
# ---------------------
# ---------------------
# ---------------------
# ('EXPERIMENTAL DESIGN: Expression of CA9 and CD34, an endothelial cell marker, was examined in serial paraffin-embedded sections by immunohistochemistry in 25 grade 1, 17 grade 2, and 20 grade 3 meningiomas.', ['CA9', 'CD34'])
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# (' Besides, our results firstly identify that CREB can recruit SIRT1 (class III HDACS) by adaptor protein p300, then repress the expression of CA9.', ['CA9', 'SIRT1'])
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# (' Univariate Cox regression analysis revealed that six RNAs (2 DELs: FAM138B, SSTR5‑AS1; 2 DEMs: hsa‑miR‑149, hsa‑miR‑7; 2\xa0DEGs: CCNE2, RRM2) were significantly associated with OS; while seven RNAs (1 DEL: LINC00284; 3 DEMs: hsa‑miR‑7, hsa‑miR‑15b, hsa‑miR‑30c‑2; and 3 DEGs: RRM2, CCNE2, CA2) were significantly associated with RFS.', ['FAM138B', 'CCNE2', 'RRM2'])
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# (' EGF, TGF-alpha and secretin, but not CCK or GRP, bound to the TAKA-1 cells.', ['CCK', 'EGF', 'GRP'])
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ('Poorer outcome in stromal HIF-2 alpha- and CA9-positive colorectal adenocarcinomas is associated with wild-type TP53 but not with BNIP3 promoter hypermethylation or apoptosis.', ['TP53', 'BNIP3'])
# (' Therefore, we correlated apoptosis, TP53 mutational status and BNIP3 promoter hypermethylation of CRC cells with HIF-2 alpha- and CA9-related poor outcome.', ['TP53', 'BNIP3'])
# (' In a series of 195 CRCs, TP53 mutations in exons 5-8 were analysed by direct sequencing, and promoter hypermethylation of BNIP3 was determined by methylation-specific PCR.', ['TP53', 'BNIP3'])
# (' Expressions of HIF-2 alpha, CA9, p53, BNIP3 and M30 were analysed immunohistochemically.', ['CA9', 'BNIP3'])
# (' Poorer survival of HIF-2 alpha and CA9 stromal-positive CRCs was associated with wild-type TP53 (P=0.', ['CA9', 'TP53'])
# (' Furthermore, apoptotic levels were independent of the TP53 status, but lower in unmethylated BNIP3 CRCs (P=0.', ['TP53', 'BNIP3'])
# ---------------------
# ---------------------
# ('RESULTS: Expression of CA9, CSF1, DUSP6, STAT1, and MMD differed between NSCLC and normal lung.', ['MMD', 'DUSP6', 'CA9', 'CSF1', 'STAT1'])
# (' EGFR was more abundant in SCC compared with AC, whereas the reverse was true for DUSP6 and ERBB3.', ['EGFR', 'ERBB3', 'DUSP6'])
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ...
# ('CONCLUSIONS: Our data show that in the setting of hypoxia and CXCR4 up-regulation in Treg, CXCL12 expression may have the negative consequence of enhancing Treg recruitment and suppressing the anti-tumour immune response.', ['CXCR4', 'CXCL12'])
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# (' CA9 and RGS5 expression levels of both groups were compared using immunohistochemistry, reverse transcription‑quantitative polymerase chain reaction and ELISA.', ['CA9', 'RGS5'])
# (' Compared with the control (NS) group, both CA9 and RGS5 expression in rh‑ES group were significantly decreased at days 4 and 6 (P<0.', ['CA9', 'RGS5'])
# ---------------------
# ---------------------
# (' Further analysis revealed that FZD2 is positively correlated with WNT3A, WNT5B, WNT7A and WNT2 and is negatively correlated with WNT4.', ['WNT4', 'WNT7A', 'WNT5B', 'WNT2', 'FZD2', 'WNT3A'])
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# (' Renal tumors with entity-defining genetic alterations may ultimately require molecular confirmation via cytogenetics or sequencing technologies, such as RCC with TFE3, TFEB, or ALK gene rearrangements, or TFEB amplified RCC.', ['TFEB', 'ALK', 'TFE3'])
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# (' In Ishikawa cells, a human endometrial epithelial cell line, LEFTY2 downregulated the expression of calcium release-activated calcium channel protein 1, encoded by ORAI1, and inhibited store-operated Ca2+ entry (SOCE).', ['LEFTY2', 'ORAI1'])
# (' Furthermore, LEFTY2 and the Orai1 blockers 2-APB, MRS-1845, as well as YM-58483, inhibited, whereas the Ca2+ ionophore, ionomycin, strongly upregulated COX2, BMP2 and WNT4 expression in decidualizing HESCs.', ['LEFTY2', 'WNT4', 'BMP2'])
# (' •LEFTY2 and the Orai1 blockers 2-APB, MRS-1845, and YM-58483 inhibit COX2, BMP2, and WNT4 expression in endometrial cells.', ['WNT4', 'BMP2'])
# ---------------------
# ---------------------
# (' Our results demonstrated that ALDH1, CD44, ARID1A, and CAIX in immunoreactive GA tumor cells exhibit different expression profiles compared with control cells and that these differences are associated with patient survival.', ['CD44', 'ARID1A'])
# (' In addition, the loss of ALDH1, ARID1A, and CD44 and the overexpression of CAIX are important for tumor invasion and metastasis; therefore, they may serve as useful prognostic indicators of long-term survival in patients with GA.', ['ARID1A', 'CD44'])
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# (' Recently, we identified the tumour-associated carbonic anhydrases (CA), CA9 and CA12 as hypoxia-inducible in tumour cell lines.', ['CA9', 'CA12'])
# ---------------------
# (' Linear regression analysis comparing FAZA retention with patterns of gene expression in individual tissue fragments revealed that CA9, GLUT1 and LOX mRNA levels were equally and strongly correlated to hypoxic extent in FaDudd.', ['CA9', 'LOX'])
# (' The same link between hypoxia and gene expression profile was observed for CA9 and GLUT1, but not LOX, in SCCVII tumors.', ['CA9', 'LOX'])
# (' Among tested genes, our study identified CA9, GLUT1 and possibly LOX as highly specific biomarkers of tumor hypoxia in vivo.', ['CA9', 'LOX'])
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# (' A combination of RENCA lysates and AbOmpA up-regulated the surface expression of co-stimulatory molecules, CD80 and CD86, and the antigen presenting molecules, major histocompatibility (MHC) class I and class II, in DCs.', ['CD80', 'CD86'])
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# (' This was in accord with very low expression of TSC1 (that is associated with HIF activation) and a high expression of TSC2.', ['TSC1', 'TSC2'])
# (' Moreover, angiomyolipoma specimens showed the overexpression of the ER stress markers XBP1, CHOP and ATF4 as well as of the mediators of calcium metabolism, namely the type 1 and 2, but not the type 3 IP3 receptors.', ['ATF4', 'XBP1'])
# ---------------------
# ---------------------
# (' The increase in VHL expression was accompanied an increase in the level of mRNA for NF-κB p65 and kinases PDK1 and Akt.', ['VHL', 'PDK1'])
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ('The forkhead box (FOX), FOXO1 and FOXO3, transcription factors regulate multiple functions in mammalian cells.', ['FOXO1', 'FOXO3'])
# (' Immunostaining and Western blot analyses confirmed FOXO1 and phosphatase and tensin homolog (PTEN) depletion, maintenance of globin transcription factor (GATA) 4 and nuclear localization of FOXL2 and phosphorylated small mothers against decapentaplegic (SMAD) 2/3 in the tumor cells, recapitulating results we observed in human adult GCTs.', ['FOXO1', 'FOXL2'])
# (' Thus, analyses of the Foxo1/3/Pten mouse GCTs and human adult GCTs provide strong evidence that impaired functions of the FOXO1/3/PTEN pathways lead to dramatic changes in the molecular program within granulosa cells, chronic activin signaling in the presence of FOXL2 and GATA4, and tumor formation.', ['FOXL2', 'GATA4'])
# ---------------------
# ---------------------
# ('The serum levels of a-PBP, IgG4, IgG, anti-nuclear antibodies (ANA), anti-lactoferrin (a-LF), a-CA-II, and rheumatoid factor (RF) were evaluated in patients with AIP (n\u200a=\u200a29), PC (n\u200a=\u200a17), pancreatic neuroendocrine neoplasm (P-NEN, n\u200a=\u200a12), and alcoholic chronic pancreatitis (ACP, n\u200a=\u200a41).', ['PC', 'AIP'])
# ('There was no statistically significant difference in mean a-PBP values in AIP compared with PC.', ['PC', 'AIP'])
# ('3\u200aU, low values of a-PBP had a sensitivity and specificity of 45% and 71% for differentiating AIP from PC.', ['PC', 'AIP'])
# ('4\u200ag/L) for differentiating AIP from PC was 45% and 88%, but rose to 52% and 88% when using a cut-off of 1.', ['PC', 'AIP'])
# (' When using this cut-off, the sensitivity and specificity for differentiating type 1 AIP from PC was 68% and 88%.', ['PC', 'AIP'])
# (' None of the other markers were significantly changed in AIP versus PC.', ['PC', 'AIP'])
# ('The only serological marker for which we found a statistically significant difference in mean values between AIP and PC was IgG4.', ['PC', 'AIP'])
# (' However, the value of IgG4 for the distinction of AIP from PC was limited, probably in part due to the relatively high number of type 2 AIP patients in our study.', ['PC', 'AIP'])
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# (' We investigated whether these biomarkers (HIF-1α, HIF-2α, CAIX, VEGF, VEGFR1, VEGFR2, VEGFR3, PDGFB, PDGFRA, PDGFRB, CD31, CD44, bcl-xL, KIT, p21, CXCR4, PTEN, (CSF)-1R, RET, and FLT-3) can predictive the different effects between sunitinib and sorafenib treatments and are available to guide targeted drug selection.', ['PDGFB', 'PDGFRB', 'CXCR4', 'PTEN', 'CD44', 'PDGFRA', 'KIT', 'RET'])
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# (' From 9 patients without cirrhosis, 3 presented NASH F3 and 6 NASH F2.', ['F2', 'F3'])
# ---------------------
# ---------------------
# (' The expression of Beclin-1, ARID1A, IDH1 and CA9 were determined by immunohistochemical staining.', ['ARID1A', 'CA9', 'IDH1'])
# ('RESULTS: Beclin-1, ARID1A, CA9 and IDH1 were highly expressed in ICC tumor tissues.', ['ARID1A', 'CA9', 'IDH1'])
# (' Neither CA9 nor IDH1 expression was significantly associated with mortality or disease recurrence.', ['CA9', 'IDH1'])
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# (' In other cancers, the activation of canonical wnt/beta-catenin signaling is associated with APC, CTNNB1 or AXIN1 mutations.', ['AXIN1', 'APC', 'CTNNB1'])
# (' HMEC expressed all Frizzled receptors except FZD9 and FZD10.', ['FZD10', 'FZD9'])
# (' They also expressed LRP5 and LRP6 co-receptors, as well as four Lef/TCF transcription factors.', ['LRP6', 'LRP5'])
# (' HMEC cells also expressed many Wnt ligands, including WNT1, WNT2B, WNT3, WNT5A, WNT5B, WNT7B, WNT9A, WNT10B and WNT16.', ['WNT5B', 'WNT3', 'WNT7B', 'WNT5A', 'WNT2B', 'WNT10B', 'WNT9A', 'WNT1', 'WNT16'])
# (' We noticed that most breast cancer cell lines overexpressed WNT3A, WNT4, WNT6, WNT8B, WNT9A and WNT10B.', ['WNT6', 'WNT4', 'WNT8B', 'WNT10B', 'WNT9A', 'WNT3A'])
# (' In contrast, the expression of WNT5A, WNT5B and WNT16 was usually down-regulated.', ['WNT5B', 'WNT5A', 'WNT16'])
# (' It is noteworthy that all six Wnt ligands that are overexpressed in malignant cell lines are known to signal through the canonical Wnt/beta-catenin signaling pathway, whereas down-regulated WNT5A and WNT5B ligands signal via the non-canonical pathway.', ['WNT5B', 'WNT5A'])
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# (' Antibodies were used to quantify endogenous POR, MTRR, NDOR1, and NOS2A expression in 23 human tumor cell lines; however, only POR protein was detectable and its expression correlated with anoxic PR-104A reduction (r(2) = 0.', ['MTRR', 'NDOR1', 'POR'])
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# (' FBXL14 mRNA is decreased in tumors with a high expression of two proteins up-regulated in hypoxia, carbonic anhydrase 9 and TWIST1.', ['FBXL14', 'TWIST1'])
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ('MATERIALS AND METHODS: Expression of the hypoxia-induced genes OPN, CA9, EPO, VEGF and HIF-1alpha was analyzed in three GBM cell lines, GaMG, U373 and U251, under in vitro hypoxia (1, 6 or 24h at 5%, 1% or 0.', ['CA9', 'EPO'])
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# (' Immunohistochemical stains for markers of HIF pathway activation (HIF-1α, CA9, and glucose transporter-1 (GLUT-1)) as well as other relevant markers (CK7, CD10, AMACR, and TFE3) were performed.', ['CA9', 'AMACR'])
# (' No expression of TFE3, CD10, or AMACR was seen.', ['TFE3', 'AMACR'])
# (' The co-expression of CA9, HIF-1α, and GLUT-1 in the absence of VHL gene alterations in clear-cell papillary renal cell carcinoma suggests activation of the HIF pathway by non-VHL-dependent mechanisms.', ['CA9', 'VHL'])
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# (' We show that the interaction with two of these proteins, namely XPO1 exportin and TNPO1 importin, occurs via the C-terminal region of CA IX and increases with protein phosphorylation.', ['XPO1', 'TNPO1'])
# ---------------------
# ---------------------
# (' Immunohistochemically, the tumor were positive for BRM, PBRM1, ARID1A, CD10, CKpan, Vimentin, carbonic anhydrase IX (CA-IX), and P504S (AMACR) but negative for INI1, BRG1, HMB45, melan A, CK7, CD117, Ksp-cadherin, TFEB, TFE3, and Cathepsin K.', ['PBRM1', 'TFEB', 'TFE3', 'ARID1A'])
# ---------------------
# ---------------------
# (' The expression of angiogenesis markers VEGF-A, VEGFR, PDGFββ, PDGFR, CCND1 and CA9 was assessed by immunohistochemistry (IHC) and correlated with overall survival (OS) and progression-free survival (PFS).', ['CA9', 'CCND1'])
# (' CCND1 and CA9 were positive in 44% and 60% of cases.', ['CA9', 'CCND1'])
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# (' However, the data showed that TSA down-regulated influential transcripts that drive the BRAF-extracellular signal-regulated kinase (ERK)1/2 oncogenic pathway (namely PRKCD and MYC proto-oncogene which negatively affected the cell-cycle distribution.', ['PRKCD', 'MYC'])
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# (' FISH and reverse-transcription polymerase chain reaction assays showed no EWSR1 and NR4A3 loci rearrangements.', ['EWSR1', 'NR4A3'])
# (' Microarray-based analysis also revealed no changes in NR4A3 and EWSR1 gene transcription levels.', ['EWSR1', 'NR4A3'])
# ---------------------
# (' In this study, the effect of 10 cytokines on the expression of the mCRP CD46, CD55 and CD59 and the renal tumour-associated antigen G250/MN/CAIX on four human renal tumour cell lines and proximal tubular epithelial cells was determined by flow cytometry.', ['CD55', 'CD59', 'CD46'])
# (' In addition, it was measured whether changes in the expression of the classical pathway regulatory proteins CD55 and CD59 had an effect on C3 deposition and lysis.', ['CD59', 'C3', 'CD55'])
# (' Interleukin-1beta (IL-1beta) consistently downregulated the expression of CD46 and CD59; IL-4 consistently downregulated the expression of CD46 and transforming growth factor-beta1, consistently downregulated the expression of both CD46 and CD55.', ['CD55', 'CD46'])
# (' Changes in the expression of CD55 and CD59 were associated with changes in the amount of C3 deposited and the extent of complement-mediated lysis, respectively.', ['CD59', 'C3', 'CD55'])
# (' This suggests that clinical immunotherapy, consisting of treatment with cytokines and MoAb, may induce either up- or downregulation of CD55 or CD59 and thus affect the effectiveness of immunotherapy with MoAb.', ['CD59', 'CD55'])
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# ---------------------
# (' Immunohistochemistry revealed positivity for Pan-CK, CK7, CK8/18, MUC1, MUC6, carbonic anhydrase IX, CD10, EMA, β-catenin and e-cadherin.', ['MUC6', 'MUC1'])
# (' Sanger sequencing did not detect mutations for β-catenin, BRAF, KRAS, PIK3CA and GNAS.', ['PIK3CA', 'KRAS', 'BRAF', 'GNAS'])
# ---------------------
# ---------------------
# ---------------------
# ---------------------

# %%
s='FSTX1	SFTX1	YSX1	FXX1	头晕	黄疸	PQTTX1	BJQX1	坐立不安	HBX1	YXFTX1	ZYXTX1	ZFTX1	YSFTX1	FSDFX1	CXFTX1	YHJZX1	ZFXTX1	突然发作	绞痛	JLFTX1	恶心呕吐	腹胀	TZPBX1	停经	YDLXX1	PNGBX1	FTSCFX1	YCFTX1	性别	年龄'

# %%
print(len(s.split('	')))
# Out:
# 31
